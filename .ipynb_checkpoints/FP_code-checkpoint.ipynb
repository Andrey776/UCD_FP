# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Infrastructure" data-toc-modified-id="Infrastructure-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Infrastructure</a></span><ul class="toc-item"><li><span><a href="#Library-and-data-upload" data-toc-modified-id="Library-and-data-upload-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Library and data upload</a></span></li><li><span><a href="#Functions-and-Plan-1-of-2" data-toc-modified-id="Functions-and-Plan-1-of-2-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Functions and Plan 1 of 2</a></span><ul class="toc-item"><li><span><a href="#bin_table" data-toc-modified-id="bin_table-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>bin_table</a></span></li><li><span><a href="#CART_class" data-toc-modified-id="CART_class-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>CART_class</a></span></li><li><span><a href="#get_edges_dict" data-toc-modified-id="get_edges_dict-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>get_edges_dict</a></span></li><li><span><a href="#woe_transform" data-toc-modified-id="woe_transform-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>woe_transform</a></span></li><li><span><a href="#var_list_woe" data-toc-modified-id="var_list_woe-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>var_list_woe</a></span></li><li><span><a href="#lr_model_fit_test" data-toc-modified-id="lr_model_fit_test-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>lr_model_fit_test</a></span></li><li><span><a href="#check_model" data-toc-modified-id="check_model-1.2.7"><span class="toc-item-num">1.2.7&nbsp;&nbsp;</span>check_model</a></span></li><li><span><a href="#plot_results-(bootstrap)" data-toc-modified-id="plot_results-(bootstrap)-1.2.8"><span class="toc-item-num">1.2.8&nbsp;&nbsp;</span>plot_results (bootstrap)</a></span></li><li><span><a href="#prepare-the-data-set" data-toc-modified-id="prepare-the-data-set-1.2.9"><span class="toc-item-num">1.2.9&nbsp;&nbsp;</span>prepare the data set</a></span></li><li><span><a href="#plot-parameter-cycle-results" data-toc-modified-id="plot-parameter-cycle-results-1.2.10"><span class="toc-item-num">1.2.10&nbsp;&nbsp;</span>plot parameter cycle results</a></span></li><li><span><a href="#Save-and-load-staff" data-toc-modified-id="Save-and-load-staff-1.2.11"><span class="toc-item-num">1.2.11&nbsp;&nbsp;</span>Save and load staff</a></span></li></ul></li></ul></li><li><span><a href="#DEA" data-toc-modified-id="DEA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DEA</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#pipeline-cycle-over-parameter-space" data-toc-modified-id="pipeline-cycle-over-parameter-space-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>pipeline cycle over parameter space</a></span></li><li><span><a href="#results" data-toc-modified-id="results-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>results</a></span></li></ul></li></ul></li><li><span><a href="#Experiment---Cont-vs.-Bin" data-toc-modified-id="Experiment---Cont-vs.-Bin-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Experiment - Cont vs. Bin</a></span><ul class="toc-item"><li><span><a href="#no-binning-(Scikit-+-GridSearchCV)" data-toc-modified-id="no-binning-(Scikit-+-GridSearchCV)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>no binning (Scikit + GridSearchCV)</a></span></li><li><span><a href="#no-binning-(Scikit,-no-GridSearchCV)" data-toc-modified-id="no-binning-(Scikit,-no-GridSearchCV)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>no binning (Scikit, no GridSearchCV)</a></span></li><li><span><a href="#simple-binning-(KBinsDisc),-no-WOE)" data-toc-modified-id="simple-binning-(KBinsDisc),-no-WOE)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>simple binning (KBinsDisc), no WOE)</a></span></li></ul></li><li><span><a href="#Experiment-simple-bin-vs.-WOE-transformed" data-toc-modified-id="Experiment-simple-bin-vs.-WOE-transformed-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Experiment simple bin vs. WOE-transformed</a></span><ul class="toc-item"><li><span><a href="#simple-binning-(n_bins-=-10,-no-WoE-transf)" data-toc-modified-id="simple-binning-(n_bins-=-10,-no-WoE-transf)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>simple binning (n_bins = 10, no WoE transf)</a></span></li><li><span><a href="#woe-transformed-binning-(n_bins-=-10)" data-toc-modified-id="woe-transformed-binning-(n_bins-=-10)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>woe transformed binning (n_bins = 10)</a></span></li></ul></li><li><span><a href="#Unsupervized-methods-exploration" data-toc-modified-id="Unsupervized-methods-exploration-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Unsupervized methods exploration</a></span></li><li><span><a href="#OptBinning-exploration-NEW" data-toc-modified-id="OptBinning-exploration-NEW-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>OptBinning exploration NEW</a></span><ul class="toc-item"><li><span><a href="#Exp_1-p_val" data-toc-modified-id="Exp_1-p_val-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Exp_1 p_val</a></span></li><li><span><a href="#Exp-2-min_bin_n_event" data-toc-modified-id="Exp-2-min_bin_n_event-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Exp 2 min_bin_n_event</a></span></li></ul></li><li><span><a href="#CART-exploration-NEW" data-toc-modified-id="CART-exploration-NEW-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>CART exploration NEW</a></span><ul class="toc-item"><li><span><a href="#Exp_1" data-toc-modified-id="Exp_1-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Exp_1</a></span></li><li><span><a href="#Exp_2" data-toc-modified-id="Exp_2-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Exp_2</a></span></li></ul></li><li><span><a href="#MDLP-exploration" data-toc-modified-id="MDLP-exploration-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>MDLP exploration</a></span><ul class="toc-item"><li><span><a href="#Experiment" data-toc-modified-id="Experiment-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Experiment</a></span></li><li><span><a href="#Time-baseline" data-toc-modified-id="Time-baseline-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Time baseline</a></span></li></ul></li><li><span><a href="#The-best-one-for-a-wider-dataset" data-toc-modified-id="The-best-one-for-a-wider-dataset-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>The best one for a wider dataset</a></span><ul class="toc-item"><li><span><a href="#Basic-experiment" data-toc-modified-id="Basic-experiment-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Basic experiment</a></span></li><li><span><a href="#Playing-with-time" data-toc-modified-id="Playing-with-time-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Playing with time</a></span></li></ul></li><li><span><a href="#Test-sandbox" data-toc-modified-id="Test-sandbox-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Test sandbox</a></span></li></ul></div>

# %% [markdown]
# # Infrastructure

# %% [markdown]
# ## Library and data upload

# %%
#import sys
import pandas as pd
import numpy as np
import random
import pyspark
import time 
import itertools
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
import pickle
import statsmodels.api as sm

from collections import Counter

from math import sqrt
from platform import python_version

from pyspark.sql import SparkSession
from pyspark.sql import functions as f
#from pyspark.mllib.feature import MDLPDiscretizer
from pyspark.mllib.util import MLUtils
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.ml.linalg import Vectors

import joblib
from joblib import parallel_backend
from joblib import Parallel, delayed

from joblib import parallel_backend

#from pandas_profiling import ProfileReport

from sklearn.preprocessing import KBinsDiscretizer
from sklearn.tree import DecisionTreeClassifier
#from sklearn.datasets import load_boston
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import f1_score, r2_score, roc_curve, auc, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from optbinning import OptimalBinning
from optbinning import MDLP
from optbinning import BinningProcess
from optbinning.binning.transformations import transform_event_rate_to_woe
from optbinning.binning.metrics import gini
from optbinning.binning.outlier import ModifiedZScoreDetector

#plt.style.use('seaborn')    
#plt.style.use('default')

# %%
spark = SparkSession.builder.master("local").appName("spark_app_1234").getOrCreate()
sc = spark.sparkContext
spark
d0 = (
    spark
    .read
    .format("csv") 
    .option("header","true") 
    .option("inferSchema","true") 
    .load("/Users/AM/home-credit-default-risk/application_train.csv")
)

# %%
d0.count()
# Out:
# 307511

# %% [markdown]
# ## Functions and Plan 1 of 2
# - check WOE transform for EXT2 +
# - check WOE transform for EXT3 +
# - Check scorekit Logregmodel on roccurve approach +
# - change  Model_check for y_prob +
# - train-test +++
# - cycle with +++
# - add MDLP +++
# - Chi2 +++ no code in Python
# - play with stratify +++ (no need as the reslts are very close)
# - move part of this plan into FP report (esp startify) ???
# - find splits on the entire DS and than measure metrics on diffferent train/ test splits

# %% [markdown]
# ### bin_table

# %%
def bin_table(dataframe, disc_var_name, target_var_name, edges):
    '''
    returns the analogue of optb.binning_table (plus Gini) based on edges 
    df - our data in DataFrame, target_var_name - target variable
    disc_var_name - variable to analyze
    edges - bin edges 
    returns WoE DataFrame
    also puts all NA into a separate bin (to keep info as I wrote in FP paper)
    '''
    df = dataframe.copy()
    edges = np.append(edges, np.inf)
    edges = np.insert(edges, 0, -np.inf)
    N_na = df[disc_var_name].isna().sum()
    if N_na > 0: 
        target_share_in_na = df[target][df[disc_var_name].isna()].sum() / N_na

    df['Bin'] = pd.cut(df[disc_var_name],  bins = edges) 
    df = pd.concat([df['Bin'], df[target_var_name]], axis = 1)
    df = pd.concat([df.groupby(df.columns.values[0], 
                               as_index = False)[df.columns.values[1]].count(),
                    df.groupby(df.columns.values[0], 
                               as_index = False)[df.columns.values[1]].mean()], axis = 1)
    df = df.iloc[:, [0, 1, 3]]
    if N_na > 0: 
        df.loc[df.shape[0]] = ['Missing', N_na, target_share_in_na]  # adding na observations
    df.columns = [df.columns.values[0], 'N_obs', 'prop_pos']
    df['N_obs'] = df['N_obs']
    df['Count (%)'] = (100*df['N_obs'] / df['N_obs'].sum()).round(2)
    df['N_pos'] = (df['prop_pos'] * df['N_obs'])
    df['N_neg'] = ((1 - df['prop_pos']) * df['N_obs'])
    df['Event_rate'] = df['N_pos'] / df['N_obs']
    df['Non_event_rate'] = df['N_neg'] / df['N_obs']
    df['prop_N_pos'] = df['N_pos'] / df['N_pos'].sum()
    df['prop_N_neg'] = df['N_neg'] / df['N_neg'].sum()
    #df['Odds'] = df['Event_rate'] / df['Non_event_rate']
    df['WoE'] = -np.log(df['prop_N_pos'] / df['prop_N_neg']) 
    df['diff_prop_pos'] = df['prop_pos'].diff().abs()
    df['diff_WoE'] = df['WoE'].diff().abs()
    df['IV'] = -(df['prop_N_pos'] - df['prop_N_neg']) * df['WoE']
    df['Gini'] = ''
    df = df[['Bin', 'N_obs', 'Count (%)', 'N_neg', 'N_pos', 
             'Event_rate', 'WoE', 'IV', 'Gini']]
    df.loc['Total']= df.sum(numeric_only=True, axis=0)
    df.columns = ['Bin', 'Count', 'Count (%)', 'Non_event', 'Event', 
                  'Event_rate', 'WoE', 'IV', 'Gini']   
    df.loc['Total', 'Gini'] = round(gini(df.Event[:-1], df.Non_event[:-1]), 4)
    df.loc['Total', 'Event_rate'] = ""
    df.loc['Total', 'WoE'] = ""
    #df.loc['Total', 'Bin'] = "" # set the category first
    #df.loc['Total', 'Odds'] = ""
    return df

# %% [markdown]
# ### CART_class

# %%
class CART:
    def __init__(self, criterion='gini', splitter='best', max_depth=None, 
                       min_samples_leaf=1000, 
                       max_leaf_nodes=None, 
                       min_impurity_decrease=0, ccp_alpha=0, n_jobs=-1): 
        self.criterion=criterion
        self.splitter=splitter
        self.max_depth=max_depth 
        self.min_samples_leaf=min_samples_leaf 
        self.max_leaf_nodes = max_leaf_nodes 
        self.min_impurity_decrease = min_impurity_decrease
        self.ccp_alpha = ccp_alpha
        self.n_jobs = n_jobs
        self.dtree = DecisionTreeClassifier(criterion=self.criterion, 
                                     splitter=self.splitter, 
                                     max_depth=self.max_depth,
                                     min_samples_leaf=self.min_samples_leaf,
                                     max_leaf_nodes = self.max_leaf_nodes, 
                                     min_impurity_decrease = self.min_impurity_decrease, 
                                     ccp_alpha = self.ccp_alpha)
    
    def fit(self, x, y):
        '''fits the tree '''

        #with parallel_backend('threading', n_jobs=self.n_jobs):
        self.dtree.fit(x, y)
        return self.dtree

    def get_tree_splits(self):
        '''
        Returns list of thresholds of the deision tree.

        Parameters
        ---------------
        tree: DecisionTreeClassifier object

        Returns
        ---------------
        boundaries: list of thresholds
        '''
        children_left = self.dtree.tree_.children_left
        children_right = self.dtree.tree_.children_right
        threshold = self.dtree.tree_.threshold
        # boundaries of split
        self.boundaries = []

        for i in range(self.dtree.tree_.node_count):
            if children_left[i] != children_right[i]:
                self.boundaries.append(threshold[i])

        return sorted(self.boundaries)
    def print_param(self):
        print(self.criterion,
        self.splitter,
        self.max_depth, 
        self.min_samples_leaf, 
        self.max_leaf_nodes, 
        self.min_impurity_decrease,
        self.ccp_alpha)

# %% [markdown]
# ### get_edges_dict

# %%
# prepare edges
def get_edges_dict(dataframe, variables, target, 
                   bin_method = OptimalBinning(dtype="numerical"), verbose = False):
    '''
    split variables of the df from the variables list by a chosen method
    and stores it in the dict 
    '''
    t0 = time.time()
    df = dataframe.copy()
    edges_dict = {}
    bt_dict = {}
    master_method = bin_method # need it to solve MDLP edges_dict library mistake
    for i, variable in enumerate(variables):
        t00 = time.time()
        if type(bin_method) == MDLP:
            ind_tmp = df[variable].isna()
            x = df[variable][~ind_tmp].values
            y = df[target][~ind_tmp]
            bin_method.fit(x, y)
            current_edges = bin_method.splits
            current_edges = current_edges.tolist()
            next_turn_last_edges = bin_method.splits
            next_turn_last_edges = next_turn_last_edges.tolist()
            if i>0:    
                for e in last_turn_edges:
                    current_edges.remove(e)
            edges_tmp = current_edges
            last_turn_edges = next_turn_last_edges
            
        elif type(bin_method) == OptimalBinning:    
            x = df[variable].values
            y = df[target]
            bin_method.fit(x, y)
            edges_tmp = bin_method.splits
            bt = bin_method.binning_table
            bt.build()
            bt_dict[variable] = bt
        elif type(bin_method) == CART:
            ind_tmp = df[variable].isna()
            x = df[variable][~ind_tmp].values.reshape(-1,1)
            y = df[target][~ind_tmp]
            bin_method.fit(x, y)
            edges_tmp = bin_method.get_tree_splits() 
            bt = bin_table(df, variable, target, edges_tmp)
            bt_dict[variable] = bt # think about unification with OptBinning case
        else: 
            type(bin_method) == KBinsDiscretizer
            x = df[variable].dropna().values
            x = x.reshape(-1,1)
            est = bin_method.fit(x)
            edges_tmp = est.bin_edges_[0][1:-1] # drop the first and the last to be in line with optimalBinning
        
        edges_dict[variable] = edges_tmp
        bin_method = master_method # need it to solve MDLP edges_dict library mistake
        if (type(bin_method) == OptimalBinning) & verbose:    
            print(f'for {variable} optb.status is {bin_method.status}')
        if verbose: 
            print(f'for {variable} run time {time.time()-t00}')
            print(f'edges are {edges_tmp}')
            print('')
    if verbose:
        print(f'Bin_method is {bin_method}; Total run time {time.time()-t0}')
    if type(bin_method) == CART:   
        result = (edges_dict, bt_dict)
    elif type(bin_method) == OptimalBinning:
        result = (edges_dict, bt_dict)
    else: result = (edges_dict, 'mas_no_bt_dict_here')
    return result

# %% [markdown]
# ### woe_transform

# %%
def WOE_transform(df_to_transform, df_to_find_WOE, variable, target, edges):
    '''
    optimized version
    returns a list f'{variable}_woe' - WOE transormed variable
    first it uses bin_table function
    '''  
    tt0 = time.time()
    btf = bin_table(df_to_find_WOE, variable, target, edges)
    tt1 = time.time()
    edges_np = np.array(edges)
    woe_index = np.searchsorted(edges_np, df_to_transform[variable].values)
    tt2 = time.time()
    df_tmp = pd.DataFrame()
    df_tmp[f'{variable}_WoE'] = [btf.WoE[i] for i in woe_index]
    if 'Missing' in btf.Bin.values:    
        tmp = btf.WoE[btf.shape[0]-2]
        df_tmp.loc[df_to_transform[variable].isna(), f'{variable}_WoE'] = tmp
    tt3 =time.time()
    tt = tt3-tt0
    print(f'WOE_transform: Bin_table-{round(100*(tt1-tt0)/tt, 1)}%; np.searchsorted-{round(100*(tt2-tt1)/tt, 1)}%; wrap up-{round(100*(tt3-tt2)/tt, 1)}%; Total {round((tt3-tt2), 1)}sec ')
    return df_tmp

# %% [markdown]
# ### var_list_woe

# %%
def var_list_woe(df_to_transform, df_to_find_WOE, variables, target, edges_dict, verbose = False):
    ''' creates new df with woe-transformed var'''
    t0 = time.time()
    df = pd.DataFrame()
    df.loc[:, target] = df_to_transform[target]
    for variable in variables:
        t00 = time.time()
        df[f'{variable}_woe'] = WOE_transform(df_to_transform, df_to_find_WOE, 
                                              variable, target, edges_dict[variable])
        if verbose: print(f'{variable}_woe run time is {time.time()-t00}')
    if verbose: 
        print('')
        print(f'Total woe_transformation run time is {time.time()-t0}')        
    return df

# %% [markdown]
# ### lr_model_fit_test

# %%
def lr_model_fit_test(df_woe_, lr = LogisticRegression(), verbose = False):
    X = df_woe_.iloc[:, 1:].to_numpy()
    y = df_woe_.iloc[:, 0].values
    print('starting the lr model fit...')

    lr.fit(X, y)
    #y_pred = lr.predict(X)
    #y_dec_score = lr.decision_function(X)
    if verbose: print('model parameters: ', lr.intercept_, lr.coef_)
    print('start to check the model')

    metric = check_model(lr, X, y, verbose = verbose)
    return metric

# %% [markdown]
# ### check_model

# %%
def check_model(m, X, y, verbose = False):
    y_prob = m.predict_proba(X)[:,1]
    fpr, tpr, _ = roc_curve(y, y_prob) 
    g = round((2 * auc(fpr, tpr) - 1), 4)
    if verbose:   
        y_pred = m.predict(X)
        y_dec_score = m.decision_function(X)
        accuracy = accuracy_score(y, y_pred)
        print(f'accuracy = {accuracy:2.5f}')
        f1 = f1_score(y, y_pred)
        print(f'F1 score = {f1:2.5f}')
        roc_auc_sc1 = roc_auc_score(y, y_prob)
        roc_auc_sc2 = roc_auc_score(y, y_dec_score)
        print(f'roc_auc_score (prob based) = {roc_auc_sc1:2.5f}')
        print(f'roc_auc_score (dec_func_based) = {roc_auc_sc2:2.5f}')        
        print(f'AUC = {auc(fpr, tpr):2.5f}')    
        print(f'(2 * roc_AUC - 1 ) = {g:2.5f}')
        plt.plot(fpr, tpr, linewidth=2)
        plt.plot([0, 1], [0, 1], 'k--')  
        plt.xlabel('False positive Rate')
        plt.ylabel('True Positive Rate (Recall)')
        plt.show()
    return g

# %% [markdown]
# ### plot_results (bootstrap)

# %%
def plot_results(df_result, metric, bin_method):
    n = df_result.shape[0]-2
    plt.figure(figsize=(8,6))
    dd = df_result[metric][:-1].values
    sns.distplot(dd)
    palette = itertools.cycle(sns.color_palette())
    bootstrap_gini = dd
    plt.axvline(x=np.mean(bootstrap_gini), linestyle='--', color='b', alpha=0.8)
    plt.text(np.mean(bootstrap_gini), 0, '   mean = '+str(round(np.mean(bootstrap_gini),4)),
                 horizontalalignment='right', verticalalignment='bottom', rotation=90, fontsize=14)

    plt.axvline(x=np.mean(bootstrap_gini)-np.std(bootstrap_gini), linestyle='--', color='red', alpha=0.3)
    plt.text(np.mean(bootstrap_gini)-np.std(bootstrap_gini), 0, '   mean-std = '+str(round(np.mean(bootstrap_gini)-np.std(bootstrap_gini),4)),
                 horizontalalignment='right', verticalalignment='bottom', rotation=90, fontsize=12)

    plt.axvline(x=np.mean(bootstrap_gini)+np.std(bootstrap_gini), linestyle='--', color='red', alpha=0.3)
    plt.text(np.mean(bootstrap_gini)+np.std(bootstrap_gini), 0, '   mean+std = '+str(round(np.mean(bootstrap_gini)+np.std(bootstrap_gini),4)),
                 horizontalalignment='right', verticalalignment='bottom', rotation=90, fontsize=12)

    plt.axvline(x=np.mean(bootstrap_gini)-2*np.std(bootstrap_gini), linestyle='--', color='red', alpha=0.5)
    plt.text(np.mean(bootstrap_gini)-2*np.std(bootstrap_gini), 0, '   mean-2*std = '+str(round(np.mean(bootstrap_gini)-2*np.std(bootstrap_gini),4)),
                 horizontalalignment='right', verticalalignment='bottom', rotation=90, fontsize=12)
    plt.axvline(x=np.mean(bootstrap_gini)+2*np.std(bootstrap_gini), linestyle='--', color='red', alpha=0.5)
    plt.text(np.mean(bootstrap_gini)+2*np.std(bootstrap_gini), 0, '   mean+2*std = '+str(round(np.mean(bootstrap_gini)+2*np.std(bootstrap_gini),4)),
                 horizontalalignment='right', verticalalignment='bottom', rotation=90, fontsize=12)
    mm = round(np.mean(bootstrap_gini), 4)
    ss =round(np.std(bootstrap_gini), 4)
    plt.xlabel(f'Gini values (std = {ss})', fontsize=14)
    plt.ylabel('Distribution', fontsize = 14)
    #tmp_rt = round(df_result.loc['MEAN', 'Run_time'], 3)
    plt.title(f'Bootstrap distribution for {metric}, {n} samples.\n\
Method: {bin_method}', fontsize = 15, loc='center')
    plt.yticks([])
    plt.show()

# %% [markdown]
# ### prepare the data set

# %%
target = 'TARGET'
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
def prepare_df(df_spark, variables = variables, 
               remove_outl = True, remove_na = True):
    '''just ulpoad and creates the initial df from previously uploaded spark d0'''
    df0 = df_spark.select(variables + [target]).toPandas()
    df0.DAYS_EMPLOYED.replace(365243, np.nan, inplace=True)
    print(f'df initial shape: {df0.shape}\n')
    if remove_na:
        df = df0.dropna(axis=0).reset_index(drop = True)
        print(f'df shape after processing missing values: {df.shape}\n')
    else: 
        df = df0
    outl = ModifiedZScoreDetector(3.5)
    if remove_outl:
        for variable in variables:
            outl.fit(df[variable])
            df = df[~outl.get_support()]
            print(f'N outliers in {variable}: {outl.get_support().sum()},\
            df shape after outlier removal: {df.shape}')
        df = df.reset_index(drop = True)
    print(f'\nfinal df shape: {df.shape}')
    # we remove nan not to spent time for different method API's
    return df

# %% [markdown]
# ### plot parameter cycle results

# %%
def plot_cycle_results(result_df, bin_method, n, x_name):
    labels = result_df.index.to_list()
    x = np.arange(len(labels))
    fig, ax = plt.subplots(figsize=(10,6))

    width = 0.35

    rects1 = ax.bar(x - width/2, result_df.g_train, width, label = 'Gini train', alpha = 0.6)
    rects2 = ax.bar(x + width/2, result_df.g_test, width, label = 'Gini test', alpha = 0.6)

    ax.set_ylabel('Gini coefficient', fontsize=14)
    name = f'{bin_method}'#[:14]
    ax.set_title(f'Mean gini, {n} iterations.\n\
    Method: {name}', fontsize = 15)
    ax.set_xticks(x)

    ymin = 0.97*result_df.g_train.min()
    ymax = 1.02*result_df.g_train.max()
    ax.set_ylim([ymin, ymax])
    ax.set_xlabel(x_name, fontsize=14)

    ax.set_xticklabels(labels)
    ax.legend()

    ax.bar_label(rects1, padding=3)
    ax.bar_label(rects2, padding=3)

    plt.show()

# %% [markdown]
# ### Save and load staff

# %%
def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# # DEA

# %%
df = prepare_df(d0)

# %%
#df_dea = ProfileReport(df)

# %%
#df_dea.to_file('df_dea.html')

# %%
#df_dea

# %% [markdown]
# ###  pipeline cycle over parameter space

# %%
parameter_space = ['cart', 'mdlp', 'quantile']
result_dict = {} # contains all the df_result tables
for n_param, parameter in enumerate(parameter_space): 
    tpar0=time.time()
    bin_method=OptimalBinning(prebinning_method=parameter)
    #bin_method = MDLP(min_samples_split=2, min_samples_leaf=10000, max_candidates=32)
    #bin_method=KBinsDiscretizer()
    #bin_method = CART()
    n_iter = 100
    verbose = False
    model = LogisticRegression(max_iter=n_iter)
    ed = get_edges_dict(df, variables, target, verbose=False, bin_method=bin_method)
    df_woe = var_list_woe(df, df, variables, target, ed, verbose=False)
    df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 
                                      'N_bins', 'Bin_method', 'N_iter'])
    for i in range(n_iter):
        dfw_train, dfw_test = train_test_split(df_woe, test_size=0.30)#, stratify=df[target])
        tp0 = time.time()
        #fit the model on train set
        X = dfw_train.iloc[:, 1:].to_numpy()
        y = dfw_train.iloc[:, 0].values
        model.fit(X, y)
        g_train = round(check_model(model, X, y), 4)
        # now test the model on test_set
        X = dfw_test.iloc[:, 1:].to_numpy()
        y = dfw_test.iloc[:, 0].values
        g_test = round(check_model(model, X, y), 4)
        t = round((time.time() - tp0), 2)
        if verbose: 
            print(f'Train gini {g_train}; Test gini {g_test}')
            print(f'Run time for round {i+1} is {t} sec.')
        df_result.loc[i, 'Bin_method'] = bin_method  
        df_result.loc[i, 'Gini_train'] = g_train
        df_result.loc[i, 'Gini_test'] = g_test
        df_result.loc[i, 'Run_time'] = t  
        df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
        df_result.loc[i, 'N_iter'] = n_iter  
       
    
    df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].mean(), 4)
    df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].std(), 4)
    t = round((time.time() - tpar0), 2)
    print(f'Run time for parameter {parameter} is {t} sec.')
    result_dict[parameter] = df_result

# %%
result_dict[parameter]

# %% [markdown]
# ### results

# %%
# df_dict_result contains gini train/ test for each parameter
df_dict_result = pd.DataFrame(columns=['parameter', "g_train", "g_test", 
                                       "Bin_method", 'N_iter'])
for i, parameter in enumerate(result_dict.keys()):
    df_dict_result.loc[i,"parameter"] = parameter
    df_dict_result.loc[i,"g_train"] = result_dict[parameter].loc['MEAN', 'Gini_train']
    df_dict_result.loc[i,"g_test"] = result_dict[parameter].loc['MEAN', 'Gini_test']
    df_dict_result.loc[i,"Bin_method"] = result_dict[parameter].loc[0, 'Bin_method']
    df_dict_result.loc[i,"N_iter"] = result_dict[parameter].loc[0, 'N_iter']

    
df_dict_result

# %%
f'{bin_method}'[:10]

# %%
plt.figure(figsize=(10,6))
x = np.array(list(result_dict.keys()))
plt.plot(x, df_dict_result.g_train)
plt.plot(x, df_dict_result.g_test)

plt.ylabel('Gini', fontsize=14)
plt.xlabel('Parameter', fontsize = 14)
plt.legend(df_dict_result.columns[1:3])
#plt.title(f'Gini, {n} samples.\n\
#Method: {bin_method}', fontsize = 15, loc='center')
plt.show()

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
# stable as of 2021 11 05 mrning

# # pipeline
# #bin_method=OptimalBinning()
# ## find it inside ##bin_method = MDLP(min_samples_split=2, min_samples_leaf=10000, max_candidates=32)
# #bin_method=KBinsDiscretizer(n_bins=2)

# df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 'N_bins', 'Bin_method'])
# for i in range(2):
#     ## must be inside the loop
#     bin_method = MDLP(min_samples_split=2, min_samples_leaf=15000, max_candidates=32)
#     ## to avoid the library driven error
    
#     df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
#     df_train = df_train.reset_index()
#     df_test = df_test.reset_index()

#     tp0 = time.time()
#     ed = get_edges_dict(df_train, variables, target, verbose=False, bin_method=bin_method)
#     df_woe = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
#     g_train = round(lr_model_fit_test(df_woe, verbose=False), 5)
    
#     df_woe = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)
#     g_test = round(lr_model_fit_test(df_woe, verbose=False), 5)
#     print(f'Train gini {g_train}; Test gini {g_test}')
#     t = round((time.time() - tp0), 2)
#     print(f'Run time for round {i+1} is {t} sec')
#     df_result.loc[i, 'Bin_method'] = bin_method  
#     df_result.loc[i, 'Gini_train'] = g_train
#     df_result.loc[i, 'Gini_test'] = g_test
#     df_result.loc[i, 'Run_time'] = t  
#     df_result.loc[i, 'N_bins'] = [len(ed[x]) for x in ed.keys()]
#     print('')
# df_result.loc['MEAN']= df_result[['Gini_train', 'Gini_test', 'Run_time']].mean()
# df_result.loc['STD']= df_result[['Gini_train', 'Gini_test', 'Run_time']].std()

# df_result

# %%
plot_results(df_result, 'Gini_train', est)

# %% [markdown]
# # Experiment - Cont vs. Bin

# %%
df = prepare_df(d0)

# %% [markdown]
# ## no binning (Scikit + GridSearchCV)
# - Run time for parameter 1 is 158.91 sec.
# - try it with njob =[1,2,4, 8, 16, -1]

# %%
y = df[target]
X = df[variables]

parameter_space = ['1']

grid={"C":np.logspace(-2, 3, 7), "penalty":["l1","l2"]}# l1 lasso l2 ridge
logreg=LogisticRegression()
logreg_cv = GridSearchCV(logreg, grid, cv=5)

#m = LogisticRegression(max_iter=100)
n_bins = np.nan
bin_method = np.nan
n_iter = 50
verbose = False

result_dict = {} # contains all the df_result tables
for n_param, parameter in enumerate(parameter_space): 
    tpar0 = time.time()

    df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 
                                      'N_bins', 'Bin_method', 'N_iter'])
    for i in range(n_iter):
        tp0 = time.time()
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)#, stratify=df[target])
    
        logreg_cv.fit(X_train,y_train)
        m = logreg_cv.best_estimator_
        y_prob = m.predict_proba(X_train)[:,1]
        fpr, tpr, _ = roc_curve(y_train, y_prob) 
        g_train = (2 * auc(fpr, tpr) - 1)
        # now test the model on test_set   
        y_prob = m.predict_proba(X_test)[:,1]
        fpr, tpr, _ = roc_curve(y_test, y_prob) 
        g_test = (2 * auc(fpr, tpr) - 1) 
        
        t = round((time.time() - tp0), 2)
        if verbose: 
            print(f'Train gini {g_train}; Test gini {g_test}')
            print(f'Run time for round {i+1} is {t} sec.')
        df_result.loc[i, 'Bin_method'] = bin_method  
        df_result.loc[i, 'Gini_train'] = g_train
        df_result.loc[i, 'Gini_test'] = g_test
        df_result.loc[i, 'Run_time'] = t  
        df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
        df_result.loc[i, 'N_iter'] = n_iter  
         
    df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].mean(), 4)
    df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].std(), 4)
    t = round((time.time() - tpar0), 2)
    print(f'Run time for parameter {parameter} is {t} sec.')
    result_dict[parameter] = df_result

# %%
result_dict['1']

# %%
bin_method = 'without binning; GridSearchCV (C and penalties).'

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
plot_results(df_result, 'Gini_test', bin_method)

# %% [markdown]
# ## no binning (Scikit, no GridSearchCV)

# %%
y = df[target]
X = df[variables]

parameter_space = ['1']

logreg_cv=LogisticRegression()

n_bins = np.nan
bin_method = np.nan
n_iter = 50
verbose = False

result_dict = {} # contains all the df_result tables
for n_param, parameter in enumerate(parameter_space): 
    tpar0 = time.time()

    df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 
                                      'N_bins', 'Bin_method', 'N_iter'])
    for i in range(n_iter):
        tp0 = time.time()
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)#, stratify=df[target])
    
        logreg_cv.fit(X_train,y_train)
        m = logreg_cv
        y_prob = m.predict_proba(X_train)[:,1]
        fpr, tpr, _ = roc_curve(y_train, y_prob) 
        g_train = (2 * auc(fpr, tpr) - 1)
        # now test the model on test_set   
        y_prob = m.predict_proba(X_test)[:,1]
        fpr, tpr, _ = roc_curve(y_test, y_prob) 
        g_test = (2 * auc(fpr, tpr) - 1) 
        
        t = round((time.time() - tp0), 2)
        if verbose: 
            print(f'Train gini {g_train}; Test gini {g_test}')
            print(f'Run time for round {i+1} is {t} sec.')
        df_result.loc[i, 'Bin_method'] = bin_method  
        df_result.loc[i, 'Gini_train'] = g_train
        df_result.loc[i, 'Gini_test'] = g_test
        df_result.loc[i, 'Run_time'] = t  
        df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
        df_result.loc[i, 'N_iter'] = n_iter  
         
    df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].mean(), 4)
    df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].std(), 4)
    t = round((time.time() - tpar0), 2)
    print(f'Run time for parameter {parameter} is {t} sec.')
    result_dict[parameter] = df_result

# %%
bin_method = 'without binning; without GridSearchCV.'

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
plot_results(df_result, 'Gini_test', bin_method)

# %% [markdown]
# ## simple binning (KBinsDisc), no WOE)
# - build basic model (as the baseline) +
# - build one-hot encoded with all the Scikit-learn methods +
# - CART
# - run model check cycles +

# %%
df = prepare_df(d0)

# %%
m = LogisticRegression()
n_bins = 5
n_iter = 50
verbose = False

y = df[target]
X = df[variables]

est = KBinsDiscretizer()
est.fit(X)

# %%
t0 = time.time()
df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 'N_bins', 'Bin_method'])
for i in range(n_iter):
    tp0 = time.time()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)#, stratify=df[target])
    
    Xt_train = est.transform(X_train)
    m.fit(Xt_train, y_train)
    y_prob = m.predict_proba(Xt_train)[:,1]
    fpr, tpr, _ = roc_curve(y_train, y_prob) 
    g_train = (2 * auc(fpr, tpr) - 1)

    Xt_test = est.transform(X_test)
    m.fit(Xt_test, y_test)
    y_prob = m.predict_proba(Xt_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_prob) 
    g_test = (2 * auc(fpr, tpr) - 1)    
    t = round((time.time() - tp0), 2)
    if verbose:
        print(f'Train gini {g_train}; Test gini {g_test}')
        print(f'Run time for round {i+1} is {t} sec')
        print('')
    df_result.loc[i, 'Bin_method'] = est
    df_result.loc[i, 'Gini_train'] = g_train
    df_result.loc[i, 'Gini_test'] = g_test
    df_result.loc[i, 'Run_time'] = t  
    df_result.loc[i, 'N_bins'] = n_bins
    
df_result.loc['MEAN']= df_result[['Gini_train', 'Gini_test', 'Run_time']].mean()
df_result.loc['STD']= df_result[['Gini_train', 'Gini_test', 'Run_time']].std()
t = time.time()-t0
print(f'Run time is {t} sec')

df_result

# %%
plot_results(df_result, 'Gini_train', est)

# %%
plot_results(df_result, 'Gini_test', est)

# %% [markdown]
# # Experiment simple bin vs. WOE-transformed

# %%
df = prepare_df(d0)

# %% [markdown]
# ## simple binning (n_bins = 10, no WoE transf)

# %%
m = LogisticRegression()
n_bins = 10
n_iter = 50
verbose = False
est = KBinsDiscretizer(n_bins=n_bins)

y = df[target]
X = df[variables]

est.fit(X)

# %%
t0 = time.time()
df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 'N_bins', 'Bin_method'])
for i in range(n_iter):
    tp0 = time.time()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)#, stratify=df[target])
    
    Xt_train = est.transform(X_train)
    m.fit(Xt_train, y_train)
    y_prob = m.predict_proba(Xt_train)[:,1]
    fpr, tpr, _ = roc_curve(y_train, y_prob) 
    g_train = (2 * auc(fpr, tpr) - 1)

    Xt_test = est.transform(X_test)
    m.fit(Xt_test, y_test)
    y_prob = m.predict_proba(Xt_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_prob) 
    g_test = (2 * auc(fpr, tpr) - 1)    
    t = round((time.time() - tp0), 2)
    if verbose:
        print(f'Train gini {g_train}; Test gini {g_test}')
        print(f'Run time for round {i+1} is {t} sec')
        print('')
    df_result.loc[i, 'Bin_method'] = est
    df_result.loc[i, 'Gini_train'] = g_train
    df_result.loc[i, 'Gini_test'] = g_test
    df_result.loc[i, 'Run_time'] = t  
    df_result.loc[i, 'N_bins'] = n_bins
    
df_result.loc['MEAN']= df_result[['Gini_train', 'Gini_test', 'Run_time']].mean()
df_result.loc['STD']= df_result[['Gini_train', 'Gini_test', 'Run_time']].std()
t = time.time()-t0
print(f'Run time is {t} sec')

# %%
plot_results(df_result, 'Gini_train', est)

# %%
plot_results(df_result, 'Gini_test', est)

# %% [markdown]
# ## woe transformed binning (n_bins = 10)

# %%
parameter_space = ['1']
result_dict = {} # contains all the df_result tables
for n_param, parameter in enumerate(parameter_space): 
    tpar0=time.time()
    #bin_method=OptimalBinning(prebinning_method=parameter)
    #bin_method = MDLP(min_samples_split=2, min_samples_leaf=10000, max_candidates=32)
    n_bins = 10
    bin_method=KBinsDiscretizer(n_bins=n_bins)
    n_iter = 50
    verbose = False
    model = LogisticRegression()
    ed = get_edges_dict(df, variables, target, verbose=False, bin_method=bin_method)
    df_woe = var_list_woe(df, df, variables, target, ed, verbose=False)
    df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 
                                      'N_bins', 'Bin_method', 'N_iter'])
    for i in range(n_iter):
        dfw_train, dfw_test = train_test_split(df_woe, test_size=0.30)#, stratify=df[target])
        #fit the model on train set
        X = dfw_train.iloc[:, 1:].to_numpy()
        y = dfw_train.iloc[:, 0].values
        model.fit(X, y)
        g_train = round(check_model(model, X, y), 4)
        # now test the model on test_set
        X = dfw_test.iloc[:, 1:].to_numpy()
        y = dfw_test.iloc[:, 0].values
        g_test = round(check_model(model, X, y), 4)
        df_result.loc[i, 'Bin_method'] = bin_method  
        df_result.loc[i, 'Gini_train'] = g_train
        df_result.loc[i, 'Gini_test'] = g_test
        df_result.loc[i, 'Run_time'] = t  
        df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
        df_result.loc[i, 'N_iter'] = n_iter          
    df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].mean(), 4)
    df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].std(), 4)
    t = round((time.time() - tpar0), 2)
    print(f'Run time for parameter {parameter} is {t} sec.')
    result_dict[parameter] = df_result

# %%
plot_results(df_result, 'Gini_train', bin_method)

# %%
plot_results(df_result, 'Gini_test', bin_method)

# %% [markdown]
# # Unsupervized methods exploration
# - n-bins
# - method
# - !!! recalculate it as there was a bag in plot_cycle_results

# %%
df = prepare_df(d0)

# %%
parameter_space_1 = [2, 3, 4, 6, 8, 10, 12, 15, 20, 30, 40, 50]
parameter_space_2 = ['uniform', 'quantile', 'kmeans']# 2, 3, 5 ,7, 10, 12, 15]
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        #bin_method=OptimalBinning(prebinning_method=parameter)
        #bin_method = MDLP(min_samples_split=2, min_samples_leaf=10000, max_candidates=32)
        n_bins = parameter_1
        bin_method=KBinsDiscretizer(n_bins=n_bins, strategy=parameter_2)
        n_iter = 50
        verbose = False
        model = LogisticRegression()
        ed = get_edges_dict(df, variables, target, verbose=False, bin_method=bin_method)
        df_woe = var_list_woe(df, df, variables, target, ed, verbose=False)
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 'Run_time', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            dfw_train, dfw_test = train_test_split(df_woe, test_size=0.30)#, stratify=df[target])
            #fit the model on train set
            X = dfw_train.iloc[:, 1:].to_numpy()
            y = dfw_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = dfw_test.iloc[:, 1:].to_numpy()
            y = dfw_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'Run_time'] = t  
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test', 'Run_time']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = df_result
    result_dict_1[parameter_1] = result_dict_2

# %%
#save_obj(result_dict_1, "result_dict_unsuperv")
tmp = load_obj('result_dict_unsuperv')
parameter_space_1 = [2, 3, 4, 6, 8, 10, 12, 15, 20, 30, 40, 50]
parameter_space_2 = ['uniform', 'quantile', 'kmeans']# 2, 3, 5 ,7, 10, 12, 15]

# %%
# plots the bins
col_to_binplot = parameter_space_2
second_param_name = 'N_bins'
second_param_val = 50

df_report_train = pd.DataFrame(columns=col_to_binplot) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=col_to_binplot) # parameter to plot cycle result

for parameter_1 in parameter_space_1:
    for parameter_2 in col_to_binplot:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2].loc['MEAN', 'Gini_test']
       
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 

display(df_report_train)
d = pd.DataFrame({'g_train': df_report_train.loc[second_param_val, :], 
                    "g_test": df_report_test.loc[second_param_val, :]})
plot_cycle_results(d, f'KBinsDiscretizer(n_bins={second_param_val})', 50)

# %%
plt.figure(figsize = (12,12))
df_report_train.plot()
#plt.plot(df_report.index, df_report.uniform)
plt.title('Gini train vs. number of bins')
plt.ylabel('Gini train')
plt.show()

# %%
df_report_time = pd.DataFrame(columns=parameter_space_1)
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_time.loc[parameter_2, parameter_1] = tmp[parameter_1][parameter_2].loc['MEAN', 'Run_time']
df_report_time.index.rename('N_bins', inplace = True)    
df_report_time

# %%
df_report_test = pd.DataFrame(columns=parameter_space_1)
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_test.loc[parameter_2, parameter_1] = tmp[parameter_1][parameter_2].loc['MEAN', 'Gini_test']
df_report_test.index.rename('N_bins', inplace = True)    
df_report_test

# %%
df_report_test_error = pd.DataFrame(columns=parameter_space_1)
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        g_test = tmp[parameter_1][parameter_2].loc['MEAN', 'Gini_test']
        g_test_std = tmpp[parameter_1][parameter_2].loc['STD', 'Gini_test']
        df_report_test_error.loc[parameter_2, parameter_1] = round(g_test_std/ g_test, 3)
df_report_test_error.index.rename('N_bins', inplace = True)    
df_report_test_error

# %% [markdown]
# # OptBinning exploration NEW

# %% [markdown]
# ## Exp_1 p_val

# %%
df = prepare_df(d0, remove_outl=True, remove_na=True)
# Out:
# df initial shape: (307511, 4)
#
# df shape after processing missing values: (202044, 4)
#
# N outliers in DAYS_EMPLOYED: 10203,            df shape after outlier removal: (191841, 4)
# N outliers in AMT_GOODS_PRICE: 2980,            df shape after outlier removal: (188861, 4)
# N outliers in EXT_SOURCE_3: 0,            df shape after outlier removal: (188861, 4)
#
# final df shape: (188861, 4)

# %%
max_iter = 100
max_n_prebins = 2048
n_iter = 11
inf_repl = 100
parameter_space_1 = [0.5, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.00001] # p_val
parameter_space_2 = ['iv', 'js', 'hellinger',] # divergence
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method=OptimalBinning(divergence=parameter_2, max_pvalue = parameter_1,
                                 max_n_prebins=max_n_prebins)
        n_iter = n_iter
        verbose = False
        model = LogisticRegression(max_iter=max_iter)     
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2

# %%
fn = "OptBin_results_exp_1" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
parameter_space_1 = [0.5, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.00001]
parameter_space_2 = ['iv', 'js', 'hellinger',]

# %%
second_param_name = 'p-val'
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 

display(df_report_train)
display(df_report_test)
display(df_report_bins)
# Out:
#              iv      js hellinger
# p-val
# 0.50000   0.387  0.3862    0.3863
# 0.10000  0.3849  0.3865    0.3871
# 0.05000  0.3853  0.3864    0.3862
# 0.01000  0.3837  0.3843     0.385
# 0.00100  0.3829  0.3848    0.3844
# 0.00010  0.3853  0.3818    0.3829
# 0.00001  0.3812  0.3811    0.3814
#              iv      js hellinger
# p-val
# 0.50000  0.3787  0.3806    0.3806
# 0.10000  0.3827  0.3792    0.3782
# 0.05000  0.3819  0.3785    0.3795
# 0.01000  0.3838   0.382    0.3808
# 0.00100  0.3827  0.3796    0.3793
# 0.00010  0.3731  0.3826    0.3789
# 0.00001  0.3782  0.3777    0.3773
#                  iv          js   hellinger
# p-val
# 0.50000  [9, 9, 12]  [9, 9, 13]  [9, 9, 12]
# 0.10000  [7, 8, 11]  [7, 8, 11]  [6, 8, 11]
# 0.05000  [6, 8, 10]  [6, 8, 11]  [6, 8, 10]
# 0.01000   [6, 7, 8]   [6, 7, 8]   [5, 7, 8]
# 0.00100   [4, 7, 8]   [4, 7, 8]   [4, 7, 8]
# 0.00010   [4, 6, 8]   [4, 7, 8]   [4, 7, 7]
# 0.00001   [3, 7, 6]   [4, 6, 8]   [3, 6, 7]

# %%
df_tmp.min().min()

# %%
df_tmp = df_report_train
plt.figure(figsize=(3,5))
sns.set(style= "whitegrid")
x = np.log(df_tmp.index.values)
y = df_tmp
plt.ylim(y.min().min()*0.93, y.max().max()*1.04)
plt.xlabel('ln p-val')
plt.ylabel('Gini scoring')
plt.title('Train sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='divergence')
plt.show()

# %%
df_tmp = df_report_test
sns.set(style= "whitegrid")
plt.figure(figsize=(3,5))
x = np.log(df_tmp.index.values)
y = df_tmp
plt.ylim(y.min().min()*0.93, y.max().max()*1.04)
plt.xlabel('ln p-val')
plt.ylabel('Gini scoring')
plt.title('Test sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='divergence')
plt.show()

# %%
#tmp[0.001]['iv'][1]['DAYS_EMPLOYED'].plot() does not work with this pickle file/ tmp

# %%
tmp[0.001]['iv'][1]['DAYS_EMPLOYED'].build()

# %%
tmp[0.5]['iv'][1]['DAYS_EMPLOYED'].plot()

# %%
tmp[0.5]['iv'][1]['DAYS_EMPLOYED'].build()

# %% [markdown]
# ## Exp 2 min_bin_n_event

# %%
max_iter = 100
max_n_prebins = 2048
n_iter = 11
inf_repl = 100
n_target = df.TARGET.sum()
divergence='iv'
parameter_space_1 = [0.5, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.00001] # p_val
parameter_space_2 = [0.01, 0.02, 0.1, 1, 5, 10, 25] # min % of targets per bin min_bin_n_event
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method=OptimalBinning(divergence=divergence, max_pvalue = parameter_1,
                                 max_n_prebins=max_n_prebins, min_bin_n_event=int(parameter_2*n_target/100))
        n_iter = n_iter
        verbose = False
        model = LogisticRegression(max_iter=max_iter)     
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2

# %%
# let's check p-val
X = sm.add_constant(df_woe_train.iloc[:, 1:].to_numpy())
y = df_woe_train.iloc[:, 0].values
log_reg = sm.Logit(y, X).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.274164
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               132202
# Model:                          Logit   Df Residuals:                   132198
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 17 Nov 2021   Pseudo R-squ.:                 0.06268
# Time:                        09:21:34   Log-Likelihood:                -36245.
# converged:                       True   LL-Null:                       -38669.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3671      0.010   -228.093      0.000      -2.387      -2.347
# x1            -0.7103      0.039    -18.296      0.000      -0.786      -0.634
# x2            -0.7747      0.037    -21.184      0.000      -0.846      -0.703
# x3            -0.9371      0.016    -59.120      0.000      -0.968      -0.906
# ==============================================================================

# %%
# let's check p-val
X = df_woe_train.iloc[:, 1:].to_numpy()
y = df_woe_train.iloc[:, 0].values
log_reg = sm.Logit(y, X).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.636101
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               132202
# Model:                          Logit   Df Residuals:                   132199
# Method:                           MLE   Df Model:                            2
# Date:                Wed, 17 Nov 2021   Pseudo R-squ.:                  -1.175
# Time:                        09:17:36   Log-Likelihood:                -84094.
# converged:                       True   LL-Null:                       -38669.
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.6717      0.021    -31.845      0.000      -0.713      -0.630
# x2            -0.7856      0.022    -36.453      0.000      -0.828      -0.743
# x3            -1.0236      0.010    -99.503      0.000      -1.044      -1.003
# ==============================================================================

# %%
model.coef_

# %%
X = df_woe_test.iloc[:, 1:].to_numpy()
y = df_woe_test.iloc[:, 0].values
log_reg = sm.Logit(y, X).fit()
print(log_reg.summary())

# %%
fn = "OptBin_results_exp_2" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
parameter_space_1 = [0.5, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.00001] # p_val
parameter_space_2 = [0.01, 0.02, 0.1, 1, 5, 10, 25] # % of targets min_bin_n_event

# %%
second_param_name = 'p-val'
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 
display(df_report_train)
display(df_report_test)
display(df_report_bins)

# %%
df_tmp = df_report_train
plt.figure(figsize=(4,6))
sns.set(style= "whitegrid")
x = np.log(df_tmp.index.values)
y = df_tmp
plt.ylim(y.min().min()*0.97, y.max().max()*1.02)
plt.xlabel('ln p-val')
plt.ylabel('Gini scoring')
plt.title('Train sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='min % of targets per bin')
plt.show()

# %%
df_tmp = df_report_test
#plt.style.use('default') 
sns.set(style= "whitegrid")
plt.figure(figsize=(4,6))
x = np.log(df_tmp.index.values)
y = df_tmp
plt.ylim(y.min().min()*0.97, y.max().max()*1.02)
plt.xlabel('ln p-val')
plt.ylabel('Gini scoring')
plt.title('Test sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='min % of targets per bin')
plt.show()

# %%
#tmp[0.001]['iv'][1]['DAYS_EMPLOYED'].plot()

# %%
tmp[0.001][0.1][1]['DAYS_EMPLOYED'].plot()

# %%
tmp[0.5]['iv'][1]['DAYS_EMPLOYED'].plot()

# %%
tmp[0.5]['iv'][1]['DAYS_EMPLOYED'].build()

# %% [markdown]
# # CART exploration NEW

# %%
df = prepare_df(d0)
# Out:
# df initial shape: (202044, 4)
#
# N outliers in DAYS_EMPLOYED: 10203,        df shape after outlier removal: (191841, 4)
# N outliers in AMT_GOODS_PRICE: 2980,        df shape after outlier removal: (188861, 4)
# N outliers in EXT_SOURCE_3: 0,        df shape after outlier removal: (188861, 4)
#
# df shape: (188861, 4)

# %% [markdown]
# ## Exp_1

# %%
msl = 100 # min_samples_leaf
max_iter = 100
inf_repl = 100
parameter_space_1 = [0, 10**-6, 10**-5, 10**-4, 0.001, 0.005, 0.01] #alpha
parameter_space_2 = [2**i for i in range(1, 12)] #max leaf nodes
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method = CART(max_leaf_nodes=parameter_2, ccp_alpha = parameter_1, 
                          criterion = 'entropy', min_samples_leaf=msl)
        n_iter = 5
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2

# %%
fn = "CART_results_exp_1_msl_100" #min samples leaf
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
# min_samples_leaf=100 (also try 500 and 100)
parameter_space_1 = [0, 10**-6, 10**-5, 10**-4, 0.001, 0.005, 0.01] #alpha
parameter_space_2 = [2**i for i in range(1, 12)] #max leaf nodes

# %%
tmp
# Out:
# {0: {2: (     Gini_train Gini_test     N_bins  \
#    0        0.3171    0.3196  [2, 2, 2]
#    1         0.321    0.3098  [2, 2, 2]
#    2        0.3136    0.3239  [2, 2, 2]
#    3        0.3179    0.3179  [2, 2, 2]
#    4        0.3245    0.3025  [2, 2, 2]
#    MEAN     0.3188    0.3147        NaN
#    STD      0.0037    0.0076        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9dbe7130>      5
#    1     <__main__.CART object at 0x7fde9dbe7130>      5
#    2     <__main__.CART object at 0x7fde9dbe7130>      5
#    3     <__main__.CART object at 0x7fde9dbe7130>      5
#    4     <__main__.CART object at 0x7fde9dbe7130>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                    Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, -2050.5]   53512.0      40.48    50167.0   3345.0   0.062509
#     1       (-2050.5, inf]   78690.0      59.52    70666.0   8024.0    0.10197
#     Total              NaN  132202.0     100.00   120833.0  11369.0
#
#                 WoE        IV   Gini
#     0      0.344372  0.041654
#     1     -0.187992  0.022739
#     Total            0.064392  0.121  ,
#     'AMT_GOODS_PRICE':                     Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 677889.0]   96334.0      72.87    87116.0   9218.0   0.095688
#     1       (677889.0, inf]   35868.0      27.13    33717.0   2151.0    0.05997
#     Total               NaN  132202.0     100.00   120833.0  11369.0
#
#                 WoE        IV    Gini
#     0     -0.117437  0.010550
#     1       0.38855  0.034907
#     Total            0.045458  0.0898  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31524.0      23.85    26212.0   5312.0   0.168507
#     1       (0.343, inf]  100678.0      76.15    94621.0   6057.0   0.060162
#     Total            NaN  132202.0     100.00   120833.0  11369.0
#
#                 WoE        IV    Gini
#     0      -0.76727  0.192054
#     1      0.385146  0.096405
#     Total            0.288459  0.2503  },
#    21.89),
#   4: (     Gini_train Gini_test     N_bins  \
#    0        0.3769    0.3595  [4, 4, 4]
#    1        0.3709    0.3695  [4, 4, 4]
#    2         0.375    0.3502  [4, 4, 4]
#    3        0.3695    0.3607  [4, 4, 4]
#    4        0.3691    0.3732  [4, 4, 4]
#    MEAN     0.3723    0.3626        NaN
#    STD      0.0031    0.0081        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde899f6c40>      5
#    1     <__main__.CART object at 0x7fde899f6c40>      5
#    2     <__main__.CART object at 0x7fde899f6c40>      5
#    3     <__main__.CART object at 0x7fde899f6c40>      5
#    4     <__main__.CART object at 0x7fde899f6c40>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -3923.5]   19455.0      14.72    18447.0   1008.0   0.051812
#     1      (-3923.5, -1901.5]   37701.0      28.52    34996.0   2705.0   0.071749
#     2      (-1901.5, -1028.5]   30473.0      23.05    27616.0   2857.0   0.093755
#     3          (-1028.5, inf]   44573.0      33.72    39612.0   4961.0   0.111301
#     Total                 NaN  132202.0     100.01   120671.0  11531.0
#
#                 WoE        IV    Gini
#     0      0.558905  0.036582
#     1      0.212103  0.011756
#     2     -0.079406  0.001502
#     3     -0.270504  0.027583
#     Total            0.077423  0.1485  ,
#     'AMT_GOODS_PRICE':                          Bin     Count  Count (%)  Non_event    Event  \
#     0          (-inf, 282197.25]   40977.0      31.00    37437.0   3540.0
#     1      (282197.25, 451732.5]   26586.0      20.11    23252.0   3334.0
#     2      (451732.5, 677441.25]   29060.0      21.98    26614.0   2446.0
#     3           (677441.25, inf]   35579.0      26.91    33368.0   2211.0
#     Total                    NaN  132202.0     100.00   120671.0  11531.0
#
#           Event_rate       WoE        IV    Gini
#     0        0.08639  0.010504  0.000034
#     1       0.125404  -0.40581  0.039138
#     2       0.084171  0.038955  0.000328
#     3       0.062143  0.366124  0.031039
#     Total                       0.070539  0.1401  ,
#     'EXT_SOURCE_3':                   Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0       (-inf, 0.149]    6948.0       5.26     5240.0   1708.0   0.245826
#     1      (0.149, 0.343]   24639.0      18.64    21032.0   3607.0   0.146394
#     2      (0.343, 0.502]   30938.0      23.40    28160.0   2778.0   0.089792
#     3        (0.502, inf]   69677.0      52.70    66239.0   3438.0   0.049342
#     Total             NaN  132202.0     100.00   120671.0  11531.0
#
#                 WoE        IV    Gini
#     0      -1.22703  0.128468
#     1      -0.58486  0.081013
#     2     -0.031857  0.000241
#     3      0.610351  0.153057
#     Total            0.362779  0.3181  },
#    22.06),
#   8: (     Gini_train Gini_test     N_bins  \
#    0        0.3832    0.3859  [8, 8, 8]
#    1        0.3869    0.3829  [8, 8, 8]
#    2        0.3885     0.381  [8, 8, 8]
#    3        0.3874    0.3801  [8, 8, 8]
#    4        0.3825    0.3839  [8, 8, 8]
#    MEAN     0.3857    0.3828        NaN
#    STD      0.0024    0.0021        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9d186160>      5
#    1     <__main__.CART object at 0x7fde9d186160>      5
#    2     <__main__.CART object at 0x7fde9d186160>      5
#    3     <__main__.CART object at 0x7fde9d186160>      5
#    4     <__main__.CART object at 0x7fde9d186160>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -4244.5]   16352.0      12.37    15537.0    815.0   0.049841
#     1      (-4244.5, -4214.5]     286.0       0.22      282.0      4.0   0.013986
#     2      (-4214.5, -3220.5]   12333.0       9.33    11584.0    749.0   0.060731
#     3      (-3220.5, -3212.5]     115.0       0.09      114.0      1.0   0.008696
#     4      (-3212.5, -2430.5]   15370.0      11.63    14262.0   1108.0   0.072088
#     5      (-2430.5, -1789.5]   15868.0      12.00    14582.0   1286.0   0.081044
#     6      (-1789.5, -1004.5]   28224.0      21.35    25580.0   2644.0   0.093679
#     7          (-1004.5, inf]   43654.0      33.02    38829.0   4825.0   0.110528
#     Total                 NaN  132202.0     100.01   120770.0  11432.0
#
#                 WoE        IV    Gini
#     0       0.59032  0.033860
#     1      1.898141  0.003768
#     2       0.38117  0.011588
#     3      2.378727  0.002037
#     4      0.197571  0.004183
#     5       0.07078  0.000584
#     6     -0.087954  0.001713
#     7     -0.272115  0.027361
#     Total            0.085093  0.1535  ,
#     'AMT_GOODS_PRICE':                          Bin     Count  Count (%)  Non_event    Event  \
#     0           (-inf, 158283.0]   10629.0       8.04     9871.0    758.0
#     1      (158283.0, 344049.75]   37304.0      28.22    33827.0   3477.0
#     2      (344049.75, 418486.5]    5845.0       4.42     5180.0    665.0
#     3       (418486.5, 451732.5]   13870.0      10.49    11902.0   1968.0
#     4       (451732.5, 677889.0]   28864.0      21.83    26508.0   2356.0
#     5       (677889.0, 902371.5]   18350.0      13.88    17081.0   1269.0
#     6      (902371.5, 1325250.0]   12454.0       9.42    11706.0    748.0
#     7           (1325250.0, inf]    4886.0       3.70     4695.0    191.0
#     Total                    NaN  132202.0     100.00   120770.0  11432.0
#
#           Event_rate       WoE        IV    Gini
#     0       0.071314  0.209202  0.003228
#     1       0.093207 -0.082382  0.001981
#     2       0.113772 -0.304698  0.004655
#     3       0.141889 -0.557783  0.041051
#     4       0.081624   0.06301  0.000845
#     5       0.069155  0.242266  0.007372
#     6       0.060061  0.392982  0.012378
#     7       0.039091  0.844508  0.018721
#     Total                       0.090232  0.1601  ,
#     'EXT_SOURCE_3':                    Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0       (-inf, 0.0929]    2811.0       2.13     2020.0    791.0   0.281395
#     1      (0.0929, 0.163]    5349.0       4.05     4212.0   1137.0   0.212563
#     2       (0.163, 0.266]   11464.0       8.67     9603.0   1861.0   0.162334
#     3       (0.266, 0.343]   11921.0       9.02    10462.0   1459.0   0.122389
#     4       (0.343, 0.436]   17228.0      13.03    15554.0   1674.0   0.097167
#     5       (0.436, 0.506]   14583.0      11.03    13434.0   1149.0    0.07879
#     6       (0.506, 0.702]   47022.0      35.57    44472.0   2550.0    0.05423
#     7         (0.702, inf]   21824.0      16.51    21013.0    811.0   0.037161
#     Total              NaN  132202.0     100.01   120770.0  11432.0
#
#                 WoE        IV    Gini
#     0     -1.419917  0.074497
#     1     -1.047927  0.067677
#     2      -0.71651  0.059667
#     3     -0.387473  0.015885
#     4      -0.12837  0.002265
#     5      0.101425  0.001088
#     6      0.501295  0.072778
#     7      0.897157  0.092453
#     Total            0.386308  0.3384  },
#    21.09),
#   16: (     Gini_train Gini_test        N_bins  \
#    0        0.3911    0.3924  [16, 16, 16]
#    1        0.3912    0.3877  [16, 16, 16]
#    2        0.3953    0.3774  [16, 16, 16]
#    3        0.3934    0.3839  [16, 16, 16]
#    4         0.393    0.3872  [16, 16, 16]
#    MEAN     0.3928    0.3857           NaN
#    STD      0.0016     0.005           NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde899ef250>      5
#    1     <__main__.CART object at 0x7fde899ef250>      5
#    2     <__main__.CART object at 0x7fde899ef250>      5
#    3     <__main__.CART object at 0x7fde899ef250>      5
#    4     <__main__.CART object at 0x7fde899ef250>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -6647.0]    2452.0       1.85     2350.0    102.0   0.041599
#     1      (-6647.0, -6611.5]     109.0       0.08      109.0      0.0        0.0
#     2      (-6611.5, -4779.5]    9230.0       6.98     8726.0    504.0   0.054605
#     3      (-4779.5, -4718.5]     510.0       0.39      496.0     14.0   0.027451
#     4      (-4718.5, -4703.5]     131.0       0.10      131.0      0.0        0.0
#     5      (-4703.5, -4684.5]     136.0       0.10      124.0     12.0   0.088235
#     6      (-4684.5, -4566.5]    1020.0       0.77      980.0     40.0   0.039216
#     7      (-4566.5, -4544.5]     183.0       0.14      163.0     20.0    0.10929
#     8      (-4544.5, -3075.5]   17733.0      13.41    16635.0   1098.0   0.061918
#     9      (-3075.5, -2469.5]   12230.0       9.25    11344.0    886.0   0.072445
#     10     (-2469.5, -2449.5]     407.0       0.31      390.0     17.0   0.041769
#     11     (-2449.5, -1836.5]   14933.0      11.30    13712.0   1221.0   0.081765
#     12     (-1836.5, -1775.5]    1818.0       1.38     1703.0    115.0   0.063256
#     13     (-1775.5, -1771.5]     108.0       0.08       89.0     19.0   0.175926
#     14      (-1771.5, -868.5]   33479.0      25.32    30267.0   3212.0   0.095941
#     15          (-868.5, inf]   37723.0      28.53    33546.0   4177.0   0.110728
#     Total                 NaN  132202.0      99.99   120765.0  11437.0
#
#                 WoE            IV    Gini
#     0      0.780205  8.224030e-03
#     1           inf           inf
#     2      0.494493  1.393904e-02
#     3      1.210526  3.490010e-03
#     4           inf           inf
#     5     -0.021618  4.850756e-07
#     6       0.84168  3.886470e-03
#     7     -0.258975  1.033262e-04
#     8      0.361026  1.507018e-02
#     9      0.192735  3.173688e-03
#     10     0.775941  1.352471e-03
#     11     0.061608  4.179552e-04
#     12     0.338222  1.368676e-03
#     13    -0.812795  7.512719e-04
#     14    -0.113829  3.439402e-03
#     15    -0.273668  2.392929e-02
#     Total                     inf  0.1513  ,
#     'AMT_GOODS_PRICE':                           Bin     Count  Count (%)  Non_event    Event  \
#     0            (-inf, 158283.0]   10656.0       8.06     9892.0    764.0
#     1        (158283.0, 177750.0]     644.0       0.49      561.0     83.0
#     2        (177750.0, 204750.0]    6790.0       5.14     6202.0    588.0
#     3        (204750.0, 231750.0]   11302.0       8.55    10103.0   1199.0
#     4       (231750.0, 282197.25]   11668.0       8.83    10774.0    894.0
#     5      (282197.25, 385017.75]   10626.0       8.04     9523.0   1103.0
#     6       (385017.75, 398250.0]     444.0       0.34      363.0     81.0
#     7        (398250.0, 407362.5]    1443.0       1.09     1301.0    142.0
#     8        (407362.5, 452250.0]   14014.0      10.60    12059.0   1955.0
#     9        (452250.0, 472225.5]    6042.0       4.57     5665.0    377.0
#     10       (472225.5, 593226.0]    9322.0       7.05     8585.0    737.0
#     11      (593226.0, 677441.25]   13651.0      10.33    12321.0   1330.0
#     12     (677441.25, 686918.25]    2546.0       1.93     2443.0    103.0
#     13      (686918.25, 902371.5]   15795.0      11.95    14685.0   1110.0
#     14      (902371.5, 1265125.5]   11905.0       9.01    11174.0    731.0
#     15           (1265125.5, inf]    5354.0       4.05     5114.0    240.0
#     Total                     NaN  132202.0     100.03   120765.0  11437.0
#
#           Event_rate       WoE            IV    Gini
#     0       0.071697  0.203921  3.081332e-03
#     1       0.128882 -0.446112  1.165140e-03
#     2       0.086598 -0.001093  6.134574e-08
#     3       0.106087 -0.225648  4.778517e-03
#     4        0.07662  0.132193  1.460362e-03
#     5       0.103802 -0.201317  3.540303e-03
#     6       0.182432 -0.857039  3.493668e-03
#     7       0.098406 -0.141931  2.331726e-04
#     8       0.139503 -0.537572  3.821132e-02
#     9       0.062397  0.352824  4.920520e-03
#     10       0.07906  0.098191  6.528236e-04
#     11      0.097429 -0.130867  1.866766e-03
#     12      0.040456   0.80926  9.082743e-03
#     13      0.070275  0.225474  5.534564e-03
#     14      0.061403  0.369939  1.058448e-02
#     15      0.044826  0.702105  1.499850e-02
#     Total                       1.036043e-01  0.1779  ,
#     'EXT_SOURCE_3':                      Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0        (-inf, 0.00594]     470.0       0.36      387.0     83.0   0.176596
#     1      (0.00594, 0.0491]     443.0       0.34      248.0    195.0   0.440181
#     2       (0.0491, 0.0809]    1346.0       1.02      965.0    381.0   0.283061
#     3        (0.0809, 0.149]    4664.0       3.53     3606.0   1058.0   0.226844
#     4         (0.149, 0.159]     893.0       0.68      738.0    155.0   0.173572
#     5         (0.159, 0.167]     707.0       0.53      546.0    161.0   0.227723
#     6         (0.167, 0.241]    8017.0       6.06     6663.0   1354.0   0.168891
#     7         (0.241, 0.262]    2589.0       1.96     2216.0    373.0   0.144071
#     8         (0.262, 0.343]   12496.0       9.45    10947.0   1549.0    0.12396
#     9          (0.343, 0.47]   24154.0      18.27    21917.0   2237.0   0.092614
#     10         (0.47, 0.493]    5023.0       3.80     4672.0    351.0   0.069879
#     11        (0.493, 0.495]     337.0       0.25      299.0     38.0    0.11276
#     12        (0.495, 0.572]   17332.0      13.11    16234.0   1098.0   0.063351
#     13        (0.572, 0.622]   12363.0       9.35    11696.0    667.0   0.053951
#     14        (0.622, 0.704]   19763.0      14.95    18835.0    928.0   0.046956
#     15          (0.704, inf]   21605.0      16.34    20796.0    809.0   0.037445
#     Total                NaN  132202.0     100.00   120765.0  11437.0
#
#                 WoE        IV    Gini
#     0     -0.817409  0.003313
#     1     -2.116564  0.031741
#     2     -1.427664  0.036152
#     3     -1.130774  0.070840
#     4     -0.796474  0.005927
#     5     -1.135778  0.010853
#     6     -0.763486  0.048263
#     7     -0.575112  0.008203
#     8     -0.401537  0.017985
#     9     -0.074866  0.001056
#     10     0.231564  0.001852
#     11    -0.294135  0.000249
#     12     0.336625  0.012934
#     13     0.507219  0.019543
#     14     0.653448  0.048893
#     15     0.889724  0.090278
#     Total            0.408082  0.3478  },
#    21.01),
#   32: (     Gini_train Gini_test        N_bins  \
#    0        0.3978    0.3899  [32, 32, 32]
#    1        0.3974    0.3913  [32, 32, 32]
#    2        0.4054     0.372  [32, 32, 32]
#    3        0.3988     0.382  [32, 32, 32]
#    4        0.3957    0.3925  [32, 32, 32]
#    MEAN      0.399    0.3855           NaN
#    STD      0.0033    0.0077           NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9d40f7f0>      5
#    1     <__main__.CART object at 0x7fde9d40f7f0>      5
#    2     <__main__.CART object at 0x7fde9d40f7f0>      5
#    3     <__main__.CART object at 0x7fde9d40f7f0>      5
#    4     <__main__.CART object at 0x7fde9d40f7f0>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -5971.5]    4744.0       3.59     4530.0    214.0    0.04511
#     1      (-5971.5, -5920.5]     217.0       0.16      213.0      4.0   0.018433
#     2      (-5920.5, -5892.5]     115.0       0.09      103.0     12.0   0.104348
#     3      (-5892.5, -4684.5]    7563.0       5.72     7163.0    400.0   0.052889
#     4      (-4684.5, -4654.5]     220.0       0.17      218.0      2.0   0.009091
#     5      (-4654.5, -3075.5]   18777.0      14.20    17640.0   1137.0   0.060553
#     6      (-3075.5, -3061.5]     232.0       0.18      205.0     27.0   0.116379
#     7      (-3061.5, -2541.5]   10328.0       7.81     9553.0    775.0   0.075039
#     8      (-2541.5, -2522.5]     442.0       0.33      426.0     16.0   0.036199
#     9      (-2522.5, -2471.5]    1049.0       0.79      972.0     77.0   0.073403
#     10     (-2471.5, -2455.5]     341.0       0.26      330.0     11.0   0.032258
#     11     (-2455.5, -2430.5]     565.0       0.43      531.0     34.0   0.060177
#     12     (-2430.5, -2395.5]     829.0       0.63      746.0     83.0   0.100121
#     13     (-2395.5, -2391.5]     121.0       0.09      117.0      4.0   0.033058
#     14     (-2391.5, -1728.5]   16660.0      12.60    15340.0   1320.0   0.079232
#     15     (-1728.5, -1664.5]    2152.0       1.63     1924.0    228.0   0.105948
#     16     (-1664.5, -1484.5]    6046.0       4.57     5540.0    506.0   0.083692
#     17     (-1484.5, -1481.5]     108.0       0.08      106.0      2.0   0.018519
#     18     (-1481.5, -1450.5]    1081.0       0.82      952.0    129.0   0.119334
#     19     (-1450.5, -1443.5]     234.0       0.18      221.0     13.0   0.055556
#     20      (-1443.5, -880.5]   22192.0      16.79    20009.0   2183.0   0.098369
#     21       (-880.5, -521.5]   15957.0      12.07    14153.0   1804.0   0.113054
#     22       (-521.5, -518.5]     128.0       0.10      122.0      6.0   0.046875
#     23       (-518.5, -494.5]    1094.0       0.83      984.0    110.0   0.100548
#     24       (-494.5, -392.5]    4843.0       3.66     4233.0    610.0   0.125955
#     25       (-392.5, -337.5]    2781.0       2.10     2529.0    252.0   0.090615
#     26       (-337.5, -324.5]     553.0       0.42      466.0     87.0   0.157324
#     27       (-324.5, -317.5]     343.0       0.26      304.0     39.0   0.113703
#     28       (-317.5, -312.5]     248.0       0.19      237.0     11.0   0.044355
#     29       (-312.5, -148.5]    8886.0       6.72     7905.0    981.0   0.110398
#     30       (-148.5, -140.5]     406.0       0.31      345.0     61.0   0.150246
#     31          (-140.5, inf]    2947.0       2.23     2657.0    290.0   0.098405
#     Total                 NaN  132202.0     100.01   120774.0  11428.0
#
#                 WoE        IV    Gini
#     0      0.694647  0.013047
#     1      1.617143  0.002286
#     2     -0.208032  0.000041
#     3      0.527365  0.012819
#     4      2.333493  0.003804
#     5      0.383921  0.017877
#     6     -0.330681  0.000220
#     7      0.153893  0.001736
#     8      0.923996  0.001966
#     9      0.177696  0.000233
#     10     1.043343  0.001847
#     11     0.390547  0.000555
#     12     -0.16197  0.000176
#     13     1.018025  0.000630
#     14     0.094978  0.001093
#     15    -0.225039  0.000905
#     16     0.035359  0.000056
#     17     1.612437  0.001133
#     18    -0.359102  0.001223
#     19     0.475359  0.000329
#     20    -0.142372  0.003609
#     21    -0.297934  0.012118
#     22     0.654407  0.000317
#     23    -0.166709  0.000246
#     24    -0.420647  0.007710
#     25    -0.051704  0.000057
#     26    -0.679577  0.002551
#     27    -0.304388  0.000273
#     28      0.71231  0.000712
#     29    -0.271176  0.005529
#     30    -0.625184  0.001551
#     31    -0.142783  0.000482
#     Total            0.097132  0.1679  ,
#     'AMT_GOODS_PRICE':                           Bin     Count  Count (%)  Non_event    Event  \
#     0             (-inf, 67446.0]     790.0       0.60      754.0     36.0
#     1         (67446.0, 158283.0]    9811.0       7.42     9070.0    741.0
#     2        (158283.0, 177750.0]     631.0       0.48      552.0     79.0
#     3       (177750.0, 191067.75]    4886.0       3.70     4443.0    443.0
#     4       (191067.75, 206266.5]    1824.0       1.38     1695.0    129.0
#     5        (206266.5, 222750.0]     482.0       0.36      419.0     63.0
#     6        (222750.0, 227250.0]    9798.0       7.41     8757.0   1041.0
#     7       (227250.0, 243717.75]    3734.0       2.82     3420.0    314.0
#     8       (243717.75, 249750.0]    1773.0       1.34     1651.0    122.0
#     9       (249750.0, 266960.25]    1300.0       0.98     1146.0    154.0
#     10      (266960.25, 272250.0]    5459.0       4.13     5055.0    404.0
#     11       (272250.0, 339750.0]    7041.0       5.33     6359.0    682.0
#     12      (339750.0, 385886.25]    4010.0       3.03     3566.0    444.0
#     13      (385886.25, 402750.0]     515.0       0.39      430.0     85.0
#     14       (402750.0, 407362.5]    1354.0       1.02     1225.0    129.0
#     15       (407362.5, 451732.5]   14130.0      10.69    12166.0   1964.0
#     16       (451732.5, 471505.5]    5921.0       4.48     5545.0    376.0
#     17      (471505.5, 486042.75]    2374.0       1.80     2166.0    208.0
#     18      (486042.75, 542250.0]    4391.0       3.32     4082.0    309.0
#     19       (542250.0, 578250.0]    1252.0       0.95     1122.0    130.0
#     20      (578250.0, 593948.25]    1365.0       1.03     1267.0     98.0
#     21      (593948.25, 594279.0]     103.0       0.08       86.0     17.0
#     22       (594279.0, 677889.0]   13515.0      10.22    12207.0   1308.0
#     23      (677889.0, 686918.25]    2538.0       1.92     2434.0    104.0
#     24     (686918.25, 728736.75]    3336.0       2.52     3135.0    201.0
#     25      (728736.75, 902371.5]   12503.0       9.46    11572.0    931.0
#     26       (902371.5, 924750.0]    1705.0       1.29     1626.0     79.0
#     27      (924750.0, 1320750.0]   10718.0       8.11    10080.0    638.0
#     28     (1320750.0, 1464750.0]    3578.0       2.71     3437.0    141.0
#     29     (1464750.0, 1523250.0]     148.0       0.11      148.0      0.0
#     30     (1523250.0, 1559250.0]     130.0       0.10      117.0     13.0
#     31           (1559250.0, inf]    1087.0       0.82     1042.0     45.0
#     Total                     NaN  132202.0     100.00   120774.0  11428.0
#
#           Event_rate       WoE        IV    Gini
#     0        0.04557  0.684019  0.002116
#     1       0.075527  0.146872  0.001507
#     2       0.125198 -0.413754  0.000969
#     3       0.090667 -0.052339  0.000103
#     4       0.070724  0.217771  0.000598
#     5       0.130705 -0.463118  0.000946
#     6       0.106246 -0.228183  0.004241
#     7       0.084092  0.030148  0.000025
#     8        0.06881  0.247261  0.000740
#     9       0.118462 -0.350774  0.001398
#     10      0.074006  0.168864  0.001098
#     11      0.096861 -0.125258  0.000880
#     12      0.110723 -0.274479  0.002560
#     13      0.165049 -0.736721  0.002857
#     14      0.095273 -0.106971  0.000122
#     15      0.138995 -0.534193  0.037994
#     16      0.063503  0.333208  0.004335
#     17      0.087616 -0.014755  0.000004
#     18      0.070371  0.223147  0.001508
#     19      0.103834 -0.202521  0.000422
#     20      0.071795  0.201585  0.000386
#     21      0.165049 -0.736721  0.000571
#     22      0.096781 -0.124344  0.001664
#     23      0.040977  0.795046  0.008788
#     24      0.060252  0.389225  0.003257
#     25      0.074462   0.16223  0.002328
#     26      0.046334  0.666576  0.004366
#     27      0.059526  0.402116  0.011112
#     28      0.039407   0.83574  0.013472
#     29           0.0       inf       inf
#     30           0.1  -0.16063  0.000027
#     31      0.041398   0.78438  0.003679
#     Total                            inf  0.1881  ,
#     'EXT_SOURCE_3':                      Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0        (-inf, 0.00594]     456.0       0.34      377.0     79.0   0.173246
#     1      (0.00594, 0.0491]     419.0       0.32      249.0    170.0   0.405728
#     2       (0.0491, 0.0529]     111.0       0.08       83.0     28.0   0.252252
#     3       (0.0529, 0.0586]     220.0       0.17      138.0     82.0   0.372727
#     4       (0.0586, 0.0636]     203.0       0.15      157.0     46.0   0.226601
#     5       (0.0636, 0.0671]     145.0       0.11       99.0     46.0   0.317241
#     6         (0.0671, 0.12]    3017.0       2.28     2313.0    704.0   0.233344
#     7          (0.12, 0.151]    2531.0       1.91     1994.0    537.0   0.212169
#     8         (0.151, 0.159]     639.0       0.48      532.0    107.0   0.167449
#     9          (0.159, 0.16]     148.0       0.11      100.0     48.0   0.324324
#     10         (0.16, 0.163]     260.0       0.20      208.0     52.0        0.2
#     11        (0.163, 0.226]    6383.0       4.83     5281.0   1102.0   0.172646
#     12        (0.226, 0.267]    5256.0       3.98     4471.0    785.0   0.149353
#     13        (0.267, 0.316]    7087.0       5.36     6161.0    926.0   0.130662
#     14        (0.316, 0.321]     784.0       0.59      712.0     72.0   0.091837
#     15        (0.321, 0.334]    2173.0       1.64     1909.0    264.0   0.121491
#     16        (0.334, 0.446]   20931.0      15.83    18917.0   2014.0   0.096221
#     17        (0.446, 0.502]   11708.0       8.86    10800.0    908.0   0.077554
#     18        (0.502, 0.565]   14415.0      10.90    13524.0    891.0   0.061811
#     19        (0.565, 0.566]     523.0       0.40      480.0     43.0   0.082218
#     20        (0.566, 0.624]   13742.0      10.39    12973.0    769.0    0.05596
#     21        (0.624, 0.631]    1631.0       1.23     1574.0     57.0   0.034948
#     22        (0.631, 0.676]   11286.0       8.54    10700.0    586.0   0.051923
#     23        (0.676, 0.678]     291.0       0.22      284.0      7.0   0.024055
#     24        (0.678, 0.705]    6441.0       4.87     6142.0    299.0   0.046421
#     25        (0.705, 0.707]     508.0       0.38      488.0     20.0    0.03937
#     26        (0.707, 0.711]     953.0       0.72      932.0     21.0   0.022036
#     27        (0.711, 0.714]    1088.0       0.82     1029.0     59.0   0.054228
#     28        (0.714, 0.801]   14599.0      11.04    14029.0    570.0   0.039044
#     29        (0.801, 0.827]    2576.0       1.95     2506.0     70.0   0.027174
#     30        (0.827, 0.831]     126.0       0.10      115.0     11.0   0.087302
#     31          (0.831, inf]    1552.0       1.17     1497.0     55.0   0.035438
#     Total                NaN  132202.0      99.97   120774.0  11428.0
#
#                 WoE            IV    Gini
#     0     -0.795057  3.014311e-03
#     1       -1.9762  2.532311e-02
#     2     -1.271218  2.241016e-03
#     3      -1.83732  1.108405e-02
#     4      -1.13025  3.080217e-03
#     5     -1.591376  5.101138e-03
#     6     -1.168332  4.959758e-02
#     7     -1.045955  3.188036e-02
#     8      -0.75404  3.738565e-03
#     9     -1.623885  5.476094e-03
#     10     -0.97156  2.747575e-03
#     11    -0.790866  4.168141e-02
#     12    -0.618171  1.957832e-02
#     13    -0.462734  1.388963e-02
#     14    -0.066443  2.690974e-05
#     15    -0.379469  2.768139e-03
#     16    -0.117916  2.311446e-03
#     17     0.118202  1.178390e-03
#     18     0.362022  1.231286e-02
#     19     0.054731  1.158540e-05
#     20      0.46768  1.876549e-02
#     21      0.96047  7.726841e-03
#     22     0.546825  2.040622e-02
#     23      1.34521  2.339278e-03
#     24     0.664608  1.641016e-02
#     25     0.836729  1.916541e-03
#     26     1.434956  8.436537e-03
#     27     0.500951  1.681836e-03
#     28     0.845391  5.603388e-02
#     29     1.220093  1.784288e-02
#     30    -0.010818  1.120327e-07
#     31     0.946031  7.173099e-03
#     Total            3.957756e-01  0.3432  },
#    21.42),
#   64: (     Gini_train Gini_test        N_bins  \
#    0        0.4088    0.3787  [64, 64, 64]
#    1        0.4065    0.3888  [64, 64, 64]
#    2        0.4159    0.3663  [64, 64, 64]
#    3         0.415    0.3663  [64, 64, 64]
#    4        0.4073    0.3855  [64, 64, 64]
#    MEAN     0.4107    0.3771           NaN
#    STD       0.004    0.0094           NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde8adf9d00>      5
#    1     <__main__.CART object at 0x7fde8adf9d00>      5
#    2     <__main__.CART object at 0x7fde8adf9d00>      5
#    3     <__main__.CART object at 0x7fde8adf9d00>      5
#    4     <__main__.CART object at 0x7fde8adf9d00>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -6951.5]    1573.0       1.19     1505.0     68.0   0.043229
#     1      (-6951.5, -6910.5]     115.0       0.09      115.0      0.0        0.0
#     2      (-6910.5, -6722.5]     549.0       0.42      531.0     18.0   0.032787
#     3      (-6722.5, -6431.5]     875.0       0.66      820.0     55.0   0.062857
#     4      (-6431.5, -6320.5]     372.0       0.28      364.0      8.0   0.021505
#     ...                   ...       ...        ...        ...      ...        ...
#     60       (-308.5, -172.5]    7535.0       5.70     6696.0    839.0   0.111347
#     61       (-172.5, -164.5]     395.0       0.30      367.0     28.0   0.070886
#     62        (-164.5, -57.5]    3953.0       2.99     3539.0    414.0   0.104731
#     63           (-57.5, inf]     155.0       0.12      130.0     25.0    0.16129
#     Total                 NaN  132202.0     100.04   120783.0  11419.0
#
#                 WoE        IV    Gini
#     0      0.738324  0.004803
#     1           inf       inf
#     2      1.025673  0.002892
#     3      0.343254  0.000677
#     4      1.458995  0.003375
#     ...         ...       ...     ...
#     60    -0.281662  0.005080
#     61      0.21444  0.000126
#     62    -0.212983  0.001481
#     63    -0.710058  0.000790
#     Total                 inf  0.1709
#
#     [65 rows x 9 columns],
#     'AMT_GOODS_PRICE':                           Bin     Count  Count (%)  Non_event    Event  \
#     0             (-inf, 56250.0]     583.0       0.44      556.0     27.0
#     1          (56250.0, 96750.0]    2495.0       1.89     2332.0    163.0
#     2         (96750.0, 110250.0]     664.0       0.50      603.0     61.0
#     3        (110250.0, 138321.0]    4575.0       3.46     4254.0    321.0
#     4        (138321.0, 150750.0]    1050.0       0.79      965.0     85.0
#     ...                       ...       ...        ...        ...      ...
#     60     (1329750.0, 1464750.0]    3370.0       2.55     3244.0    126.0
#     61     (1464750.0, 1523250.0]     155.0       0.12      155.0      0.0
#     62     (1523250.0, 1568250.0]     136.0       0.10      123.0     13.0
#     63           (1568250.0, inf]    1093.0       0.83     1046.0     47.0
#     Total                     NaN  132202.0     100.01   120783.0  11419.0
#
#           Event_rate       WoE        IV    Gini
#     0       0.046312  0.666215  0.001492
#     1       0.065331  0.302014  0.001520
#     2       0.091867 -0.067674  0.000024
#     3       0.070164  0.225457  0.001603
#     4       0.080952   0.07076  0.000039
#     ...          ...       ...       ...     ...
#     60      0.037389  0.889564  0.014076
#     61           0.0       inf       inf
#     62      0.095588 -0.111482  0.000013
#     63      0.043001  0.743864  0.003380
#     Total                            inf  0.1954
#
#     [65 rows x 9 columns],
#     'EXT_SOURCE_3':                     Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0       (-inf, 0.00594]     440.0       0.33      355.0     85.0   0.193182
#     1      (0.00594, 0.034]     126.0       0.10       60.0     66.0    0.52381
#     2       (0.034, 0.0431]     176.0       0.13      105.0     71.0   0.403409
#     3      (0.0431, 0.0598]     512.0       0.39      355.0    157.0   0.306641
#     4      (0.0598, 0.0662]     257.0       0.19      206.0     51.0   0.198444
#     ...                 ...       ...        ...        ...      ...        ...
#     60       (0.827, 0.831]     137.0       0.10      126.0     11.0   0.080292
#     61       (0.831, 0.846]    1014.0       0.77      978.0     36.0   0.035503
#     62       (0.846, 0.855]     168.0       0.13      166.0      2.0   0.011905
#     63         (0.855, inf]     414.0       0.31      394.0     20.0   0.048309
#     Total               NaN  132202.0     100.01   120783.0  11419.0
#
#                 WoE        IV    Gini
#     0      -0.92925  0.004186
#     1     -2.454027  0.012965
#     2     -1.967436  0.010523
#     3     -1.542845  0.016678
#     4     -0.962666  0.002658
#     ...         ...       ...     ...
#     60      0.07967  0.000006
#     61     0.943274  0.004664
#     62     2.060124  0.002471
#     63     0.621902  0.000939
#     Total            0.418037  0.3513
#
#     [65 rows x 9 columns]},
#    22.59),
#   128: (     Gini_train Gini_test           N_bins  \
#    0        0.4266    0.3647  [128, 128, 128]
#    1        0.4296    0.3586  [128, 128, 128]
#    2        0.4227    0.3782  [128, 128, 128]
#    3        0.4267    0.3677  [128, 128, 128]
#    4        0.4215    0.3776  [128, 128, 128]
#    MEAN     0.4254    0.3694              NaN
#    STD      0.0029    0.0076              NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde89987100>      5
#    1     <__main__.CART object at 0x7fde89987100>      5
#    2     <__main__.CART object at 0x7fde89987100>      5
#    3     <__main__.CART object at 0x7fde89987100>      5
#    4     <__main__.CART object at 0x7fde89987100>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -4668.5]   12652.0       9.57    12031.0    621.0   0.049083
#     1      (-4668.5, -4654.5]     109.0       0.08      109.0      0.0        0.0
#     2      (-4654.5, -4640.5]     107.0       0.08       96.0     11.0   0.102804
#     3      (-4640.5, -4624.5]     101.0       0.08       99.0      2.0   0.019802
#     4      (-4624.5, -4087.5]    4892.0       3.70     4607.0    285.0   0.058258
#     ...                   ...       ...        ...        ...      ...        ...
#     124      (-211.5, -208.5]     171.0       0.13      160.0     11.0   0.064327
#     125       (-208.5, -68.5]    6481.0       4.90     5816.0    665.0   0.102608
#     126        (-68.5, -43.5]     110.0       0.08      105.0      5.0   0.045455
#     127          (-43.5, inf]     104.0       0.08       88.0     16.0   0.153846
#     Total                 NaN  132202.0      99.94   120830.0  11372.0
#
#                 WoE        IV    Gini
#     0       0.60068  0.027008
#     1           inf       inf
#     2     -0.196777  0.000034
#     3      1.538742  0.000990
#     4      0.419613  0.005483
#     ...         ...       ...     ...
#     124    0.314048  0.000112
#     125   -0.194649  0.002013
#     126    0.681292  0.000292
#     127   -0.658482  0.000447
#     Total                 inf  0.1938
#
#     [129 rows x 9 columns],
#     'AMT_GOODS_PRICE':                           Bin     Count  Count (%)  Non_event    Event  \
#     0             (-inf, 56250.0]     602.0       0.46      572.0     30.0
#     1          (56250.0, 96750.0]    2511.0       1.90     2344.0    167.0
#     2         (96750.0, 101250.0]     204.0       0.15      189.0     15.0
#     3        (101250.0, 110250.0]     448.0       0.34      405.0     43.0
#     4        (110250.0, 115362.0]     796.0       0.60      737.0     59.0
#     ...                       ...       ...        ...        ...      ...
#     124    (1464750.0, 1527750.0]     158.0       0.12      157.0      1.0
#     125    (1527750.0, 1568250.0]     143.0       0.11      131.0     12.0
#     126    (1568250.0, 1577250.0]     956.0       0.72      917.0     39.0
#     127          (1577250.0, inf]     110.0       0.08      104.0      6.0
#     Total                     NaN  132202.0      99.96   120830.0  11372.0
#
#           Event_rate       WoE            IV    Gini
#     0       0.049834  0.584711  1.225476e-03
#     1       0.066507   0.27839  1.312320e-03
#     2       0.073529  0.170466  4.179016e-05
#     3       0.095982 -0.120543  5.176141e-05
#     4       0.074121   0.16182  1.474661e-04
#     ...          ...       ...           ...     ...
#     124     0.006329  2.693015  3.262348e-03
#     125     0.083916   0.02706  7.832455e-07
#     126     0.040795  0.794315  3.304113e-03
#     127     0.054545  0.489401  1.630203e-04
#     Total                       1.388674e-01  0.2028
#
#     [129 rows x 9 columns],
#     'EXT_SOURCE_3':                     Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0       (-inf, 0.00594]     467.0       0.35      378.0     89.0   0.190578
#     1      (0.00594, 0.034]     120.0       0.09       58.0     62.0   0.516667
#     2       (0.034, 0.0446]     192.0       0.15      113.0     79.0   0.411458
#     3      (0.0446, 0.0586]     443.0       0.34      300.0    143.0   0.322799
#     4      (0.0586, 0.0627]     155.0       0.12      115.0     40.0   0.258065
#     ...                 ...       ...        ...        ...      ...        ...
#     124      (0.843, 0.855]     346.0       0.26      340.0      6.0   0.017341
#     125      (0.855, 0.861]     113.0       0.09      107.0      6.0   0.053097
#     126      (0.861, 0.865]     177.0       0.13      174.0      3.0   0.016949
#     127        (0.865, inf]     117.0       0.09      111.0      6.0   0.051282
#     Total               NaN  132202.0      99.97   120830.0  11372.0
#
#                 WoE        IV    Gini
#     0     -0.916973  0.004308
#     1     -2.429922  0.012082
#     2      -2.00529  0.012055
#     3     -1.622293  0.016372
#     4     -1.307178  0.003354
#     ...         ...       ...     ...
#     124    1.673956  0.003827
#     125    0.517839  0.000185
#     126    1.697213  0.001996
#     127     0.55454  0.000217
#     Total            0.425738  0.3552
#
#     [129 rows x 9 columns]},
#    24.2),
#   256: (     Gini_train Gini_test           N_bins  \
#    0        0.4438    0.3518  [256, 191, 256]
#    1        0.4444    0.3484  [256, 189, 256]
#    2         0.441    0.3585  [256, 191, 256]
#    3        0.4439    0.3538  [256, 191, 256]
#    4        0.4446    0.3448  [256, 192, 256]
#    MEAN     0.4435    0.3515              NaN
#    STD      0.0013    0.0047              NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fdea2ec7e50>      5
#    1     <__main__.CART object at 0x7fdea2ec7e50>      5
#    2     <__main__.CART object at 0x7fdea2ec7e50>      5
#    3     <__main__.CART object at 0x7fdea2ec7e50>      5
#    4     <__main__.CART object at 0x7fdea2ec7e50>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                       Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0         (-inf, -6951.5]    1556.0       1.18     1489.0     67.0   0.043059
#     1      (-6951.5, -6910.5]     124.0       0.09      122.0      2.0   0.016129
#     2      (-6910.5, -6867.5]     126.0       0.10      117.0      9.0   0.071429
#     3      (-6867.5, -6817.5]     135.0       0.10      134.0      1.0   0.007407
#     4      (-6817.5, -6773.5]     116.0       0.09      106.0     10.0   0.086207
#     ...                   ...       ...        ...        ...      ...        ...
#     252      (-228.5, -224.5]     238.0       0.18      205.0     33.0   0.138655
#     253       (-224.5, -74.5]    7527.0       5.69     6750.0    777.0   0.103228
#     254        (-74.5, -57.5]     104.0       0.08       97.0      7.0   0.067308
#     255          (-57.5, inf]     144.0       0.11      124.0     20.0   0.138889
#     Total                 NaN  132202.0      99.98   120722.0  11480.0
#
#                 WoE            IV    Gini
#     0      0.748283  4.862260e-03
#     1       1.75799  1.470330e-03
#     2      0.212065  3.927381e-05
#     3      2.544956  2.603185e-03
#     4       0.00797  5.555302e-08
#     ...         ...           ...     ...
#     252   -0.526382  6.192606e-04
#     253   -0.191027  2.248257e-03
#     254    0.275917  5.345691e-05
#     255   -0.528335  3.777630e-04
#     Total                     inf  0.2168
#
#     [257 rows x 9 columns],
#     'AMT_GOODS_PRICE':                           Bin     Count  Count (%)  Non_event    Event  \
#     0             (-inf, 51750.0]     512.0       0.39      488.0     24.0
#     1         (51750.0, 61535.25]     221.0       0.17      213.0      8.0
#     2         (61535.25, 69750.0]     600.0       0.45      563.0     37.0
#     3          (69750.0, 78750.0]     198.0       0.15      184.0     14.0
#     4          (78750.0, 87750.0]     211.0       0.16      197.0     14.0
#     ...                       ...       ...        ...        ...      ...
#     188    (1424250.0, 1464750.0]     126.0       0.10      122.0      4.0
#     189    (1464750.0, 1514250.0]     131.0       0.10      131.0      0.0
#     190    (1514250.0, 1568250.0]     165.0       0.12      151.0     14.0
#     191          (1568250.0, inf]    1043.0       0.79      994.0     49.0
#     Total                     NaN  132202.0     100.00   120722.0  11480.0
#
#           Event_rate       WoE            IV    Gini
#     0       0.046875  0.659378  1.286942e-03
#     1       0.036199  0.928967  9.916906e-04
#     2       0.061667  0.369478  5.322736e-04
#     3       0.070707  0.222994  6.793542e-05
#     4       0.066351  0.291262  1.200980e-04
#     ...          ...       ...           ...     ...
#     188     0.031746  1.064843  7.050901e-04
#     189          0.0       inf           inf
#     190     0.084848  0.025339  7.929802e-07
#     191      0.04698  0.657033  2.605464e-03
#     Total                                inf  0.2152
#
#     [193 rows x 9 columns],
#     'EXT_SOURCE_3':                        Bin     Count  Count (%)  Non_event    Event  \
#     0         (-inf, 0.005936]     456.0       0.34      362.0     94.0
#     1      (0.005936, 0.03856]     197.0       0.15      113.0     84.0
#     2       (0.03856, 0.04459]     131.0       0.10       68.0     63.0
#     3       (0.04459, 0.04909]     119.0       0.09       77.0     42.0
#     4       (0.04909, 0.05293]     103.0       0.08       79.0     24.0
#     ...                    ...       ...        ...        ...      ...
#     252       (0.8459, 0.8551]     158.0       0.12      155.0      3.0
#     253       (0.8551, 0.8608]     106.0       0.08      102.0      4.0
# ...
#    3        0.2424    0.2494  [1, 1, 2]
#    4        0.2435    0.2471  [1, 1, 2]
#    MEAN     0.2432     0.248        NaN
#    STD      0.0018    0.0037        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9e281340>      5
#    1     <__main__.CART object at 0x7fde9e281340>      5
#    2     <__main__.CART object at 0x7fde9e281340>      5
#    3     <__main__.CART object at 0x7fde9e281340>      5
#    4     <__main__.CART object at 0x7fde9e281340>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120747.0  11455.0   0.086648 -0.0
#     Total          NaN  132202.0      100.0   120747.0  11455.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120747.0  11455.0   0.086648 -0.0
#     Total          NaN  132202.0      100.0   120747.0  11455.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31552.0      23.87    26271.0   5281.0   0.167374
#     1       (0.343, inf]  100650.0      76.13    94476.0   6174.0   0.061341
#     Total            NaN  132202.0     100.00   120747.0  11455.0
#
#                 WoE        IV    Gini
#     0     -0.750921  0.182812
#     1      0.372728  0.090741
#     Total            0.273553  0.2435  },
#    20.96),
#   32: (     Gini_train Gini_test     N_bins  \
#    0        0.2389    0.2443  [1, 1, 2]
#    1        0.2503    0.2309  [1, 1, 2]
#    2        0.2407    0.2402  [1, 1, 2]
#    3        0.2472    0.2383  [1, 1, 2]
#    4        0.2441    0.2324  [1, 1, 2]
#    MEAN     0.2442    0.2372        NaN
#    STD      0.0042     0.005        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9ec09610>      5
#    1     <__main__.CART object at 0x7fde9ec09610>      5
#    2     <__main__.CART object at 0x7fde9ec09610>      5
#    3     <__main__.CART object at 0x7fde9ec09610>      5
#    4     <__main__.CART object at 0x7fde9ec09610>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120822.0  11380.0    0.08608 -0.0
#     Total          NaN  132202.0      100.0   120822.0  11380.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120822.0  11380.0    0.08608 -0.0
#     Total          NaN  132202.0      100.0   120822.0  11380.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.334]   30002.0      22.69    24881.0   5121.0   0.170689
#     1       (0.334, inf]  102200.0      77.31    95941.0   6259.0   0.061243
#     Total            NaN  132202.0     100.00   120822.0  11380.0
#
#                 WoE        IV    Gini
#     0     -0.781706  0.190790
#     1      0.367252  0.089635
#     Total            0.280425  0.2441  },
#    21.48),
#   64: (     Gini_train Gini_test     N_bins  \
#    0         0.242    0.2505  [1, 1, 2]
#    1        0.2457    0.2419  [1, 1, 2]
#    2        0.2483    0.2358  [1, 1, 2]
#    3        0.2482    0.2374  [1, 1, 2]
#    4        0.2506    0.2301  [1, 1, 2]
#    MEAN      0.247    0.2391        NaN
#    STD      0.0029    0.0068        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9ebfcbe0>      5
#    1     <__main__.CART object at 0x7fde9ebfcbe0>      5
#    2     <__main__.CART object at 0x7fde9ebfcbe0>      5
#    3     <__main__.CART object at 0x7fde9ebfcbe0>      5
#    4     <__main__.CART object at 0x7fde9ebfcbe0>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120720.0  11482.0   0.086852 -0.0
#     Total          NaN  132202.0      100.0   120720.0  11482.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120720.0  11482.0   0.086852 -0.0
#     Total          NaN  132202.0      100.0   120720.0  11482.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31519.0      23.84    26154.0   5365.0   0.170215
#     1       (0.343, inf]  100683.0      76.16    94566.0   6117.0   0.060755
#     Total            NaN  132202.0     100.00   120720.0  11482.0
#
#                 WoE        IV    Gini
#     0     -0.768587  0.192610
#     1      0.385533  0.096616
#     Total            0.289226  0.2506  },
#    22.1),
#   128: (     Gini_train Gini_test     N_bins  \
#    0        0.2453    0.2427  [1, 1, 2]
#    1        0.2429    0.2484  [1, 1, 2]
#    2        0.2613    0.2531  [1, 1, 2]
#    3        0.2453    0.2427  [1, 1, 2]
#    4        0.2439    0.2327  [1, 1, 2]
#    MEAN     0.2477    0.2439        NaN
#    STD      0.0068    0.0068        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9ebf7eb0>      5
#    1     <__main__.CART object at 0x7fde9ebf7eb0>      5
#    2     <__main__.CART object at 0x7fde9ebf7eb0>      5
#    3     <__main__.CART object at 0x7fde9ebf7eb0>      5
#    4     <__main__.CART object at 0x7fde9ebf7eb0>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120806.0  11396.0   0.086201 -0.0
#     Total          NaN  132202.0      100.0   120806.0  11396.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120806.0  11396.0   0.086201 -0.0
#     Total          NaN  132202.0      100.0   120806.0  11396.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.334]   29796.0      22.54    24688.0   5108.0   0.171432
#     1       (0.334, inf]  102406.0      77.46    96118.0   6288.0   0.061403
#     Total            NaN  132202.0     100.00   120806.0  11396.0
#
#                 WoE        IV    Gini
#     0     -0.785414  0.191536
#     1       0.36601  0.089258
#     Total            0.280794  0.2439  },
#    22.05),
#   256: (     Gini_train Gini_test     N_bins  \
#    0        0.2484    0.2369  [1, 1, 2]
#    1        0.2456    0.2421  [1, 1, 2]
#    2        0.2522    0.2284  [1, 1, 2]
#    3        0.2509    0.2319  [1, 1, 2]
#    4        0.2445    0.2445  [1, 1, 2]
#    MEAN     0.2483    0.2368        NaN
#    STD       0.003     0.006        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9ec002e0>      5
#    1     <__main__.CART object at 0x7fde9ec002e0>      5
#    2     <__main__.CART object at 0x7fde9ec002e0>      5
#    3     <__main__.CART object at 0x7fde9ec002e0>      5
#    4     <__main__.CART object at 0x7fde9ec002e0>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120841.0  11361.0   0.085937 -0.0
#     Total          NaN  132202.0      100.0   120841.0  11361.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120841.0  11361.0   0.085937 -0.0
#     Total          NaN  132202.0      100.0   120841.0  11361.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31424.0      23.77    26184.0   5240.0   0.166752
#     1       (0.343, inf]  100778.0      76.23    94657.0   6121.0   0.060737
#     Total            NaN  132202.0     100.00   120841.0  11361.0
#
#                 WoE        IV    Gini
#     0     -0.755462  0.184745
#     1      0.374245  0.091520
#     Total            0.276265  0.2445  },
#    21.47),
#   512: (     Gini_train Gini_test     N_bins  \
#    0        0.2429    0.2497  [1, 1, 2]
#    1        0.2463    0.2417  [1, 1, 2]
#    2        0.2415    0.2531  [1, 1, 2]
#    3         0.246     0.241  [1, 1, 2]
#    4        0.2418    0.2508  [1, 1, 2]
#    MEAN     0.2437    0.2473        NaN
#    STD      0.0021     0.005        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9ec17790>      5
#    1     <__main__.CART object at 0x7fde9ec17790>      5
#    2     <__main__.CART object at 0x7fde9ec17790>      5
#    3     <__main__.CART object at 0x7fde9ec17790>      5
#    4     <__main__.CART object at 0x7fde9ec17790>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120820.0  11382.0   0.086096 -0.0
#     Total          NaN  132202.0      100.0   120820.0  11382.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120820.0  11382.0   0.086096 -0.0
#     Total          NaN  132202.0      100.0   120820.0  11382.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31496.0      23.82    26269.0   5227.0   0.165958
#     1       (0.343, inf]  100706.0      76.18    94551.0   6155.0   0.061119
#     Total            NaN  132202.0     100.00   120820.0  11382.0
#
#                 WoE        IV    Gini
#     0     -0.747717  0.180806
#     1      0.369606  0.089375
#     Total            0.270181  0.2418  },
#    21.93),
#   1024: (     Gini_train Gini_test     N_bins  \
#    0        0.2474    0.2392  [1, 1, 2]
#    1        0.2459    0.2414  [1, 1, 2]
#    2        0.2464    0.2417  [1, 1, 2]
#    3         0.245    0.2435  [1, 1, 2]
#    4        0.2436    0.2465  [1, 1, 2]
#    MEAN     0.2457    0.2425        NaN
#    STD      0.0013    0.0024        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9dc4da60>      5
#    1     <__main__.CART object at 0x7fde9dc4da60>      5
#    2     <__main__.CART object at 0x7fde9dc4da60>      5
#    3     <__main__.CART object at 0x7fde9dc4da60>      5
#    4     <__main__.CART object at 0x7fde9dc4da60>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120888.0  11314.0   0.085581 -0.0
#     Total          NaN  132202.0      100.0   120888.0  11314.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120888.0  11314.0   0.085581 -0.0
#     Total          NaN  132202.0      100.0   120888.0  11314.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31472.0      23.81    26258.0   5214.0   0.165671
#     1       (0.343, inf]  100730.0      76.19    94630.0   6100.0   0.060558
#     Total            NaN  132202.0     100.00   120888.0  11314.0
#
#                 WoE        IV    Gini
#     0       -0.7522  0.183263
#     1      0.372862  0.090843
#     Total            0.274105  0.2436  },
#    21.77),
#   2048: (     Gini_train Gini_test     N_bins  \
#    0        0.2446    0.2443  [1, 1, 2]
#    1        0.2668    0.2464  [1, 1, 2]
#    2        0.2473    0.2394  [1, 1, 2]
#    3        0.2436    0.2466  [1, 1, 2]
#    4        0.2379    0.2601  [1, 1, 2]
#    MEAN      0.248    0.2474        NaN
#    STD      0.0099    0.0069        NaN
#
#                                        Bin_method N_iter
#    0     <__main__.CART object at 0x7fde9dc4b070>      5
#    1     <__main__.CART object at 0x7fde9dc4b070>      5
#    2     <__main__.CART object at 0x7fde9dc4b070>      5
#    3     <__main__.CART object at 0x7fde9dc4b070>      5
#    4     <__main__.CART object at 0x7fde9dc4b070>      5
#    MEAN                                       NaN    NaN
#    STD                                        NaN    NaN  ,
#    {'DAYS_EMPLOYED':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120785.0  11417.0    0.08636 -0.0
#     Total          NaN  132202.0      100.0   120785.0  11417.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'AMT_GOODS_PRICE':                Bin     Count  Count (%)  Non_event    Event Event_rate  WoE  \
#     0      (-inf, inf]  132202.0      100.0   120785.0  11417.0    0.08636 -0.0
#     Total          NaN  132202.0      100.0   120785.0  11417.0
#
#             IV Gini
#     0      0.0
#     Total  0.0    0  ,
#     'EXT_SOURCE_3':                  Bin     Count  Count (%)  Non_event    Event Event_rate  \
#     0      (-inf, 0.343]   31507.0      23.83    26305.0   5202.0   0.165106
#     1       (0.343, inf]  100695.0      76.17    94480.0   6215.0   0.061721
#     Total            NaN  132202.0     100.00   120785.0  11417.0
#
#                 WoE        IV    Gini
#     0     -0.738193  0.175581
#     1      0.362514  0.086225
#     Total            0.261806  0.2379  },
#    22.01)}}

# %%
second_param_name = 'ccp-alpha'
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 

display(df_report_train)
display(df_report_test)
display(df_report_bins)
# Out:
#              2       4       8       16      32      64      128     256   \
# ccp-alpha
# 0.000000   0.3188  0.3723  0.3857  0.3928   0.399  0.4107  0.4254  0.4435
# 0.000001   0.3162  0.3716  0.3871   0.394  0.4005  0.4101  0.4247  0.4413
# 0.000010   0.3177   0.372  0.3877  0.3946  0.4025  0.4114  0.4228  0.4354
# 0.000100   0.3162  0.3711   0.385  0.3894  0.3893  0.3876  0.3893  0.3912
# 0.001000   0.3205  0.3639  0.3634  0.3652  0.3627  0.3641  0.3581  0.3623
# 0.005000   0.2428  0.2481  0.2462  0.2447  0.2472  0.2463  0.2485  0.2436
# 0.010000   0.2452  0.2479  0.2471  0.2432  0.2442   0.247  0.2477  0.2483
#
#              512     1024    2048
# ccp-alpha
# 0.000000   0.4585  0.4686  0.4683
# 0.000001   0.4596  0.4678  0.4689
# 0.000010   0.4465  0.4491  0.4493
# 0.000100   0.3843  0.3878  0.3873
# 0.001000   0.3668  0.3601  0.3642
# 0.005000   0.2444  0.2462  0.2448
# 0.010000   0.2437  0.2457   0.248
#              2       4       8       16      32      64      128     256   \
# ccp-alpha
# 0.000000   0.3147  0.3626  0.3828  0.3857  0.3855  0.3771  0.3694  0.3515
# 0.000001   0.3169  0.3674  0.3801  0.3824   0.383  0.3789  0.3695  0.3547
# 0.000010   0.3152  0.3668  0.3786  0.3806  0.3798  0.3721  0.3684  0.3555
# 0.000100     0.32  0.3698  0.3812  0.3799   0.381  0.3836  0.3799  0.3756
# 0.001000   0.3106  0.3612  0.3554  0.3603  0.3574  0.3573  0.3551  0.3517
# 0.005000   0.2485  0.2464  0.2409  0.2419  0.2392  0.2397  0.2456  0.2354
# 0.010000   0.2435  0.2454  0.2494   0.248  0.2372  0.2391  0.2439  0.2368
#
#              512     1024    2048
# ccp-alpha
# 0.000000   0.3414  0.3327  0.3342
# 0.000001   0.3375  0.3339  0.3318
# 0.000010   0.3484  0.3488  0.3461
# 0.000100   0.3903  0.3816  0.3842
# 0.001000   0.3567  0.3573  0.3597
# 0.005000   0.2458  0.2427  0.2415
# 0.010000   0.2473  0.2425  0.2474
#                 2          4          8             16            32    \
# ccp-alpha
# 0.000000   [2, 2, 2]  [4, 4, 4]  [8, 8, 8]  [16, 16, 16]  [32, 32, 32]
# 0.000001   [2, 2, 2]  [4, 4, 4]  [8, 8, 8]  [16, 16, 16]  [32, 32, 32]
# 0.000010   [2, 2, 2]  [4, 4, 4]  [8, 8, 8]  [16, 16, 16]  [32, 32, 32]
# 0.000100   [2, 2, 2]  [4, 4, 4]  [4, 8, 8]   [4, 10, 11]    [4, 9, 11]
# 0.001000   [2, 2, 2]  [2, 4, 4]  [2, 2, 4]     [2, 4, 4]     [2, 2, 4]
# 0.005000   [1, 1, 2]  [1, 1, 2]  [1, 1, 2]     [1, 1, 2]     [1, 1, 2]
# 0.010000   [1, 1, 2]  [1, 1, 2]  [1, 1, 2]     [1, 1, 2]     [1, 1, 2]
#
#                    64               128              256              512   \
# ccp-alpha
# 0.000000   [64, 64, 64]  [128, 128, 128]  [256, 189, 256]  [512, 190, 467]
# 0.000001   [64, 64, 64]  [128, 128, 128]  [256, 149, 256]  [512, 157, 329]
# 0.000010   [64, 57, 57]    [128, 81, 96]   [235, 67, 107]   [406, 87, 126]
# 0.000100    [5, 10, 11]      [4, 11, 10]      [4, 10, 10]        [4, 9, 9]
# 0.001000      [2, 2, 4]        [2, 2, 4]        [2, 4, 4]        [2, 4, 4]
# 0.005000      [1, 1, 2]        [1, 1, 2]        [1, 1, 2]        [1, 1, 2]
# 0.010000      [1, 1, 2]        [1, 1, 2]        [1, 1, 2]        [1, 1, 2]
#
#                       1024             2048
# ccp-alpha
# 0.000000   [945, 193, 468]  [946, 191, 469]
# 0.000001   [863, 168, 327]  [856, 147, 348]
# 0.000010    [440, 65, 125]   [415, 80, 126]
# 0.000100       [4, 11, 10]      [4, 12, 10]
# 0.001000         [2, 2, 4]        [2, 2, 4]
# 0.005000         [1, 1, 2]        [1, 1, 2]
# 0.010000         [1, 1, 2]        [1, 1, 2]

# %%
df_tmp = df_report_train.T
plt.figure(figsize=(5,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 max leaf nodes')
plt.ylabel('Gini scoring')
plt.title('Train sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='ccp-alpha')
plt.show()

# %%
df_tmp = df_report_test.T
plt.figure(figsize=(5,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 max leaf nodes')
plt.ylabel('Gini scoring')
plt.title('Test sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='ccp-alpha')
plt.show()

# %% [markdown]
# ## Exp_2

# %%
#np.argwhere(np.isnan(x))
df_woe_test.gt(10).sum()

# %%
max_iter = 100
inf_repl = 100
max_leaf_nodes=2048
parameter_space_1 = [0, 10**-6, 10**-5, 10**-4, 0.001, 0.01] #min impurity decr
parameter_space_2 = [2**i for i in range(4, 17)] # min_samples_leaf
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method = CART(max_leaf_nodes=max_leaf_nodes, 
                          min_impurity_decrease=parameter_1, ccp_alpha = 0, 
                          criterion = 'entropy', min_samples_leaf=parameter_2)
        n_iter = 7
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2

# %%
fn = "CART_results_exp_2" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
parameter_space_1 = [0, 10**-6, 10**-5, 10**-4, 0.001, 0.01] #min impurity decrease
parameter_space_2 = [2**i for i in range(4, 17)] # min_samples_leaf

# %%
second_param_name = 'min impurity decr'
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = \
            np.round(np.mean(tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']),1)
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 

display(df_report_train)
display(df_report_test)
display(df_report_bins)
# Out:
#                     16      32      64      128     256     512     1024   \
# min impurity decr
# 0.000000           0.5389  0.5237   0.487   0.459  0.4371  0.4196   0.408
# 0.000001           0.5374  0.5233  0.4849    0.46  0.4366  0.4188  0.4063
# 0.000010           0.4295  0.4268  0.4227  0.4175  0.4117  0.4054  0.4018
# 0.000100           0.3865  0.3869  0.3894  0.3879  0.3867  0.3876  0.3911
# 0.001000            0.358  0.3596   0.358  0.3596  0.3582  0.3601  0.3593
# 0.010000           0.2433  0.2434  0.2446  0.2454  0.2446  0.2447  0.2435
#
#                     2048    4096    8192    16384   32768   65536
# min impurity decr
# 0.000000           0.3964  0.3934  0.3875  0.3749  0.3535  0.2878
# 0.000001            0.397  0.3923  0.3883  0.3763  0.3534  0.2889
# 0.000010           0.3943  0.3922  0.3873  0.3741  0.3558  0.2873
# 0.000100           0.3892  0.3862  0.3852  0.3738   0.355  0.2887
# 0.001000           0.3577  0.3583  0.3596   0.349  0.3463  0.2867
# 0.010000           0.2455  0.2424  0.2443  0.2451  0.2507  0.2437
#                     16      32      64      128     256     512     1024   \
# min impurity decr
# 0.000000           0.2809  0.2916  0.3183  0.3403  0.3571  0.3671  0.3758
# 0.000001           0.2866   0.288  0.3194  0.3351  0.3552  0.3708  0.3788
# 0.000010            0.361   0.362   0.366  0.3685  0.3742  0.3788  0.3793
# 0.000100           0.3847  0.3869  0.3782  0.3832  0.3866  0.3834  0.3757
# 0.001000           0.3548  0.3532  0.3552  0.3537  0.3579  0.3497  0.3557
# 0.010000           0.2383  0.2443  0.2411  0.2428   0.245  0.2448  0.2472
#
#                     2048    4096    8192    16384   32768   65536
# min impurity decr
# 0.000000           0.3849   0.382  0.3808  0.3723  0.3503  0.2873
# 0.000001            0.382  0.3844  0.3794  0.3713  0.3502  0.2857
# 0.000010           0.3856  0.3833  0.3818   0.367  0.3463  0.2896
# 0.000100           0.3804  0.3854  0.3792  0.3698  0.3488  0.2863
# 0.001000           0.3546  0.3537  0.3516  0.3483   0.338   0.291
# 0.010000           0.2396  0.2449  0.2435  0.2416  0.2435   0.238
#                    16     32     64     128    256    512   1024  2048  4096   \
# min impurity decr
# 0.000000           999.3  970.7  721.3  450.7  277.0  149.0  81.0  44.7  21.7
# 0.000001           901.0  879.3  591.7  382.7  234.3  133.7  74.7  41.7  22.3
# 0.000010           124.7  119.0   94.0   72.0   66.7   56.3  42.0  22.0  16.7
# 0.000100             7.7    7.7    9.0    8.7    9.3    7.7   8.0   8.3   8.0
# 0.001000             2.7    2.7    2.7    2.7    2.7    2.7   2.7   2.7   2.7
# 0.010000             1.3    1.3    1.3    1.3    1.3    1.3   1.3   1.3   1.3
#
#                   8192  16384 32768 65536
# min impurity decr
# 0.000000           11.0   5.3   3.0   1.7
# 0.000001           11.3   5.7   3.0   1.7
# 0.000010            9.7   5.3   3.0   1.7
# 0.000100            7.0   5.0   3.0   1.7
# 0.001000            2.7   2.3   2.3   1.7
# 0.010000            1.3   1.3   1.3   1.3

# %%
df_tmp = df_report_train.T
plt.figure(figsize=(5,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 min_samples_leaf')
plt.ylabel('Gini scoring')
plt.title('Train sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='min impurity decrease')
plt.show()

# %%
df_tmp = df_report_test.T
plt.figure(figsize=(5,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 min_samples_leaf')
plt.ylabel('Gini scoring')
plt.title('Test sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='min impurity decrease')
plt.show()

# %% [markdown]
# # MDLP exploration

# %%
df = prepare_df(d0)
# Out:
# df initial shape: (202044, 4)
#
# N outliers in DAYS_EMPLOYED: 10203,        df shape after outlier removal: (191841, 4)
# N outliers in AMT_GOODS_PRICE: 2980,        df shape after outlier removal: (188861, 4)
# N outliers in EXT_SOURCE_3: 0,        df shape after outlier removal: (188861, 4)
#
# df shape: (188861, 4)

# %% [markdown]
# ## Experiment

# %%
max_iter = 100
inf_repl = 100
parameter_space_1 = [2**i for i in range(4, 16)] #min_samples_leaf
parameter_space_2 = [2**i for i in range(2, 9)] #max_candidates
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        #bin_method = MDLP(min_samples_split=2, min_samples_leaf=parameter_2, max_candidates=parameter_1)
        # have to move the method definition into the cycle to handle the library mistake
        n_iter = 11
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter'])
        for i in range(n_iter):
            bin_method = MDLP(min_samples_split=2, min_samples_leaf=parameter_1, max_candidates=parameter_2)
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter          
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2
# Out:
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 16 4 is 45.24 sec.
# Run time for parameters 16 8 is 44.96 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 16 16 is 45.51 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 16 32 is 45.74 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 16 64 is 46.71 sec.
# Run time for parameters 16 128 is 48.44 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 16 256 is 51.92 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 32 4 is 45.26 sec.
# Run time for parameters 32 8 is 44.91 sec.
# Run time for parameters 32 16 is 45.1 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 32 32 is 45.98 sec.
# Run time for parameters 32 64 is 46.79 sec.
# Run time for parameters 32 128 is 48.32 sec.
# Run time for parameters 32 256 is 50.3 sec.
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Run time for parameters 64 4 is 44.78 sec.
# Run time for parameters 64 8 is 45.12 sec.
# Run time for parameters 64 16 is 45.08 sec.
# Run time for parameters 64 32 is 45.87 sec.
# Run time for parameters 64 64 is 46.89 sec.
# Run time for parameters 64 128 is 47.93 sec.
# Run time for parameters 64 256 is 50.4 sec.
# Run time for parameters 128 4 is 44.74 sec.
# Run time for parameters 128 8 is 44.89 sec.
# Run time for parameters 128 16 is 45.46 sec.
# Run time for parameters 128 32 is 45.62 sec.
# Run time for parameters 128 64 is 46.94 sec.
# Run time for parameters 128 128 is 48.01 sec.
# Run time for parameters 128 256 is 50.2 sec.
# Run time for parameters 256 4 is 45.04 sec.
# Run time for parameters 256 8 is 45.04 sec.
# Run time for parameters 256 16 is 45.37 sec.
# Run time for parameters 256 32 is 45.8 sec.
# Run time for parameters 256 64 is 46.53 sec.
# Run time for parameters 256 128 is 48.28 sec.
# Run time for parameters 256 256 is 50.1 sec.
# Run time for parameters 512 4 is 44.77 sec.
# Run time for parameters 512 8 is 44.95 sec.
# Run time for parameters 512 16 is 45.42 sec.
# Run time for parameters 512 32 is 45.93 sec.
# Run time for parameters 512 64 is 46.45 sec.
# Run time for parameters 512 128 is 47.87 sec.
# Run time for parameters 512 256 is 50.0 sec.
# Run time for parameters 1024 4 is 44.74 sec.
# Run time for parameters 1024 8 is 45.04 sec.
# Run time for parameters 1024 16 is 45.08 sec.
# Run time for parameters 1024 32 is 45.54 sec.
# Run time for parameters 1024 64 is 46.4 sec.
# Run time for parameters 1024 128 is 47.59 sec.
# Run time for parameters 1024 256 is 49.7 sec.
# Run time for parameters 2048 4 is 61.73 sec.
# Run time for parameters 2048 8 is 47.43 sec.
# Run time for parameters 2048 16 is 48.01 sec.
# Run time for parameters 2048 32 is 46.55 sec.
# Run time for parameters 2048 64 is 47.01 sec.
# Run time for parameters 2048 128 is 48.72 sec.
# Run time for parameters 2048 256 is 50.36 sec.
# Run time for parameters 4096 4 is 45.7 sec.
# Run time for parameters 4096 8 is 46.93 sec.
# Run time for parameters 4096 16 is 45.28 sec.
# Run time for parameters 4096 32 is 46.58 sec.
# Run time for parameters 4096 64 is 46.28 sec.
# Run time for parameters 4096 128 is 49.45 sec.
# Run time for parameters 4096 256 is 50.64 sec.
# Run time for parameters 8192 4 is 45.33 sec.
# Run time for parameters 8192 8 is 45.99 sec.
# Run time for parameters 8192 16 is 45.95 sec.
# Run time for parameters 8192 32 is 46.01 sec.
# Run time for parameters 8192 64 is 46.54 sec.
# Run time for parameters 8192 128 is 47.73 sec.
# Run time for parameters 8192 256 is 48.86 sec.
# Run time for parameters 16384 4 is 45.07 sec.
# Run time for parameters 16384 8 is 44.68 sec.
# Run time for parameters 16384 16 is 46.58 sec.
# Run time for parameters 16384 32 is 46.15 sec.
# Run time for parameters 16384 64 is 46.84 sec.
# Run time for parameters 16384 128 is 47.12 sec.
# Run time for parameters 16384 256 is 46.69 sec.
# Run time for parameters 32768 4 is 45.67 sec.
# Run time for parameters 32768 8 is 44.32 sec.
# Run time for parameters 32768 16 is 47.06 sec.
# Run time for parameters 32768 32 is 46.44 sec.
# Run time for parameters 32768 64 is 45.42 sec.
# Run time for parameters 32768 128 is 47.19 sec.
# Run time for parameters 32768 256 is 45.86 sec.

# %%
fn = "MDLP_results_exp_1" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
# parameter_space_1 = [2**i for i in range(14, 16)] #min_samples_leaf
# parameter_space_2 = [2**i for i in range(7, 9)] #max_candidates
parameter_space_1 = [2**i for i in range(4, 16)] #min_samples_leaf
parameter_space_2 = [2**i for i in range(2, 9)] #max_candidates

# %%
tmp
# Out:
# {16: {4: (     Gini_train Gini_test        N_bins  \
#    0        0.3747    0.3843   [8, 10, 18]
#    1        0.3773    0.3784   [8, 10, 18]
#    2        0.3805    0.3781   [8, 14, 18]
#    3        0.3772    0.3773   [8, 10, 18]
#    4        0.3785    0.3804   [8, 10, 16]
#    5        0.3774     0.384   [8, 12, 18]
#    6        0.3799    0.3785  [10, 10, 18]
#    7        0.3804    0.3766   [8, 10, 18]
#    8        0.3815    0.3712   [8, 10, 21]
#    9        0.3881    0.3581   [8, 16, 18]
#    10       0.3827    0.3708   [8, 14, 18]
#    MEAN     0.3798    0.3762           NaN
#    STD      0.0034     0.007           NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=16)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.24),
#   8: (     Gini_train Gini_test       N_bins  \
#    0        0.3778    0.3845  [8, 14, 19]
#    1        0.3843    0.3659  [8, 14, 14]
#    2        0.3807    0.3905  [8, 16, 18]
#    3        0.3817    0.3734  [8, 10, 16]
#    4         0.381    0.3902  [8, 12, 21]
#    5        0.3866    0.3774  [8, 17, 18]
#    6        0.3802    0.3768  [8, 12, 17]
#    7        0.3841    0.3697  [8, 12, 18]
#    8        0.3839    0.3814  [8, 15, 21]
#    9        0.3871     0.363  [8, 12, 16]
#    10       0.3858     0.384  [8, 17, 21]
#    MEAN      0.383    0.3779          NaN
#    STD      0.0028    0.0088          NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=16)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.96),
#   16: (     Gini_train Gini_test       N_bins  \
#    0        0.3861    0.3782  [8, 18, 19]
#    1        0.3854     0.371  [8, 14, 18]
#    2        0.3801    0.3799  [8, 10, 18]
#    3        0.3924    0.3788  [8, 18, 19]
#    4        0.3889    0.3866  [6, 16, 16]
#    5        0.3793    0.3839  [8, 14, 19]
#    6        0.3876    0.3824  [8, 20, 19]
#    7        0.3902    0.3823  [8, 20, 16]
#    8        0.3861    0.3712  [8, 14, 16]
#    9        0.3882    0.3754  [6, 16, 16]
#    10       0.3894    0.3698  [8, 16, 16]
#    MEAN     0.3867    0.3781          NaN
#    STD      0.0038    0.0054          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=16)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.51),
#   32: (     Gini_train Gini_test       N_bins                 Bin_method N_iter
#    0        0.3908    0.3826  [8, 20, 16]  MDLP(min_samples_leaf=16)     11
#    1        0.3951    0.3745  [8, 21, 18]  MDLP(min_samples_leaf=16)     11
#    2        0.3879    0.3786  [8, 18, 14]  MDLP(min_samples_leaf=16)     11
#    3        0.3924    0.3786  [8, 18, 14]  MDLP(min_samples_leaf=16)     11
#    4        0.3887    0.3867  [8, 16, 18]  MDLP(min_samples_leaf=16)     11
#    5        0.3839    0.3874  [8, 16, 21]  MDLP(min_samples_leaf=16)     11
#    6        0.3801    0.3987  [8, 16, 19]  MDLP(min_samples_leaf=16)     11
#    7        0.3881    0.3792  [8, 14, 19]  MDLP(min_samples_leaf=16)     11
#    8        0.3947    0.3742  [8, 18, 21]  MDLP(min_samples_leaf=16)     11
#    9        0.3854    0.3944  [8, 16, 21]  MDLP(min_samples_leaf=16)     11
#    10       0.3859    0.3961  [8, 21, 14]  MDLP(min_samples_leaf=16)     11
#    MEAN     0.3885    0.3846          NaN                        NaN    NaN
#    STD      0.0044    0.0083          NaN                        NaN    NaN,
#    'mas_no_bt_dict_here',
#    45.74),
#   64: (     Gini_train Gini_test       N_bins  \
#    0        0.3877    0.3909  [8, 19, 18]
#    1        0.3938    0.3776  [8, 18, 19]
#    2        0.3903    0.3872  [8, 19, 18]
#    3        0.3922    0.3838  [8, 22, 19]
#    4        0.3886    0.3889  [8, 18, 17]
#    5        0.3926    0.3822  [8, 19, 15]
#    6        0.3932    0.3764  [8, 18, 16]
#    7        0.3907    0.3849  [8, 19, 14]
#    8        0.3912    0.3814  [8, 15, 21]
#    9        0.3884    0.3925  [8, 21, 17]
#    10       0.3893    0.3864  [8, 16, 16]
#    MEAN     0.3907    0.3847          NaN
#    STD       0.002    0.0049          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=16)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.71),
#   128: (     Gini_train Gini_test       N_bins  \
#    0        0.3911    0.3813  [8, 16, 16]
#    1        0.3914    0.3801  [8, 15, 21]
#    2        0.3963    0.3708  [8, 18, 17]
#    3        0.3908    0.3846  [8, 17, 19]
#    4        0.3852    0.3961  [8, 16, 16]
#    5        0.3903    0.3855  [8, 16, 19]
#    6         0.395     0.377  [8, 18, 19]
#    7        0.3911    0.3822  [8, 16, 17]
#    8        0.3931    0.3828  [8, 18, 23]
#    9        0.3891    0.3873  [8, 16, 16]
#    10       0.3908    0.3843  [8, 16, 19]
#    MEAN     0.3913    0.3829          NaN
#    STD      0.0028     0.006          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=16)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    48.44),
#   256: (     Gini_train Gini_test       N_bins  \
#    0        0.3942    0.3767  [8, 18, 16]
#    1        0.3915     0.385  [8, 20, 19]
#    2        0.3908    0.3827  [8, 16, 18]
#    3        0.3909     0.384  [8, 16, 19]
#    4        0.3907    0.3867  [8, 18, 16]
#    5        0.3853    0.3957  [8, 16, 19]
#    6        0.3843     0.401  [8, 16, 16]
#    7        0.3959    0.3707  [8, 16, 16]
#    8        0.3957    0.3771  [8, 20, 21]
#    9        0.3856    0.3983  [8, 16, 21]
#    10       0.3899    0.3885  [8, 18, 18]
#    MEAN     0.3904     0.386          NaN
#    STD      0.0038     0.009          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=16)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=16)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    51.92)},
#  32: {4: (     Gini_train Gini_test        N_bins  \
#    0        0.3827    0.3679   [8, 10, 20]
#    1        0.3728    0.3904   [8, 10, 18]
#    2        0.3787    0.3805   [8, 10, 16]
#    3        0.3825    0.3666  [10, 10, 18]
#    4        0.3794    0.3769   [8, 16, 18]
#    5        0.3809    0.3778  [10, 12, 18]
#    6        0.3785    0.3805   [8, 10, 21]
#    7        0.3813    0.3745   [8, 12, 18]
#    8        0.3753     0.389   [8, 10, 18]
#    9        0.3831    0.3717   [8, 16, 18]
#    10       0.3804    0.3723   [8, 10, 18]
#    MEAN     0.3796    0.3771           NaN
#    STD       0.003    0.0074           NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=32)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.26),
#   8: (     Gini_train Gini_test       N_bins  \
#    0        0.3845    0.3682  [8, 12, 17]
#    1        0.3886    0.3692  [8, 15, 18]
#    2        0.3877    0.3687  [8, 14, 17]
#    3        0.3828    0.3883  [8, 16, 18]
#    4        0.3798    0.3808  [8, 12, 21]
#    5         0.379    0.3811  [8, 14, 21]
#    6        0.3813    0.3915  [8, 16, 17]
#    7        0.3834    0.3798  [8, 18, 19]
#    8        0.3801     0.379  [8, 12, 17]
#    9        0.3835    0.3815  [8, 15, 16]
#    10       0.3855    0.3631  [8, 12, 19]
#    MEAN     0.3833    0.3774          NaN
#    STD       0.003    0.0085          NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=32)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.91),
#   16: (     Gini_train Gini_test       N_bins  \
#    0        0.3891     0.371  [6, 16, 18]
#    1        0.3888    0.3838  [8, 16, 16]
#    2        0.3884    0.3731  [8, 14, 16]
#    3        0.3874    0.3765  [8, 16, 16]
#    4        0.3816    0.3899  [8, 16, 21]
#    5        0.3826    0.3707  [8, 12, 17]
#    6        0.3809    0.3812  [8, 12, 21]
#    7        0.3835    0.3757  [6, 14, 21]
#    8        0.3914    0.3813  [8, 18, 19]
#    9        0.3846    0.3854  [6, 16, 16]
#    10       0.3847    0.3702  [6, 14, 18]
#    MEAN     0.3857    0.3781          NaN
#    STD      0.0033    0.0064          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=32)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.1),
#   32: (     Gini_train Gini_test       N_bins                 Bin_method N_iter
#    0        0.3928    0.3756  [8, 19, 16]  MDLP(min_samples_leaf=32)     11
#    1        0.3933    0.3777  [8, 18, 19]  MDLP(min_samples_leaf=32)     11
#    2        0.3956    0.3733  [8, 20, 21]  MDLP(min_samples_leaf=32)     11
#    3        0.3871    0.3801  [8, 12, 18]  MDLP(min_samples_leaf=32)     11
#    4        0.3899    0.3909  [8, 23, 21]  MDLP(min_samples_leaf=32)     11
#    5        0.3895    0.3894  [8, 21, 16]  MDLP(min_samples_leaf=32)     11
#    6        0.3905    0.3819  [8, 15, 14]  MDLP(min_samples_leaf=32)     11
#    7        0.3917    0.3797  [8, 18, 23]  MDLP(min_samples_leaf=32)     11
#    8        0.3903    0.3852  [8, 19, 19]  MDLP(min_samples_leaf=32)     11
#    9        0.3918    0.3826  [8, 16, 16]  MDLP(min_samples_leaf=32)     11
#    10       0.3902    0.3822  [8, 20, 16]  MDLP(min_samples_leaf=32)     11
#    MEAN     0.3912    0.3817          NaN                        NaN    NaN
#    STD      0.0021    0.0051          NaN                        NaN    NaN,
#    'mas_no_bt_dict_here',
#    45.98),
#   64: (     Gini_train Gini_test       N_bins  \
#    0        0.3855     0.397  [8, 17, 17]
#    1        0.3912    0.3832  [8, 19, 16]
#    2        0.3869     0.397  [8, 20, 17]
#    3         0.385    0.3959  [8, 18, 19]
#    4        0.3956    0.3712  [8, 15, 15]
#    5        0.3968    0.3685  [8, 16, 19]
#    6        0.3895    0.3873  [8, 17, 19]
#    7        0.3917    0.3797  [8, 18, 17]
#    8        0.3928    0.3803  [8, 18, 19]
#    9        0.3885    0.3902  [8, 16, 19]
#    10       0.3844    0.4007  [8, 19, 19]
#    MEAN     0.3898    0.3865          NaN
#    STD       0.004    0.0104          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=32)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.79),
#   128: (     Gini_train Gini_test       N_bins  \
#    0        0.3941    0.3729  [8, 14, 19]
#    1        0.3947    0.3767  [8, 18, 17]
#    2        0.3884    0.3888  [8, 16, 19]
#    3        0.3914    0.3831  [8, 18, 19]
#    4         0.393    0.3821  [8, 21, 21]
#    5        0.3907    0.3862  [8, 18, 17]
#    6        0.3896    0.3823  [8, 14, 16]
#    7        0.3948    0.3772  [8, 20, 16]
#    8        0.3962    0.3736  [8, 17, 14]
#    9        0.3941    0.3795  [8, 20, 19]
#    10       0.3941     0.379  [8, 19, 21]
#    MEAN     0.3928    0.3801          NaN
#    STD      0.0023    0.0047          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=32)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    48.32),
#   256: (     Gini_train Gini_test       N_bins  \
#    0        0.3908    0.3882  [6, 18, 21]
#    1        0.3858    0.3941  [6, 15, 21]
#    2        0.3958     0.376  [8, 18, 19]
#    3        0.3927    0.3788  [8, 16, 16]
#    4        0.3896    0.3877  [8, 17, 19]
#    5        0.3876    0.3912  [8, 16, 19]
#    6        0.3887    0.3941  [8, 20, 19]
#    7        0.3878     0.391  [8, 16, 19]
#    8        0.3905    0.3853  [8, 18, 17]
#    9        0.3893    0.3875  [8, 16, 18]
#    10       0.3894     0.381  [8, 16, 17]
#    MEAN     0.3898    0.3868          NaN
#    STD      0.0026    0.0057          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=32)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=32)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    50.3)},
#  64: {4: (     Gini_train Gini_test       N_bins  \
#    0        0.3776    0.3788  [8, 14, 18]
#    1        0.3776    0.3755   [8, 8, 18]
#    2         0.381    0.3717  [8, 12, 18]
#    3        0.3748    0.3825  [6, 10, 18]
#    4        0.3833    0.3686  [8, 10, 18]
#    5         0.376    0.3851  [8, 10, 18]
#    6        0.3755    0.3849  [8, 12, 18]
#    7        0.3786    0.3891  [8, 14, 18]
#    8        0.3821    0.3899  [8, 14, 18]
#    9        0.3822    0.3729   [8, 8, 18]
#    10       0.3743    0.3885  [8, 10, 18]
#    MEAN     0.3785    0.3807          NaN
#    STD      0.0031    0.0072          NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=64)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.78),
#   8: (     Gini_train Gini_test       N_bins  \
#    0        0.3759     0.387  [8, 14, 19]
#    1        0.3884     0.385  [8, 20, 17]
#    2        0.3821    0.3919  [8, 16, 21]
#    3        0.3828    0.3755  [8, 16, 17]
#    4        0.3932    0.3763  [8, 19, 18]
#    5        0.3888    0.3701  [8, 15, 19]
#    6        0.3879    0.3848  [8, 19, 16]
#    7        0.3874    0.3727  [8, 16, 19]
#    8        0.3845    0.3675  [8, 14, 16]
#    9        0.3806    0.3794  [8, 14, 21]
#    10       0.3881    0.3874  [8, 18, 19]
#    MEAN     0.3854    0.3798          NaN
#    STD      0.0046    0.0076          NaN
#
#                                           Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=64)     11
#    MEAN                                          NaN    NaN
#    STD                                           NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.12),
#   16: (     Gini_train Gini_test       N_bins  \
#    0         0.393    0.3732  [8, 16, 17]
#    1         0.387    0.3795  [8, 16, 21]
#    2        0.3811    0.3808  [8, 12, 21]
#    3        0.3868    0.3772  [8, 14, 17]
#    4        0.3842    0.3724  [8, 14, 21]
#    5        0.3829    0.3744  [8, 14, 19]
#    6        0.3818    0.3883  [8, 14, 14]
#    7        0.3897    0.3852  [8, 16, 21]
#    8        0.3892    0.3725  [6, 16, 19]
#    9        0.3845     0.388  [8, 21, 16]
#    10       0.3899    0.3842  [8, 20, 17]
#    MEAN     0.3864    0.3796          NaN
#    STD      0.0036    0.0058          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=64)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.08),
#   32: (     Gini_train Gini_test       N_bins                 Bin_method N_iter
#    0        0.3909    0.3827  [8, 17, 21]  MDLP(min_samples_leaf=64)     11
#    1        0.3886    0.3888  [8, 20, 19]  MDLP(min_samples_leaf=64)     11
#    2        0.3908    0.3863  [8, 20, 16]  MDLP(min_samples_leaf=64)     11
#    3        0.3882     0.378  [8, 12, 19]  MDLP(min_samples_leaf=64)     11
#    4        0.3847    0.3885  [8, 18, 19]  MDLP(min_samples_leaf=64)     11
#    5         0.383    0.3907  [8, 16, 19]  MDLP(min_samples_leaf=64)     11
#    6        0.3922    0.3798  [8, 19, 14]  MDLP(min_samples_leaf=64)     11
#    7         0.386    0.3848  [8, 18, 19]  MDLP(min_samples_leaf=64)     11
#    8        0.3939    0.3743  [8, 16, 21]  MDLP(min_samples_leaf=64)     11
#    9        0.3888     0.385  [8, 19, 19]  MDLP(min_samples_leaf=64)     11
#    10       0.3921    0.3834  [8, 19, 19]  MDLP(min_samples_leaf=64)     11
#    MEAN      0.389    0.3838          NaN                        NaN    NaN
#    STD      0.0032    0.0047          NaN                        NaN    NaN,
#    'mas_no_bt_dict_here',
#    45.87),
#   64: (     Gini_train Gini_test       N_bins  \
#    0        0.3886    0.3913  [8, 18, 19]
#    1         0.397    0.3677  [8, 16, 18]
#    2        0.3917    0.3825  [8, 20, 19]
#    3         0.391     0.385  [8, 20, 19]
#    4        0.3948    0.3794  [8, 21, 19]
#    5        0.3896    0.3814  [8, 15, 19]
#    6        0.3892    0.3859  [8, 18, 19]
#    7        0.3943    0.3756  [8, 15, 19]
#    8        0.3856    0.3957  [8, 16, 19]
#    9        0.3867    0.3923  [8, 16, 21]
#    10       0.3891    0.3852  [8, 17, 19]
#    MEAN     0.3907    0.3838          NaN
#    STD      0.0033    0.0076          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=64)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.89),
#   128: (     Gini_train Gini_test       N_bins  \
#    0        0.3872    0.3931  [8, 16, 23]
#    1        0.3928    0.3776  [8, 16, 17]
#    2        0.3935    0.3782  [8, 18, 19]
#    3        0.3901    0.3878  [8, 20, 16]
#    4        0.3954    0.3758  [8, 19, 21]
#    5        0.3888    0.3898  [8, 16, 19]
#    6        0.3916    0.3854  [8, 18, 19]
#    7        0.3919    0.3834  [8, 20, 16]
#    8        0.3912     0.386  [8, 18, 21]
#    9        0.3915    0.3847  [8, 20, 16]
#    10       0.3916    0.3803  [8, 16, 19]
#    MEAN     0.3914    0.3838          NaN
#    STD      0.0021    0.0052          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=64)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    47.93),
#   256: (     Gini_train Gini_test       N_bins  \
#    0         0.394    0.3751  [8, 15, 19]
#    1        0.3909    0.3845  [8, 18, 19]
#    2        0.3875    0.3909  [8, 16, 14]
#    3        0.3856    0.3936  [8, 16, 17]
#    4        0.3941    0.3773  [8, 16, 19]
#    5        0.3917    0.3815  [8, 16, 17]
#    6        0.3863    0.3984  [8, 19, 14]
#    7        0.3906    0.3824  [8, 18, 16]
#    8        0.3912    0.3849  [8, 16, 17]
#    9        0.3902    0.3897  [8, 20, 19]
#    10       0.3935     0.378  [8, 16, 18]
#    MEAN     0.3905    0.3851          NaN
#    STD      0.0028     0.007          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=64)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=64)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    50.4)},
#  128: {4: (     Gini_train Gini_test       N_bins  \
#    0        0.3817    0.3737  [8, 10, 21]
#    1          0.38    0.3765  [8, 10, 21]
#    2        0.3803    0.3737  [8, 10, 18]
#    3         0.376    0.3832  [8, 10, 18]
#    4        0.3804    0.3733  [8, 10, 18]
#    5        0.3777    0.3795  [8, 12, 16]
#    6        0.3856    0.3902  [8, 20, 18]
#    7        0.3789    0.3731  [8, 10, 19]
#    8         0.373    0.3897  [8, 10, 18]
#    9        0.3793    0.3767  [8, 10, 18]
#    10       0.3828    0.3797  [8, 12, 18]
#    MEAN     0.3796     0.379          NaN
#    STD      0.0032     0.006          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=128)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.74),
#   8: (     Gini_train Gini_test       N_bins  \
#    0        0.3779    0.3817  [6, 12, 15]
#    1        0.3826    0.3717  [8, 12, 17]
#    2        0.3858    0.3623  [8, 14, 18]
#    3        0.3859    0.3732  [8, 14, 23]
#    4        0.3864      0.38  [8, 22, 19]
#    5        0.3899    0.3825  [8, 19, 16]
#    6        0.3846    0.3752  [8, 13, 16]
#    7        0.3871    0.3901  [8, 20, 19]
#    8        0.3822    0.3851  [8, 16, 17]
#    9        0.3836    0.3738  [8, 14, 18]
#    10       0.3895     0.373  [8, 18, 19]
#    MEAN      0.385    0.3771          NaN
#    STD      0.0033    0.0073          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=128)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.89),
#   16: (     Gini_train Gini_test       N_bins  \
#    0        0.3841    0.3854  [8, 14, 19]
#    1          0.39    0.3703  [8, 18, 19]
#    2        0.3922    0.3772  [8, 19, 21]
#    3        0.3884    0.3905  [8, 20, 16]
#    4        0.3851    0.3834  [8, 20, 16]
#    5        0.3836    0.3743  [8, 14, 19]
#    6         0.386    0.3813  [8, 18, 16]
#    7        0.3773    0.3995  [8, 16, 18]
#    8        0.3825    0.3856  [8, 12, 14]
#    9        0.3903    0.3837  [8, 20, 16]
#    10       0.3916    0.3824  [8, 21, 16]
#    MEAN     0.3865    0.3831          NaN
#    STD      0.0043    0.0075          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=128)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.46),
#   32: (     Gini_train Gini_test       N_bins                  Bin_method N_iter
#    0        0.3866    0.3929  [8, 17, 19]  MDLP(min_samples_leaf=128)     11
#    1         0.396    0.3735  [8, 19, 19]  MDLP(min_samples_leaf=128)     11
#    2        0.3879     0.382  [8, 18, 19]  MDLP(min_samples_leaf=128)     11
#    3        0.3919    0.3787  [8, 16, 14]  MDLP(min_samples_leaf=128)     11
#    4        0.3922     0.382  [8, 20, 19]  MDLP(min_samples_leaf=128)     11
#    5        0.3935    0.3771  [8, 18, 19]  MDLP(min_samples_leaf=128)     11
#    6        0.3888    0.3856  [8, 15, 19]  MDLP(min_samples_leaf=128)     11
#    7        0.3899    0.3844  [8, 16, 16]  MDLP(min_samples_leaf=128)     11
#    8        0.3824    0.3892  [8, 12, 17]  MDLP(min_samples_leaf=128)     11
#    9        0.3909    0.3729  [8, 18, 19]  MDLP(min_samples_leaf=128)     11
#    10       0.3864    0.3818  [8, 16, 16]  MDLP(min_samples_leaf=128)     11
#    MEAN     0.3897    0.3818          NaN                         NaN    NaN
#    STD      0.0036    0.0059          NaN                         NaN    NaN,
#    'mas_no_bt_dict_here',
#    45.62),
#   64: (     Gini_train Gini_test       N_bins  \
#    0        0.3884    0.3892  [8, 18, 16]
#    1        0.3908    0.3868  [8, 18, 19]
#    2        0.3889    0.3898  [8, 19, 19]
#    3        0.3932    0.3796  [8, 19, 19]
#    4        0.3993     0.368  [8, 20, 21]
#    5         0.387    0.3926  [8, 18, 17]
#    6        0.3896    0.3874  [8, 18, 19]
#    7        0.3938    0.3778  [8, 19, 21]
#    8        0.3925    0.3805  [8, 16, 21]
#    9        0.3926    0.3791  [8, 16, 19]
#    10       0.3934    0.3808  [8, 21, 19]
#    MEAN     0.3918    0.3829          NaN
#    STD      0.0032    0.0067          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=128)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.94),
#   128: (     Gini_train Gini_test       N_bins  \
#    0        0.3886    0.3857  [8, 16, 14]
#    1        0.3887    0.3881  [8, 18, 14]
#    2        0.3942     0.377  [8, 18, 19]
#    3        0.3915     0.379  [8, 16, 16]
#    4        0.3838    0.3975  [8, 16, 15]
#    5         0.393    0.3784  [8, 16, 19]
#    6        0.3923    0.3807  [8, 18, 16]
#    7        0.3898    0.3845  [8, 18, 16]
#    8        0.3873    0.3914  [8, 16, 19]
#    9        0.3888    0.3878  [8, 16, 17]
#    10       0.3932    0.3783  [8, 16, 16]
#    MEAN     0.3901    0.3844          NaN
#    STD      0.0029    0.0062          NaN
#
#                                              Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=128)     11
#    MEAN                                             NaN    NaN
#    STD                                              NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    48.01),
#   256: (     Gini_train Gini_test       N_bins  \
#    0        0.3924    0.3814  [8, 20, 19]
#    1        0.3948    0.3748  [8, 18, 19]
#    2        0.3932    0.3774  [8, 16, 14]
#    3        0.3896    0.3875  [8, 16, 19]
#    4        0.3945    0.3759  [8, 16, 16]
#    5        0.3929    0.3835  [8, 20, 17]
#    6        0.3927    0.3828  [8, 20, 21]
#    7        0.3896    0.3871  [8, 16, 19]
#    8        0.3868    0.3921  [8, 16, 17]
#    9        0.3858    0.3939  [8, 16, 17]
#    10        0.389     0.389  [6, 18, 19]
#    MEAN      0.391    0.3841          NaN
#    STD      0.0029    0.0061          NaN
#
#                                              Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=128)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=128)     11
#    MEAN                                             NaN    NaN
#    STD                                              NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    50.2)},
#  256: {4: (     Gini_train Gini_test       N_bins  \
#    0        0.3788    0.3783  [8, 13, 18]
#    1        0.3837    0.3794  [8, 12, 20]
#    2        0.3805    0.3749  [8, 10, 18]
#    3        0.3848    0.3654  [8, 12, 18]
#    4        0.3812    0.3734  [8, 10, 18]
#    5        0.3764    0.3825  [8, 12, 18]
#    6        0.3759    0.3827  [8, 10, 18]
#    7        0.3775    0.3816  [8, 10, 16]
#    8        0.3844    0.3666  [8, 14, 20]
#    9        0.3776     0.383  [8, 16, 18]
#    10       0.3828    0.3675  [6, 10, 18]
#    MEAN     0.3803    0.3759          NaN
#    STD      0.0031    0.0065          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=256)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=256)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.04),
#   8: (     Gini_train Gini_test       N_bins  \
#    0        0.3803    0.3781  [8, 12, 17]
#    1        0.3894    0.3819  [8, 18, 17]
#    2        0.3884    0.3606  [8, 12, 20]
#    3        0.3814    0.3893  [8, 17, 21]
#    4        0.3878    0.3763  [8, 16, 18]
#    5        0.3839    0.3732  [8, 12, 18]
#    6        0.3783    0.3797  [8, 12, 16]
#    7        0.3779     0.387  [8, 14, 18]
#    8        0.3778    0.3846  [8, 14, 20]
#    9        0.3827     0.375  [8, 14, 18]
#    10       0.3852     0.379  [8, 16, 20]
#    MEAN      0.383    0.3786          NaN
#    STD      0.0041    0.0074          NaN
#
#                                            Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=256)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=256)     11
#    MEAN                                           NaN    NaN
#    STD                                            NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.04),
#   16: (     Gini_train Gini_test       N_bins  \
#    0        0.3782    0.3862  [8, 14, 16]
#    1        0.3923    0.3672  [6, 17, 20]
#    2        0.3837    0.3723  [8, 14, 16]
#    3        0.3763    0.3905  [8, 14, 20]
#    4         0.385    0.3718  [8, 14, 16]
#    5        0.3887    0.3762  [8, 16, 16]
#    6        0.3913    0.3798  [8, 19, 14]
#    7        0.3817    0.3892  [6, 16, 14]
#    8        0.3928    0.3761  [8, 18, 17]
#    9        0.3832    0.3734  [8, 12, 16]
#    10       0.3858    0.3782  [8, 14, 18]
#    MEAN     0.3854    0.3783          NaN
#    STD      0.0053    0.0072          NaN
#
#                                             Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=256)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=256)     11
#    MEAN                                            NaN    NaN
#    STD                                             NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.37),
#   32: (     Gini_train Gini_test       N_bins                  Bin_method N_iter
#    0         0.386    0.3946  [8, 15, 21]  MDLP(min_samples_leaf=256)     11
#    1          0.39    0.3864  [8, 17, 19]  MDLP(min_samples_leaf=256)     11
#    2        0.3851    0.3927  [8, 18, 16]  MDLP(min_samples_leaf=256)     11
#    3        0.3912    0.3817  [8, 19, 14]  MDLP(min_samples_leaf=256)     11
#    4        0.3893     0.386  [8, 15, 16]  MDLP(min_samples_leaf=256)     11
#    5         0.389    0.3877  [8, 25, 18]  MDLP(min_samples_leaf=256)     11
#    6        0.3868    0.3905  [8, 16, 16]  MDLP(min_samples_leaf=256)     11
#    7        0.3849    0.3857  [8, 16, 18]  MDLP(min_samples_leaf=256)     11
#    8        0.3899    0.3836  [8, 17, 19]  MDLP(min_samples_leaf=256)     11
#    9        0.3876    0.3914  [8, 18, 18]  MDLP(min_samples_leaf=256)     11
#    10       0.3837    0.3883  [8, 15, 16]  MDLP(min_samples_leaf=256)     11
#    MEAN     0.3876    0.3881          NaN                         NaN    NaN
#    STD      0.0024    0.0037          NaN                         NaN    NaN,
#    'mas_no_bt_dict_here',
#    45.8),
#   64: (     Gini_train Gini_test       N_bins  \
#    0        0.3887    0.3875  [8, 15, 19]
#    1         0.387    0.3892  [8, 15, 16]
#    2        0.3914    0.3816  [8, 18, 20]
#    3        0.3932    0.3828  [8, 19, 21]
# ...
#    5        0.3709    0.3737  [7, 6, 6]  MDLP(min_samples_leaf=16384)     11
#    6        0.3779    0.3599  [5, 5, 6]  MDLP(min_samples_leaf=16384)     11
#    7        0.3694    0.3686  [6, 6, 6]  MDLP(min_samples_leaf=16384)     11
#    8        0.3668    0.3748  [5, 5, 5]  MDLP(min_samples_leaf=16384)     11
#    9        0.3742    0.3629  [4, 6, 5]  MDLP(min_samples_leaf=16384)     11
#    10       0.3805    0.3636  [6, 6, 6]  MDLP(min_samples_leaf=16384)     11
#    MEAN     0.3726    0.3688        NaN                           NaN    NaN
#    STD      0.0046    0.0054        NaN                           NaN    NaN,
#    'mas_no_bt_dict_here',
#    46.15),
#   64: (     Gini_train Gini_test     N_bins  \
#    0         0.377    0.3702  [5, 6, 6]
#    1        0.3735    0.3677  [6, 6, 5]
#    2        0.3748    0.3638  [5, 6, 5]
#    3        0.3732    0.3721  [6, 6, 6]
#    4        0.3739     0.363  [6, 6, 5]
#    5        0.3754    0.3698  [6, 6, 5]
#    6        0.3768    0.3659  [5, 6, 5]
#    7        0.3741     0.368  [5, 6, 5]
#    8        0.3708    0.3671  [6, 6, 5]
#    9        0.3663    0.3717  [6, 6, 5]
#    10       0.3731    0.3795  [5, 6, 6]
#    MEAN     0.3735     0.369        NaN
#    STD      0.0028    0.0044        NaN
#
#                                               Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=16384)     11
#    MEAN                                              NaN    NaN
#    STD                                               NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.84),
#   128: (     Gini_train Gini_test     N_bins  \
#    0        0.3777    0.3634  [6, 6, 5]
#    1        0.3725    0.3698  [7, 6, 5]
#    2        0.3755    0.3624  [6, 6, 5]
#    3        0.3749    0.3665  [6, 6, 5]
#    4        0.3753    0.3646  [5, 6, 5]
#    5        0.3684    0.3753  [5, 6, 6]
#    6        0.3784    0.3588  [5, 7, 5]
#    7        0.3761     0.371  [6, 6, 6]
#    8        0.3729    0.3723  [7, 6, 6]
#    9        0.3792     0.378  [5, 6, 7]
#    10        0.374    0.3632  [6, 6, 6]
#    MEAN      0.375    0.3678        NaN
#    STD      0.0029    0.0057        NaN
#
#                                                Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=16384)     11
#    MEAN                                               NaN    NaN
#    STD                                                NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    47.12),
#   256: (     Gini_train Gini_test     N_bins  \
#    0        0.3751    0.3725  [6, 6, 6]
#    1         0.371     0.375  [5, 6, 5]
#    2        0.3774    0.3634  [7, 6, 5]
#    3        0.3715      0.38  [6, 6, 5]
#    4        0.3769    0.3647  [5, 6, 5]
#    5        0.3734     0.366  [5, 6, 5]
#    6        0.3744    0.3658  [6, 6, 5]
#    7        0.3751    0.3705  [5, 6, 6]
#    8        0.3744    0.3673  [6, 6, 6]
#    9         0.373    0.3679  [5, 6, 5]
#    10       0.3775    0.3584  [5, 7, 5]
#    MEAN     0.3745    0.3683        NaN
#    STD      0.0021    0.0057        NaN
#
#                                                Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=16384)     11
#    MEAN                                               NaN    NaN
#    STD                                                NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    46.69)},
#  32768: {4: (     Gini_train Gini_test     N_bins  \
#    0        0.3346    0.3251  [2, 2, 3]
#    1        0.3342    0.3257  [2, 2, 3]
#    2        0.3277    0.3396  [2, 2, 3]
#    3        0.3285    0.3291  [2, 2, 3]
#    4        0.3353    0.3219  [2, 2, 3]
#    5        0.3297    0.3326  [2, 2, 3]
#    6        0.3249    0.3193  [2, 2, 3]
#    7         0.335    0.3231  [2, 2, 3]
#    8        0.3324    0.3223  [2, 2, 3]
#    9        0.3279    0.3394  [2, 2, 3]
#    10        0.335    0.3256  [2, 2, 3]
#    MEAN     0.3314    0.3276        NaN
#    STD      0.0036    0.0066        NaN
#
#                                              Bin_method N_iter
#    0     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=4, min_samples_leaf=32768)     11
#    MEAN                                             NaN    NaN
#    STD                                              NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.67),
#   8: (     Gini_train Gini_test     N_bins  \
#    0        0.3204    0.3196  [3, 3, 2]
#    1        0.3132    0.3235  [3, 3, 2]
#    2        0.3213    0.3153  [3, 3, 2]
#    3        0.3074    0.3291  [3, 3, 2]
#    4        0.3253    0.3255  [3, 3, 2]
#    5        0.3224      0.31  [3, 3, 2]
#    6        0.3186    0.3224  [3, 3, 2]
#    7        0.3153    0.3314  [3, 3, 2]
#    8         0.319    0.3287  [3, 3, 2]
#    9        0.3176    0.3219  [3, 3, 2]
#    10        0.318    0.3236  [3, 3, 2]
#    MEAN      0.318    0.3228        NaN
#    STD      0.0046    0.0059        NaN
#
#                                              Bin_method N_iter
#    0     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=8, min_samples_leaf=32768)     11
#    MEAN                                             NaN    NaN
#    STD                                              NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    44.32),
#   16: (     Gini_train Gini_test     N_bins  \
#    0        0.3458    0.3328  [3, 3, 3]
#    1        0.3439    0.3357  [3, 3, 3]
#    2        0.3405    0.3473  [3, 3, 3]
#    3        0.3468    0.3376  [3, 3, 3]
#    4        0.3397    0.3419  [3, 3, 3]
#    5         0.348    0.3517  [3, 3, 3]
#    6         0.338    0.3478  [3, 3, 3]
#    7         0.343    0.3321  [3, 3, 3]
#    8        0.3423    0.3406  [3, 3, 3]
#    9        0.3355    0.3493  [3, 3, 3]
#    10        0.342    0.3386  [3, 3, 3]
#    MEAN     0.3423    0.3414        NaN
#    STD      0.0036    0.0065        NaN
#
#                                               Bin_method N_iter
#    0     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=16, min_samples_leaf=32768)     11
#    MEAN                                              NaN    NaN
#    STD                                               NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    47.06),
#   32: (     Gini_train Gini_test     N_bins                    Bin_method N_iter
#    0        0.3521    0.3486  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    1        0.3571    0.3434  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    2        0.3538    0.3414  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    3        0.3389     0.354  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    4        0.3533    0.3524  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    5        0.3571    0.3481  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    6        0.3522     0.354  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    7        0.3484     0.354  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    8        0.3584    0.3493  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    9        0.3403    0.3679  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    10       0.3542    0.3553  [3, 3, 3]  MDLP(min_samples_leaf=32768)     11
#    MEAN     0.3514    0.3517        NaN                           NaN    NaN
#    STD      0.0062    0.0067        NaN                           NaN    NaN,
#    'mas_no_bt_dict_here',
#    46.44),
#   64: (     Gini_train Gini_test     N_bins  \
#    0         0.352    0.3573  [3, 3, 3]
#    1        0.3549    0.3482  [3, 3, 3]
#    2        0.3566    0.3509  [3, 3, 3]
#    3        0.3488    0.3566  [3, 3, 3]
#    4        0.3436    0.3404  [3, 3, 3]
#    5        0.3563    0.3479  [3, 3, 3]
#    6        0.3496    0.3551  [3, 3, 3]
#    7        0.3513    0.3445  [3, 3, 3]
#    8        0.3508    0.3334  [3, 3, 3]
#    9        0.3441    0.3519  [3, 3, 3]
#    10       0.3452     0.344  [3, 3, 3]
#    MEAN     0.3503    0.3482        NaN
#    STD      0.0044     0.007        NaN
#
#                                               Bin_method N_iter
#    0     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=64, min_samples_leaf=32768)     11
#    MEAN                                              NaN    NaN
#    STD                                               NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.42),
#   128: (     Gini_train Gini_test     N_bins  \
#    0        0.3501    0.3371  [3, 3, 3]
#    1        0.3558    0.3536  [3, 3, 3]
#    2        0.3504    0.3499  [3, 3, 3]
#    3        0.3579    0.3441  [3, 3, 3]
#    4        0.3535     0.336  [3, 3, 3]
#    5         0.348    0.3572  [3, 3, 3]
#    6        0.3578    0.3499  [3, 3, 3]
#    7        0.3531    0.3596  [3, 3, 3]
#    8        0.3519    0.3609  [3, 3, 3]
#    9        0.3547    0.3539  [3, 3, 3]
#    10       0.3609    0.3358  [3, 3, 3]
#    MEAN      0.354    0.3489        NaN
#    STD      0.0037    0.0089        NaN
#
#                                                Bin_method N_iter
#    0     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=128, min_samples_leaf=32768)     11
#    MEAN                                               NaN    NaN
#    STD                                                NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    47.19),
#   256: (     Gini_train Gini_test     N_bins  \
#    0        0.3555     0.349  [3, 3, 3]
#    1        0.3544     0.354  [3, 3, 3]
#    2        0.3525    0.3609  [3, 3, 3]
#    3        0.3572    0.3335  [3, 3, 3]
#    4        0.3513     0.362  [3, 3, 3]
#    5        0.3468    0.3433  [3, 3, 3]
#    6        0.3556    0.3523  [3, 3, 3]
#    7        0.3545    0.3569  [3, 3, 3]
#    8        0.3579    0.3437  [3, 3, 3]
#    9        0.3566    0.3485  [3, 3, 3]
#    10       0.3502    0.3612  [3, 3, 3]
#    MEAN     0.3539    0.3514        NaN
#    STD      0.0032    0.0085        NaN
#
#                                                Bin_method N_iter
#    0     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    1     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    2     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    3     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    4     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    5     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    6     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    7     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    8     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    9     MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    10    MDLP(max_candidates=256, min_samples_leaf=32768)     11
#    MEAN                                               NaN    NaN
#    STD                                                NaN    NaN  ,
#    'mas_no_bt_dict_here',
#    45.86)}}

# %%
second_param_name = 'min_samples_leaf'#vertical or axis=1
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_time = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result

for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
        df_report_time.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][2]        
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 
df_report_time.index.rename(second_param_name, inplace = True) 
display(df_report_train)
display(df_report_test)
display(df_report_bins)
display(df_report_time.T)
# Out:
#                      4       8       16      32      64      128     256
# min_samples_leaf
# 16                0.3798   0.383  0.3867  0.3885  0.3907  0.3913  0.3904
# 32                0.3796  0.3833  0.3857  0.3912  0.3898  0.3928  0.3898
# 64                0.3785  0.3854  0.3864   0.389  0.3907  0.3914  0.3905
# 128               0.3796   0.385  0.3865  0.3897  0.3918  0.3901   0.391
# 256               0.3803   0.383  0.3854  0.3876   0.391   0.391  0.3924
# 512               0.3802  0.3823  0.3853  0.3888  0.3902  0.3907  0.3919
# 1024              0.3806  0.3838  0.3855  0.3879  0.3904  0.3908  0.3909
# 2048              0.3795  0.3828  0.3855  0.3887  0.3899  0.3907  0.3906
# 4096               0.377  0.3807  0.3855  0.3875   0.386  0.3885  0.3893
# 8192              0.3759  0.3771  0.3801  0.3803  0.3853  0.3852   0.385
# 16384             0.3494   0.367  0.3659  0.3726  0.3735   0.375  0.3745
# 32768             0.3314   0.318  0.3423  0.3514  0.3503   0.354  0.3539
#                      4       8       16      32      64      128     256
# min_samples_leaf
# 16                0.3762  0.3779  0.3781  0.3846  0.3847  0.3829   0.386
# 32                0.3771  0.3774  0.3781  0.3817  0.3865  0.3801  0.3868
# 64                0.3807  0.3798  0.3796  0.3838  0.3838  0.3838  0.3851
# 128                0.379  0.3771  0.3831  0.3818  0.3829  0.3844  0.3841
# 256               0.3759  0.3786  0.3783  0.3881  0.3833  0.3842  0.3815
# 512               0.3751  0.3806  0.3842  0.3842  0.3843  0.3851  0.3819
# 1024              0.3745  0.3741  0.3788  0.3891  0.3841  0.3824  0.3833
# 2048              0.3799  0.3808  0.3819  0.3818  0.3851  0.3835  0.3848
# 4096              0.3785  0.3772   0.377  0.3739  0.3793  0.3834  0.3842
# 8192              0.3744  0.3775   0.374  0.3763  0.3799  0.3841  0.3833
# 16384             0.3413  0.3681  0.3655  0.3688   0.369  0.3678  0.3683
# 32768             0.3276  0.3228  0.3414  0.3517  0.3482  0.3489  0.3514
#                           4            8            16           32   \
# min_samples_leaf
# 16                [8, 10, 18]  [8, 14, 14]  [8, 14, 18]  [8, 21, 18]
# 32                [8, 10, 18]  [8, 15, 18]  [8, 16, 16]  [8, 18, 19]
# 64                 [8, 8, 18]  [8, 20, 17]  [8, 16, 21]  [8, 20, 19]
# 128               [8, 10, 21]  [8, 12, 17]  [8, 18, 19]  [8, 19, 19]
# 256               [8, 12, 20]  [8, 18, 17]  [6, 17, 20]  [8, 17, 19]
# 512               [8, 16, 18]  [8, 18, 16]  [8, 12, 16]  [8, 18, 16]
# 1024              [8, 16, 16]  [8, 19, 15]  [6, 14, 16]  [8, 21, 16]
# 2048              [8, 10, 17]  [8, 15, 15]  [8, 12, 16]  [8, 16, 15]
# 4096              [8, 13, 14]  [8, 11, 14]  [8, 15, 13]  [8, 12, 12]
# 8192               [7, 8, 11]   [8, 8, 11]  [8, 10, 11]  [8, 11, 10]
# 16384               [4, 4, 4]    [5, 5, 5]    [5, 5, 6]    [5, 6, 6]
# 32768               [2, 2, 3]    [3, 3, 2]    [3, 3, 3]    [3, 3, 3]
#
#                           64           128          256
# min_samples_leaf
# 16                [8, 18, 19]  [8, 15, 21]  [8, 20, 19]
# 32                [8, 19, 16]  [8, 18, 17]  [6, 15, 21]
# 64                [8, 16, 18]  [8, 16, 17]  [8, 18, 19]
# 128               [8, 18, 19]  [8, 18, 14]  [8, 18, 19]
# 256               [8, 15, 16]  [8, 14, 18]  [8, 21, 16]
# 512               [8, 14, 14]  [8, 18, 18]  [8, 15, 16]
# 1024              [8, 18, 14]  [8, 17, 16]  [8, 15, 15]
# 2048              [8, 18, 15]  [8, 17, 15]  [8, 18, 15]
# 4096              [8, 12, 15]  [8, 13, 14]  [8, 12, 13]
# 8192               [7, 9, 10]  [8, 11, 11]   [8, 9, 11]
# 16384               [6, 6, 5]    [7, 6, 5]    [5, 6, 5]
# 32768               [3, 3, 3]    [3, 3, 3]    [3, 3, 3]
# min_samples_leaf  16     32     64     128    256    512    1024   2048   \
# 4                 45.24  45.26  44.78  44.74  45.04  44.77  44.74  61.73
# 8                 44.96  44.91  45.12  44.89  45.04  44.95  45.04  47.43
# 16                45.51   45.1  45.08  45.46  45.37  45.42  45.08  48.01
# 32                45.74  45.98  45.87  45.62   45.8  45.93  45.54  46.55
# 64                46.71  46.79  46.89  46.94  46.53  46.45   46.4  47.01
# 128               48.44  48.32  47.93  48.01  48.28  47.87  47.59  48.72
# 256               51.92   50.3   50.4   50.2   50.1   50.0   49.7  50.36
#
# min_samples_leaf  4096   8192   16384  32768
# 4                  45.7  45.33  45.07  45.67
# 8                 46.93  45.99  44.68  44.32
# 16                45.28  45.95  46.58  47.06
# 32                46.58  46.01  46.15  46.44
# 64                46.28  46.54  46.84  45.42
# 128               49.45  47.73  47.12  47.19
# 256               50.64  48.86  46.69  45.86

# %%
df_tmp = df_report_train.iloc[:, :-1]
plt.figure(figsize=(6,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 min samples leaf')
plt.ylabel('Gini scoring')
plt.title('Train sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='max_candidates')
plt.show()

# %%
df_tmp = df_report_test.iloc[:, :-1]
plt.figure(figsize=(6,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 min_samples_leaf')
plt.ylabel('Gini scoring')
plt.title('Test sets', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='max_candidates')
plt.show()

# %%
df_report_time
# Out:
#                     4     8     16    32    64    128   256
# min_samples_leaf
# 16                 0.93  0.65   1.2  1.43   2.4  4.13  7.61
# 32                 0.95   0.6  0.79  1.67  2.48  4.01  5.99
# 64                 0.47  0.81  0.77  1.56  2.58  3.62  6.09
# 128                0.43  0.58  1.15  1.31  2.63   3.7  5.89
# 256                0.73  0.73  1.06  1.49  2.22  3.97  5.79
# 512                0.46  0.64  1.11  1.62  2.14  3.56  5.69
# 1024               0.43  0.73  0.77  1.23  2.09  3.28  5.39
# 2048              17.42  3.12   3.7  2.24   2.7  4.41  6.05
# 4096               1.39  2.62  0.97  2.27  1.97  5.14  6.33
# 8192               1.02  1.68  1.64   1.7  2.23  3.42  4.55
# 16384              0.76  0.37  2.27  1.84  2.53  2.81  2.38
# 32768              1.36  0.01  2.75  2.13  1.11  2.88  1.55

# %%
#df_report_time = df_report_time - 44.31
df_tmp = df_report_time.iloc[[0,2, 4, 6, 9],:].T
plt.figure(figsize=(6,7))
x = np.log2(df_tmp.index.values)
y = df_tmp
plt.xlabel('log2 max candidates')
plt.ylabel('Time difference, sec')
plt.ylim([0, 8])
plt.title('Pypeline time difference with the base case, sec', fontsize = 14)
plt.plot(x, y)
plt.legend(df_tmp.columns.values, title='min_samples_leaf')
plt.show()

# %%
#pip install mdlp-discretization

# %% [markdown]
# ## Time baseline

# %%
max_iter = 100
inf_repl = 100
parameter_space_1 = [1] #min_samples_leaf
parameter_space_2 = [1,2,3] #max_candidates
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method=KBinsDiscretizer(n_bins=10, strategy='quantile')
        #bin_method = MDLP(min_samples_split=2, min_samples_leaf=parameter_2, max_candidates=parameter_1)
        # have to move the method definition into the cycle to handle the library mistake
        n_iter = 11
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter', 'Run_time'])
        for i in range(n_iter):
            #bin_method = MDLP(min_samples_split=2, min_samples_leaf=parameter_1, max_candidates=parameter_2)
            
            t_internal = time.time()
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            #fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            g_train = round(check_model(model, X, y), 4)
            # now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter 
            t = round((time.time() - t_internal), 2)
            df_result.loc[i, 'Run_time'] = t 

        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2
# Out:
# Run time for parameters 1 1 is 46.09 sec.
# Run time for parameters 1 2 is 44.31 sec.
# Run time for parameters 1 3 is 45.86 sec.

# %%
fn = "MDLP_results_exp_1_time" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
# parameter_space_1 = [2**i for i in range(14, 16)] #min_samples_leaf
# parameter_space_2 = [2**i for i in range(7, 9)] #max_candidates
parameter_space_1 = [1] #min_samples_leaf
parameter_space_2 = [1] #max_candidates

# %%
second_param_name = 'time'#vertical or axis=1
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_time = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result

for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
        df_report_time.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][2]        
df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 
df_report_time.index.rename(second_param_name, inplace = True) 
display(df_report_train)
display(df_report_test)
display(df_report_bins)
display(df_report_time)
# Out:
#            1
# time
# 1     0.3825
#            1
# time
# 1     0.3815
#                  1
# time
# 1     [10, 10, 10]
#           1
# time
# 1     46.09

# %% [markdown]
# # The best one for a wider dataset

# %% [markdown]
# ## Basic experiment

# %%
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
variables_wide = variables + ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'REGION_POPULATION_RELATIVE', 
                              'OWN_CAR_AGE', 'DAYS_BIRTH', 'DAYS_REGISTRATION',
                              'DAYS_ID_PUBLISH','CNT_FAM_MEMBERS', 'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_1',
                              'EXT_SOURCE_2', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BUILD_AVG',
                              'ENTRANCES_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 
                              'LIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE',
                              'YEARS_BUILD_MODE', 'LIVINGAREA_MODE', 'APARTMENTS_MEDI',
                              'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
                              'DAYS_LAST_PHONE_CHANGE', 'AMT_REQ_CREDIT_BUREAU_YEAR']
df = prepare_df(d0, variables_wide, remove_outl=False, remove_na=False)
# Out:
# df initial shape: (307511, 32)
#
#
# final df shape: (307511, 32)

# %%
target = 'TARGET'
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
df = prepare_df(d0)
# Out:
# df initial shape: (307511, 4)
#
# df shape after processing missing values: (202044, 4)
#
# N outliers in DAYS_EMPLOYED: 10203,            df shape after outlier removal: (191841, 4)
# N outliers in AMT_GOODS_PRICE: 2980,            df shape after outlier removal: (188861, 4)
# N outliers in EXT_SOURCE_3: 0,            df shape after outlier removal: (188861, 4)
#
# final df shape: (188861, 4)

# %%
#variables = variables_wide
max_iter = 100
inf_repl = 100
parameter_space_1 = [1] #min impurity decr
parameter_space_2 = [1] # min_samples_leaf
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method = CART(max_leaf_nodes=2048, 
                          min_impurity_decrease=0.00001, ccp_alpha = 0, 
                          criterion = 'entropy', min_samples_leaf=2048)
        n_iter = 21
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter', 'Run_time'])
        for i in range(n_iter):
            t_internal=time.time()
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            #t1 = (time.time() - t_internal)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            #t2 = (time.time() - t1 - t_internal)
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            ###fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            #t3 = (time.time() - t2 - t1 - t_internal)
            g_train = round(check_model(model, X, y), 4)
            ### now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            #t4 = (time.time() - t3 - t2 - t1 - t_internal)

            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter   
            t = round((time.time() - t_internal), 4)
            df_result.loc[i, 'Run_time'] = t #[round(t1, 4), round(t1/t, 4) , round(t2/t, 4), round(t3/t, 4), round(t4/t, 4), t] 
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2
# Out:
# Run time for parameters 1 1 is 26.22 sec.

# %%
fn = "The_best_long" 
#save_obj(result_dict_1, fn)
tmp = load_obj(fn)
parameter_space_1 = [1] #min impurity decrease
parameter_space_2 = [1] # min_samples_leaf

# %%
second_param_name = ''
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_time = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result

for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
        #df_report_time.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0]

df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 

display(df_report_train)
display(df_report_test)
display(df_report_bins)
#display(df_report_time)
# Out:
#        1
#
# 1  0.396
#         1
#
# 1  0.3817
#               1
#
# 1  [26, 20, 27]

# %%
#tmp[1][1][0]#.iloc[0,5][0]
# Out:
#      Gini_train Gini_test        N_bins  \
# 0        0.3974    0.3797  [32, 23, 17]
# 1         0.396    0.3808  [24, 21, 25]
# 2        0.4001     0.372  [28, 24, 19]
# MEAN     0.3978    0.3775           NaN
# STD      0.0017    0.0039           NaN
#
#                                     Bin_method N_iter  \
# 0     <__main__.CART object at 0x7f7f3e144220>      3
# 1     <__main__.CART object at 0x7f7f3e144220>      3
# 2     <__main__.CART object at 0x7f7f3e144220>      3
# MEAN                                       NaN    NaN
# STD                                        NaN    NaN
#
#                                       Run_time
# 0     [0.0688, 0.9026, 0.0218, 0.0067, 4.2337]
# 1     [0.0552, 0.9178, 0.0192, 0.0076, 4.1054]
# 2      [0.0563, 0.9175, 0.0188, 0.0072, 4.036]
# MEAN                                       NaN
# STD                                        NaN

# %%
plot_results(tmp[1][1][0], 'Gini_train', 
             'CART(max_leaf_nodes=2048, min_impurity_decrease=0.00001, \n ccp_alpha = 0, entropy, min_samples_leaf=2048)')
# Out:
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plot_results(tmp[1][1][0], 'Gini_test', 
             'CART(max_leaf_nodes=2048, min_impurity_decrease=0.00001, \n ccp_alpha = 0, entropy, min_samples_leaf=2048)')
# Out:
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Playing with time

# %%
target = 'TARGET'
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
df = prepare_df(d0)
# Out:
# df initial shape: (307511, 4)
#
# df shape after processing missing values: (202044, 4)
#
# N outliers in DAYS_EMPLOYED: 10203,            df shape after outlier removal: (191841, 4)
# N outliers in AMT_GOODS_PRICE: 2980,            df shape after outlier removal: (188861, 4)
# N outliers in EXT_SOURCE_3: 0,            df shape after outlier removal: (188861, 4)
#
# final df shape: (188861, 4)

# %%
target = 'TARGET'
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
variables_wide = variables + ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'REGION_POPULATION_RELATIVE', 
                              'OWN_CAR_AGE', 'DAYS_BIRTH', 'DAYS_REGISTRATION',
                              'DAYS_ID_PUBLISH','CNT_FAM_MEMBERS', 'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_1',
                              'EXT_SOURCE_2', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BUILD_AVG',
                              'ENTRANCES_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 
                              'LIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE',
                              'YEARS_BUILD_MODE', 'LIVINGAREA_MODE', 'APARTMENTS_MEDI',
                              'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
                              'DAYS_LAST_PHONE_CHANGE', 'AMT_REQ_CREDIT_BUREAU_YEAR']
df = prepare_df(d0, variables_wide, remove_outl=False, remove_na=False)
# Out:
# df initial shape: (307511, 32)
#
#
# final df shape: (307511, 32)

# %%
df_train.shape
# Out:
# (215257, 33)

# %%
variables = variables_wide
max_iter = 100
inf_repl = 100
parameter_space_1 = [1] #min impurity decr
parameter_space_2 = [1] # min_samples_leaf
result_dict_1 = {}
for n_param_1, parameter_1 in enumerate(parameter_space_1): 
    result_dict_2 = {} # contains all the df_result tables
    for n_param_2, parameter_2 in enumerate(parameter_space_2): 
        tpar0=time.time()
        bin_method = CART(max_leaf_nodes=2048, 
                          min_impurity_decrease=0.00001, ccp_alpha = 0, 
                          criterion = 'entropy', min_samples_leaf=2048, n_jobs = -1)
        n_iter = 2
        verbose = False
        model = LogisticRegression(max_iter=max_iter)
        
        df_result = pd.DataFrame(columns=['Gini_train', 'Gini_test', 
                                          'N_bins', 'Bin_method', 'N_iter', 'Run_time'])
        for i in range(n_iter):
            t_internal=time.time()
            df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
            df_train = df_train.reset_index()
            df_test = df_test.reset_index()
            tmp = get_edges_dict(df_train, variables, target, 
                                 verbose=False, bin_method=bin_method)
            t1 = (time.time() - t_internal)
            ed = tmp[0]
            bt = tmp[1]
            df_woe_train = var_list_woe(df_train, df_train, variables, target, ed, verbose=False)
            
            df_woe_test = var_list_woe(df_test, df_train, variables, target, ed, verbose=False)       
            t2 = (time.time() - t1 - t_internal)
            df_woe_train.replace(np.inf, inf_repl, inplace=True)
            df_woe_test.replace(np.inf, inf_repl, inplace=True)
            ###fit the model on train set
            X = df_woe_train.iloc[:, 1:].to_numpy()
            y = df_woe_train.iloc[:, 0].values
            model.fit(X, y)
            t3 = (time.time() - t2 - t1 - t_internal)
            g_train = round(check_model(model, X, y), 4)
            ### now test the model on test_set
            X = df_woe_test.iloc[:, 1:].to_numpy()
            y = df_woe_test.iloc[:, 0].values
            g_test = round(check_model(model, X, y), 4)
            t4 = (time.time() - t3 - t2 - t1 - t_internal)

            df_result.loc[i, 'Bin_method'] = bin_method  
            df_result.loc[i, 'Gini_train'] = g_train
            df_result.loc[i, 'Gini_test'] = g_test
            df_result.loc[i, 'N_bins'] = [len(ed[x])+1 for x in ed.keys()]
            df_result.loc[i, 'N_iter'] = n_iter   
            t = round((time.time() - t_internal), 4)
            df_result.loc[i, 'Run_time'] = [round(t1, 4), round(t2, 4), round(t1/t, 4) , round(t2/t, 4), round(t3/t, 4), round(t4/t, 4), t] 
        df_result.loc['MEAN']= round(df_result[['Gini_train', 'Gini_test']].mean(), 4)
        df_result.loc['STD']= round(df_result[['Gini_train', 'Gini_test']].std(), 4)
        t = round((time.time() - tpar0), 2)
        print(f'Run time for parameters {parameter_1} {parameter_2} is {t} sec.')
        result_dict_2[parameter_2] = (df_result, bt, t)
    result_dict_1[parameter_1] = result_dict_2
# Out:
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# WOE_transform: Bin_table-3.2%; np.searchsorted-0.5%; wrap up-96.3%; Total 1.4sec
# WOE_transform: Bin_table-3.8%; np.searchsorted-0.5%; wrap up-95.7%; Total 1.4sec
# WOE_transform: Bin_table-3.9%; np.searchsorted-0.4%; wrap up-95.7%; Total 1.4sec
# WOE_transform: Bin_table-3.3%; np.searchsorted-0.2%; wrap up-96.6%; Total 1.4sec
# WOE_transform: Bin_table-3.0%; np.searchsorted-0.3%; wrap up-96.7%; Total 1.7sec
# WOE_transform: Bin_table-3.7%; np.searchsorted-0.6%; wrap up-95.8%; Total 1.4sec
# WOE_transform: Bin_table-3.7%; np.searchsorted-0.3%; wrap up-96.0%; Total 1.4sec
# WOE_transform: Bin_table-3.6%; np.searchsorted-0.4%; wrap up-96.0%; Total 1.4sec
# WOE_transform: Bin_table-3.6%; np.searchsorted-0.4%; wrap up-95.9%; Total 1.4sec
# WOE_transform: Bin_table-3.5%; np.searchsorted-0.5%; wrap up-95.9%; Total 1.4sec
# /Users/AM/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# WOE_transform: Bin_table-3.4%; np.searchsorted-0.2%; wrap up-96.4%; Total 1.4sec
# WOE_transform: Bin_table-3.1%; np.searchsorted-0.3%; wrap up-96.7%; Total 1.6sec
# WOE_transform: Bin_table-3.8%; np.searchsorted-0.4%; wrap up-95.8%; Total 1.5sec
# WOE_transform: Bin_table-3.7%; np.searchsorted-0.5%; wrap up-95.8%; Total 1.5sec
# WOE_transform: Bin_table-4.3%; np.searchsorted-0.3%; wrap up-95.3%; Total 1.6sec
# WOE_transform: Bin_table-3.7%; np.searchsorted-0.3%; wrap up-96.0%; Total 1.6sec
# WOE_transform: Bin_table-3.5%; np.searchsorted-0.2%; wrap up-96.3%; Total 1.6sec
# WOE_transform: Bin_table-3.6%; np.searchsorted-0.2%; wrap up-96.1%; Total 1.5sec
# WOE_transform: Bin_table-3.8%; np.searchsorted-0.3%; wrap up-95.9%; Total 1.6sec

# %%
fn = 'tmp'
#fn = "The_best_wide_with_times" 
save_obj(result_dict_1, fn)
tmp = load_obj(fn)
parameter_space_1 = [1] #min impurity decrease
parameter_space_2 = [1] # min_samples_leaf

# %%
tt = tmp[parameter_1][parameter_2][0].loc[:, 'Run_time'][:-2]
cn=['t_bin_sec', 't_woe_tr_sec', 't_bin_pct', 't_woe_tr_pct', 't_mod_pct', 't_ch_pct', 't_tot_sec']
df_time = pd.DataFrame(columns=cn)
for i in range(len(tt)):
    df_time.loc[i, :] = np.array(tt[i])
df_time.loc['mean', :] = df_time.mean()
display(df_time)
# Out:
#      t_bin_sec t_woe_tr_sec t_bin_pct t_woe_tr_pct t_mod_pct t_ch_pct  \
# 0       0.6088         6.43    0.0845       0.8926    0.0166   0.0063
# 1       0.5283       6.3308    0.0752       0.9018    0.0163   0.0066
# mean   0.56855       6.3804   0.07985       0.8972   0.01645  0.00645
#
#      t_tot_sec
# 0        7.204
# 1       7.0206
# mean    7.1123

# %%
tt = tmp[parameter_1][parameter_2][0].loc[:, 'Run_time'][:-2]
cn=['t_bin_sec', 't_woe_tr_sec', 't_bin_pct', 't_woe_tr_pct', 't_mod_pct', 't_ch_pct', 't_tot_sec']
df_time = pd.DataFrame(columns=cn)
for i in range(len(tt)):
    df_time.loc[i, :] = np.array(tt[i])
df_time.loc['mean', :] = df_time.mean()
display(df_time)
# Out:
#      t_bin_sec t_woe_tr_sec t_bin_pct t_woe_tr_pct t_mod_pct  t_ch_pct  \
# 0       0.2724       4.0882     0.061       0.9152    0.0173    0.0064
# 1       0.2245       3.9115    0.0529       0.9222    0.0179    0.0069
# 2       0.2237       3.7311    0.0551       0.9187    0.0191     0.007
# 3       0.2211       3.7203    0.0547         0.92    0.0182    0.0069
# 4       0.2215       3.7358    0.0546         0.92    0.0183     0.007
# 5       0.2228       3.7188    0.0551       0.9198    0.0181    0.0068
# 6       0.2217       3.6983    0.0551       0.9194    0.0183     0.007
# mean  0.229671     3.800571    0.0555     0.919329  0.018171  0.006857
#
#      t_tot_sec
# 0       4.4671
# 1       4.2416
# 2       4.0614
# 3       4.0436
# 4       4.0604
# 5       4.0431
# 6       4.0223
# mean  4.134214

# %%
second_param_name = ''
df_report_train = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_test = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_bins = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result
df_report_time = pd.DataFrame(columns=parameter_space_2) # parameter to plot cycle result

for parameter_1 in parameter_space_1:
    for parameter_2 in parameter_space_2:
        df_report_train.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_train']
        df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
        df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
        df_report_time.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[:, 'Run_time'][:-2]

df_report_train.index.rename(second_param_name, inplace = True) 
df_report_test.index.rename(second_param_name, inplace = True) 
df_report_bins.index.rename(second_param_name, inplace = True) 

#display(df_report_train)
#display(df_report_test)
#display(df_report_bins)
#display(df_report_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l6/r1vg3v7s7t57x3f0r786wnhc0000gp/T/ipykernel_49968/2940157161.py in <module>
#      10         df_report_test.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc['MEAN', 'Gini_test']
#      11         df_report_bins.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[1, 'N_bins']
# ---> 12         df_report_time.loc[parameter_1, parameter_2] = tmp[parameter_1][parameter_2][0].loc[:, 'Run_time'][:-2]
#      13
#      14 df_report_train.index.rename(second_param_name, inplace = True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# -> 1732             self._setitem_single_block(indexer, value, name)
#    1733
#    1734     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    1957             # setting for extensionarrays that store dicts. Need to decide
#    1958             # if it's worth supporting that.
# -> 1959             value = self._align_series(indexer, Series(value))
#    1960
#    1961         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2147             return ser.reindex(ax)._values
#    2148
# -> 2149         raise ValueError("Incompatible indexer with Series")
#    2150
#    2151     def _align_frame(self, indexer, df: DataFrame):
#
# ValueError: Incompatible indexer with Series

# %%
tmp[1][1][0]#.iloc[0,5][0]
# Out:
#      Gini_train Gini_test        N_bins  \
# 0        0.3983     0.373  [25, 22, 25]
# 1         0.394    0.3859  [26, 20, 27]
# 2        0.3982     0.377  [26, 23, 22]
# 3        0.3943    0.3872  [28, 25, 20]
# 4        0.3947    0.3857  [24, 20, 22]
# 5        0.3968    0.3816  [20, 24, 23]
# MEAN      0.396    0.3817           NaN
# STD      0.0018    0.0052           NaN
#
#                                     Bin_method N_iter  \
# 0     <__main__.CART object at 0x7f7f3dce2b80>      6
# 1     <__main__.CART object at 0x7f7f3dce2b80>      6
# 2     <__main__.CART object at 0x7f7f3dce2b80>      6
# 3     <__main__.CART object at 0x7f7f3dce2b80>      6
# 4     <__main__.CART object at 0x7f7f3dce2b80>      6
# 5     <__main__.CART object at 0x7f7f3dce2b80>      6
# MEAN                                       NaN    NaN
# STD                                        NaN    NaN
#
#                                               Run_time
# 0        [0.2579, 0.061, 0.9139, 0.0179, 0.007, 4.226]
# 1     [0.2548, 0.0552, 0.9221, 0.0163, 0.0063, 4.6128]
# 2      [0.2297, 0.0541, 0.921, 0.0181, 0.0067, 4.2463]
# 3     [0.2305, 0.0532, 0.9228, 0.0171, 0.0067, 4.3296]
# 4     [0.2241, 0.0494, 0.9265, 0.0176, 0.0063, 4.5317]
# 5      [0.2192, 0.0514, 0.9182, 0.0223, 0.008, 4.2668]
# MEAN                                               NaN
# STD                                                NaN

# %% [markdown]
# # Test sandbox

# %%
df.EXT_SOURCE_3.hist()

# %%
df_tmp = df_woe_train
print("printing column name where infinity is present")
col_name = df_tmp.columns.to_series()[np.isinf(df_tmp).any()]
print(col_name)
# Out:
# printing column name where infinity is present
# CNT_FAM_MEMBERS_woe    CNT_FAM_MEMBERS_woe
# dtype: object

# %%
np.isinf(df_tmp)#.any()
# Out:
#         TARGET  DAYS_EMPLOYED_woe  AMT_GOODS_PRICE_woe  EXT_SOURCE_3_woe  \
# 0        False              False                False             False
# 1        False              False                False             False
# 2        False              False                False             False
# 3        False              False                False             False
# 4        False              False                False             False
# ...        ...                ...                  ...               ...
# 215252   False              False                False             False
# 215253   False              False                False             False
# 215254   False              False                False             False
# 215255   False              False                False             False
# 215256   False              False                False             False
#
#         CNT_CHILDREN_woe  AMT_INCOME_TOTAL_woe  \
# 0                  False                 False
# 1                  False                 False
# 2                  False                 False
# 3                  False                 False
# 4                  False                 False
# ...                  ...                   ...
# 215252             False                 False
# 215253             False                 False
# 215254             False                 False
# 215255             False                 False
# 215256             False                 False
#
#         REGION_POPULATION_RELATIVE_woe  OWN_CAR_AGE_woe  DAYS_BIRTH_woe  \
# 0                                False            False           False
# 1                                False            False           False
# 2                                False            False           False
# 3                                False            False           False
# 4                                False            False           False
# ...                                ...              ...             ...
# 215252                           False            False           False
# 215253                           False            False           False
# 215254                           False            False           False
# 215255                           False            False           False
# 215256                           False            False           False
#
#         DAYS_REGISTRATION_woe  ...  APARTMENTS_MODE_woe  \
# 0                       False  ...                False
# 1                       False  ...                False
# 2                       False  ...                False
# 3                       False  ...                False
# 4                       False  ...                False
# ...                       ...  ...                  ...
# 215252                  False  ...                False
# 215253                  False  ...                False
# 215254                  False  ...                False
# 215255                  False  ...                False
# 215256                  False  ...                False
#
#         BASEMENTAREA_MODE_woe  YEARS_BUILD_MODE_woe  LIVINGAREA_MODE_woe  \
# 0                       False                 False                False
# 1                       False                 False                False
# 2                       False                 False                False
# 3                       False                 False                False
# 4                       False                 False                False
# ...                       ...                   ...                  ...
# 215252                  False                 False                False
# 215253                  False                 False                False
# 215254                  False                 False                False
# 215255                  False                 False                False
# 215256                  False                 False                False
#
#         APARTMENTS_MEDI_woe  TOTALAREA_MODE_woe  OBS_30_CNT_SOCIAL_CIRCLE_woe  \
# 0                     False               False                         False
# 1                     False               False                         False
# 2                     False               False                         False
# 3                     False               False                         False
# 4                     False               False                         False
# ...                     ...                 ...                           ...
# 215252                False               False                         False
# 215253                False               False                         False
# 215254                False               False                         False
# 215255                False               False                         False
# 215256                False               False                         False
#
#         DEF_30_CNT_SOCIAL_CIRCLE_woe  DAYS_LAST_PHONE_CHANGE_woe  \
# 0                              False                       False
# 1                              False                       False
# 2                              False                       False
# 3                              False                       False
# 4                              False                       False
# ...                              ...                         ...
# 215252                         False                       False
# 215253                         False                       False
# 215254                         False                       False
# 215255                         False                       False
# 215256                         False                       False
#
#         AMT_REQ_CREDIT_BUREAU_YEAR_woe
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 215252                           False
# 215253                           False
# 215254                           False
# 215255                           False
# 215256                           False
#
# [215257 rows x 32 columns]

# %%
np.isinf(df_tmp).any()
# Out:
# TARGET                            False
# DAYS_EMPLOYED_woe                 False
# AMT_GOODS_PRICE_woe               False
# EXT_SOURCE_3_woe                  False
# CNT_CHILDREN_woe                  False
# AMT_INCOME_TOTAL_woe              False
# REGION_POPULATION_RELATIVE_woe    False
# OWN_CAR_AGE_woe                   False
# DAYS_BIRTH_woe                    False
# DAYS_REGISTRATION_woe             False
# DAYS_ID_PUBLISH_woe               False
# CNT_FAM_MEMBERS_woe                True
# HOUR_APPR_PROCESS_START_woe       False
# EXT_SOURCE_1_woe                  False
# EXT_SOURCE_2_woe                  False
# APARTMENTS_AVG_woe                False
# BASEMENTAREA_AVG_woe              False
# YEARS_BUILD_AVG_woe               False
# ENTRANCES_AVG_woe                 False
# LANDAREA_AVG_woe                  False
# LIVINGAPARTMENTS_AVG_woe          False
# LIVINGAREA_AVG_woe                False
# APARTMENTS_MODE_woe               False
# BASEMENTAREA_MODE_woe             False
# YEARS_BUILD_MODE_woe              False
# LIVINGAREA_MODE_woe               False
# APARTMENTS_MEDI_woe               False
# TOTALAREA_MODE_woe                False
# OBS_30_CNT_SOCIAL_CIRCLE_woe      False
# DEF_30_CNT_SOCIAL_CIRCLE_woe      False
# DAYS_LAST_PHONE_CHANGE_woe        False
# AMT_REQ_CREDIT_BUREAU_YEAR_woe    False
# dtype: bool

# %%
variable = variables[1]
x = df[variable].values
y = df[target]
bm = OptimalBinning(name = variable, max_pvalue=0.3, max_pvalue_policy='all')
bm.fit(x, y)

bt = bm.binning_table
bt.build()

bt.plot()

# %%
bt.analysis()

# %%
bt.build()

# %%
bt.build()
# p-val = 0.3

# %%
bt.analysis()

# %%
bt.build()

# %%
target = 'TARGET'
variables = ['DAYS_EMPLOYED', 'AMT_GOODS_PRICE', 'EXT_SOURCE_3']
df0 = d0.select(variables + [target]).toPandas()
df0.DAYS_EMPLOYED.replace(365243, np.nan, inplace=True)
df = df0.dropna(axis=0)
df.shape

# %%
i = 2
bt = bin_table(df, variables[i], target, ed[variables[i]])

# %%
bt

# %%
result_dict_1[0.01]['iv']

# %%
def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
save_obj(result_dict_1, "result_dict_1")
tmp = load_obj('result_dict_1')
tmp[0.01]['iv'][1].build()

# %%
#t
v = 'EXT_SOURCE_3'
bin_table(df, v, target, ed[v])

# %%
#t
#df_train, df_test = train_test_split(df, test_size=0.30)#, stratify=df[target])
bin_method = MDLP(min_samples_split=2, min_samples_leaf=25000, max_candidates=32)
#bin_method = OptimalBinning()
ed = get_edges_dict(df_train, variables, target, verbose=False, bin_method=bin_method)
ed

# %%
#t
#del(est)
bin_method = MDLP(min_samples_split=2, min_samples_leaf=2500, max_candidates=32)
variable = 'AMT_GOODS_PRICE'
ind_tmp = df[variable].isna()
x = df[variable][~ind_tmp].values
y = df[target][~ind_tmp]
print(x.shape, y.shape, x.min(), x.max())
bin_method.fit(x, y)
tmp = bin_method.splits
tmp1 = tmp.tolist()
bins1 = tmp1
print(f'type bin1 {type(bins1)}')
print(f'bins1: {bins1}; len bins2: {len(bins1)}')
bt = bin_table(df, variable, target, np.array(bins1))
display(bt)

variable = 'DAYS_EMPLOYED'
ind_tmp = df[variable].isna()
x = df[variable][~ind_tmp].values
y = df[target][~ind_tmp]
print(x.shape, y.shape, x.min(), x.max())
bin_method.fit(x, y)
tmp = bin_method.splits
tmp2 = tmp.tolist()
print(f'tmp2 {tmp2}; len tmp2: {len(tmp2)}')

for e in bins1:
    tmp2.remove(e)
    print(f'after removing {e} we have in tmp2 {len(tmp2)} elements')
    print(f'tmp2 : {tmp2}')
    print('')
bins2 = tmp2        
print(f'type bins2: {type(bins2)}; len bins2: {len(bins2)}')
print(f'bins2 {bins2}')
bt = bin_table(df, variable, target, np.array(bins2))
display(bt)
# Out:
# (188861,) (188861,) 40500.0 1615500.0
# type bin1 <class 'list'>
# bins1: [90000.0, 158791.34903225806, 202500.0, 226206.29032258064, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]; len bins2: 20
#                               Bin     Count  Count (%)  Non_event    Event  \
# 0                 (-inf, 90000.0]    4278.0       2.27     4002.0    276.0
# 1           (90000.0, 158791.349]   10808.0       5.72     9993.0    815.0
# 2          (158791.349, 202500.0]   10588.0       5.61     9665.0    923.0
# 3           (202500.0, 226206.29]   14697.0       7.78    13138.0   1559.0
# 4           (226206.29, 279000.0]   18118.0       9.59    16667.0   1451.0
# 5          (279000.0, 303193.161]    2708.0       1.43     2440.0    268.0
# 6          (303193.161, 337500.0]    6732.0       3.56     6034.0    698.0
# 7          (337500.0, 409456.452]    8382.0       4.44     7426.0    956.0
# 8        (409456.452, 453341.613]   20097.0      10.64    17249.0   2848.0
# 9        (453341.613, 463415.001]    5831.0       3.09     5469.0    362.0
# 10       (463415.001, 470670.968]    2722.0       1.44     2539.0    183.0
# 11       (470670.968, 588164.516]   13320.0       7.05    12269.0   1051.0
# 12         (588164.516, 630000.0]    2844.0       1.51     2598.0    246.0
# 13         (630000.0, 676995.262]   16767.0       8.88    15161.0   1606.0
# 14       (676995.262, 686119.355]    3620.0       1.92     3484.0    136.0
# 15       (686119.355, 721810.161]    4581.0       2.43     4304.0    277.0
# 16       (721810.161, 900893.758]   18038.0       9.55    16699.0   1339.0
# 17         (900893.758, 975510.0]    4278.0       2.27     4050.0    228.0
# 18        (975510.0, 1332168.387]   13673.0       7.24    12848.0    825.0
# 19     (1332168.387, 1372987.742]    4238.0       2.24     4070.0    168.0
# 20             (1372987.742, inf]    2541.0       1.35     2431.0    110.0
# Total                         NaN  188861.0     100.01   172536.0  16325.0
#
#       Event_rate       WoE            IV    Gini
# 0       0.064516   0.31624  1.988701e-03
# 1       0.075407  0.148544  1.187595e-03
# 2       0.087174 -0.009271  4.837237e-06
# 3       0.106076 -0.226444  4.381981e-03
# 4       0.080086   0.08327  6.426780e-04
# 5       0.098966 -0.149142  3.392326e-04
# 6       0.103684 -0.200962  1.564307e-03
# 7       0.114054 -0.307924  4.779034e-03
# 8       0.141713 -0.556771  4.146999e-02
# 9       0.062082  0.357299  3.402610e-03
# 10       0.06723  0.272131  9.540834e-04
# 11      0.078904  0.099425  6.691343e-04
# 12      0.086498 -0.000743  8.306155e-09
# 13      0.095783 -0.112929  1.186337e-03
# 14      0.037569  0.885373  1.050239e-02
# 15      0.060467  0.385374  3.074393e-03
# 16      0.074232  0.165518  2.443727e-03
# 17      0.053296  0.519218  4.936236e-03
# 18      0.060338  0.387652  9.276365e-03
# 19      0.039641  0.829526  1.103130e-02
# 20       0.04329  0.737669  5.423110e-03
# Total                       1.092580e-01  0.1822
# (188861,) (188861,) -7483.0 0.0
# tmp2 [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 90000.0, 158791.34903225806, 202500.0, 226206.29032258064, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]; len tmp2: 27
# after removing 90000.0 we have in tmp2 26 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 158791.34903225806, 202500.0, 226206.29032258064, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 158791.34903225806 we have in tmp2 25 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 202500.0, 226206.29032258064, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 202500.0 we have in tmp2 24 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 226206.29032258064, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 226206.29032258064 we have in tmp2 23 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 279000.0, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 279000.0 we have in tmp2 22 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 303193.16129032255, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 303193.16129032255 we have in tmp2 21 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 337500.0, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 337500.0 we have in tmp2 20 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 409456.4516129032, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 409456.4516129032 we have in tmp2 19 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 453341.61290322576, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 453341.61290322576 we have in tmp2 18 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 463415.0008064516, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 463415.0008064516 we have in tmp2 17 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 470670.96774193546, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 470670.96774193546 we have in tmp2 16 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 588164.5161290322, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 588164.5161290322 we have in tmp2 15 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 630000.0, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 630000.0 we have in tmp2 14 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 676995.2615322581, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 676995.2615322581 we have in tmp2 13 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 686119.3548387097, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 686119.3548387097 we have in tmp2 12 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 721810.1612903225, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 721810.1612903225 we have in tmp2 11 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 900893.7580645161, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 900893.7580645161 we have in tmp2 10 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 975510.0, 1332168.387096774, 1372987.7419354839]
#
# after removing 975510.0 we have in tmp2 9 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 1332168.387096774, 1372987.7419354839]
#
# after removing 1332168.387096774 we have in tmp2 8 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743, 1372987.7419354839]
#
# after removing 1372987.7419354839 we have in tmp2 7 elements
# tmp2 : [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743]
#
# type bins2: <class 'list'>; len bins2: 7
# bins2 [-4400.312903225807, -3249.3987096774194, -2438.4103225806457, -1849.597419354839, -1406.9306451612902, -1012.8066129032259, -876.6683870967743]
#                           Bin     Count  Count (%)  Non_event    Event  \
# 0           (-inf, -4400.313]   21427.0      11.35    20347.0   1080.0
# 1      (-4400.313, -3249.399]   19358.0      10.25    18179.0   1179.0
# 2       (-3249.399, -2438.41]   22685.0      12.01    21097.0   1588.0
# 3       (-2438.41, -1849.597]   20419.0      10.81    18793.0   1626.0
# 4      (-1849.597, -1406.931]   20703.0      10.96    18837.0   1866.0
# 5      (-1406.931, -1012.807]   21720.0      11.50    19575.0   2145.0
# 6       (-1012.807, -876.668]    8234.0       4.36     7381.0    853.0
# 7             (-876.668, inf]   54315.0      28.76    48327.0   5988.0
# Total                     NaN  188861.0     100.00   172536.0  16325.0
#
#       Event_rate       WoE        IV    Gini
# 0       0.050404  0.578064  0.029928
# 1       0.060905  0.377692  0.012518
# 2       0.070002  0.228747  0.005719
# 3       0.079632  0.089453  0.000834
# 4       0.090132 -0.045882  0.000235
# 5       0.098757 -0.146795  0.002633
# 6       0.103595 -0.200003  0.001894
# 7       0.110246 -0.269675  0.023381
# Total                       0.077143  0.1507

# %%
# # stable as of 4/11 morning
# def WOE_transform(df, variable, target, edges):
#     '''
#     optimized version
#     returns df with new column f'{variable}_woe' - WOE transormed variable
#     first it uses bin_table function
#     '''  
#     btf = bin_table(df, variable, target, edges)
#     woe_index = np.searchsorted(edges, df[variable].values)
#     df_tmp = df.copy()
#     df_tmp[f'{variable}_WoE'] = [btf.WoE[i] for i in woe_index]
#     tmp = btf.WoE[btf.shape[0]-2]
#     df_tmp.loc[df_tmp[variable].isna(), f'{variable}_WoE'] = tmp

#     #df_tmp[f'{variable}_WoE'][df_tmp[variable].isna()] = tmp
    
#     return df_tmp

# %%
11

# %%
12

# %%
1
